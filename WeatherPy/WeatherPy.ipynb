# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing the relevant modules for weather analyses
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import scipy.stats as st

# Importing the API Key
from api_keys import weather_api_key

# Setting Unit of Measurement for Temperature
celsius ='metric'

# Setting up the query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={celsius}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# Preparing lists to store random lattitude and longitude coordinates
random_lat_long = []
city_names = []

# Creting Random Lattitudes
ran_lattitude = np.random.uniform(low=-90.000, high=90.000, size=1500)
ran_longitude = np.random.uniform(low=-180.000, high=180.000, size=1500)
random_lat_long = zip(ran_lattitude,ran_longitude)

# Assigning the nearest city to the coordinates
for lat_long in random_lat_long:
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name

    # Ensuring only unique city names are added
    if city in city_names:
        next
    else:
        city_names.append(city)
print(f'The number of cities added are {len(city_names)}')
# Out:
# The number of cities added are 655

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
updated_city_list = []
cloudinesses = []
dates = []
humidity = []
lattitude = []
longitude = []
max_temp = []
wind = []
country_list = []

# set initial count quantities for organization
record_number = 0
record_sets = 1

# loops for creating dataframe columns
print(f'Data Retreival commencing\n---------------------\n')
for city in city_names:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lattitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        if record_number > 49:
            record_number = 1
            record_sets += 1
            updated_city_list.append(city)
        else:
            record_number += 1
            updated_city_list.append(city)
        print(f"Processing Record {record_number} of Set {record_sets} | {city}")
    except Exception:
        print(f"{city} not found. Proceeding to the next city...")
print("------------------------------")
print("Data Retrieval Complete\n------------------------------")
# Out:
# Data Retreival commencing
# ---------------------
#
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | auki
# Processing Record 4 of Set 1 | cherskiy
# Processing Record 5 of Set 1 | noumea
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | havre-saint-pierre
# Processing Record 9 of Set 1 | rio grande
# tabiauea not found. Proceeding to the next city...
# Processing Record 10 of Set 1 | zhanaozen
# Processing Record 11 of Set 1 | sainte-suzanne
# Processing Record 12 of Set 1 | tezu
# Processing Record 13 of Set 1 | sao joao da barra
# Processing Record 14 of Set 1 | vardo
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | kysyl-syr
# Processing Record 18 of Set 1 | mount gambier
# Processing Record 19 of Set 1 | zhangjiakou
# Processing Record 20 of Set 1 | dnipryany
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | preobrazheniye
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | caluquembe
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | never
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | ushuaia
# la ronge not found. Proceeding to the next city...
# Processing Record 29 of Set 1 | chapais
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | ngunguru
# Processing Record 32 of Set 1 | honiara
# Processing Record 33 of Set 1 | minas
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | minas novas
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | laguna
# Processing Record 39 of Set 1 | port lincoln
# Processing Record 40 of Set 1 | shingu
# Processing Record 41 of Set 1 | port macquarie
# Processing Record 42 of Set 1 | kralendijk
# taolanaro not found. Proceeding to the next city...
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | san policarpo
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | san pedro
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | esperance
# Processing Record 3 of Set 2 | muros
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | faya
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | victoria
# guicheng not found. Proceeding to the next city...
# Processing Record 9 of Set 2 | kayes
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | kapaa
# chagda not found. Proceeding to the next city...
# Processing Record 12 of Set 2 | namie
# Processing Record 13 of Set 2 | yuncheng
# Processing Record 14 of Set 2 | mataura
# mizan teferi not found. Proceeding to the next city...
# Processing Record 15 of Set 2 | porto tolle
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | san rafael
# Processing Record 20 of Set 2 | roebourne
# Processing Record 21 of Set 2 | nizhnyaya tavda
# nizhneyansk not found. Proceeding to the next city...
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | ambilobe
# barentsburg not found. Proceeding to the next city...
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | pulilan
# Processing Record 26 of Set 2 | puerto narino
# Processing Record 27 of Set 2 | kurilsk
# Processing Record 28 of Set 2 | juneau
# Processing Record 29 of Set 2 | tuatapere
# Processing Record 30 of Set 2 | lagoa
# Processing Record 31 of Set 2 | ginda
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | ust-koksa
# Processing Record 35 of Set 2 | mandali
# Processing Record 36 of Set 2 | yellowknife
# Processing Record 37 of Set 2 | westerland
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | vasylivka
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | khandbari
# Processing Record 42 of Set 2 | port elizabeth
# attawapiskat not found. Proceeding to the next city...
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | lata
# Processing Record 46 of Set 2 | yarmouth
# Processing Record 47 of Set 2 | biograd na moru
# Processing Record 48 of Set 2 | bubaque
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | grand river south east
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | horki
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | xuddur
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | poya
# Processing Record 7 of Set 3 | antofagasta
# juxian not found. Proceeding to the next city...
# Processing Record 8 of Set 3 | codrington
# Processing Record 9 of Set 3 | avera
# Processing Record 10 of Set 3 | najran
# Processing Record 11 of Set 3 | harrisburg
# Processing Record 12 of Set 3 | olinda
# Processing Record 13 of Set 3 | seminole
# Processing Record 14 of Set 3 | oranjemund
# Processing Record 15 of Set 3 | galveston
# Processing Record 16 of Set 3 | naze
# Processing Record 17 of Set 3 | hun
# Processing Record 18 of Set 3 | san patricio
# Processing Record 19 of Set 3 | whithorn
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | high level
# Processing Record 24 of Set 3 | hervey bay
# Processing Record 25 of Set 3 | nikolskoye
# ruatoria not found. Proceeding to the next city...
# Processing Record 26 of Set 3 | loubomo
# Processing Record 27 of Set 3 | nelson bay
# Processing Record 28 of Set 3 | yeovil
# Processing Record 29 of Set 3 | buzmeyin
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | ribeira grande
# sentyabrskiy not found. Proceeding to the next city...
# Processing Record 33 of Set 3 | santa catalina
# Processing Record 34 of Set 3 | gogrial
# Processing Record 35 of Set 3 | camacha
# Processing Record 36 of Set 3 | telhara
# Processing Record 37 of Set 3 | tongchuan
# Processing Record 38 of Set 3 | gweta
# Processing Record 39 of Set 3 | aracataca
# Processing Record 40 of Set 3 | rybnoye
# Processing Record 41 of Set 3 | fortuna
# saint george not found. Proceeding to the next city...
# Processing Record 42 of Set 3 | coahuayana
# Processing Record 43 of Set 3 | kozluk
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | udachnyy
# Processing Record 46 of Set 3 | flinders
# Processing Record 47 of Set 3 | grindavik
# Processing Record 48 of Set 3 | alappuzha
# umm jarr not found. Proceeding to the next city...
# Processing Record 49 of Set 3 | abu dhabi
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | jamestown
# Processing Record 2 of Set 4 | sechura
# Processing Record 3 of Set 4 | bograd
# Processing Record 4 of Set 4 | kashi
# Processing Record 5 of Set 4 | kuytun
# Processing Record 6 of Set 4 | zhigansk
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | north bend
# Processing Record 10 of Set 4 | santa eulalia del rio
# Processing Record 11 of Set 4 | leninogorsk
# Processing Record 12 of Set 4 | beira
# Processing Record 13 of Set 4 | severnoye
# Processing Record 14 of Set 4 | nouadhibou
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | san cristobal
# dubenskiy not found. Proceeding to the next city...
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | fougamou
# Processing Record 19 of Set 4 | at-bashi
# Processing Record 20 of Set 4 | tirumullaivasal
# Processing Record 21 of Set 4 | kodinar
# tasbuget not found. Proceeding to the next city...
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | adrar
# Processing Record 24 of Set 4 | dubna
# Processing Record 25 of Set 4 | ahipara
# Processing Record 26 of Set 4 | americo brasiliense
# Processing Record 27 of Set 4 | barentu
# warqla not found. Proceeding to the next city...
# Processing Record 28 of Set 4 | husavik
# Processing Record 29 of Set 4 | de-kastri
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | kibala
# Processing Record 32 of Set 4 | aksay
# karakendzha not found. Proceeding to the next city...
# Processing Record 33 of Set 4 | souillac
# Processing Record 34 of Set 4 | udimskiy
# Processing Record 35 of Set 4 | teya
# Processing Record 36 of Set 4 | nantucket
# Processing Record 37 of Set 4 | pundaguitan
# Processing Record 38 of Set 4 | shenyang
# Processing Record 39 of Set 4 | wajir
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | lagos
# marcona not found. Proceeding to the next city...
# Processing Record 42 of Set 4 | asau
# Processing Record 43 of Set 4 | solano
# Processing Record 44 of Set 4 | khatanga
# Processing Record 45 of Set 4 | luderitz
# los lunas not found. Proceeding to the next city...
# Processing Record 46 of Set 4 | tasiilaq
# zhanatas not found. Proceeding to the next city...
# Processing Record 47 of Set 4 | kankaanpaa
# belushya guba not found. Proceeding to the next city...
# artyk not found. Proceeding to the next city...
# Processing Record 48 of Set 4 | illapel
# skagastrond not found. Proceeding to the next city...
# Processing Record 49 of Set 4 | hilo
# Processing Record 50 of Set 4 | jinji
# Processing Record 1 of Set 5 | mys shmidta
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | marienburg
# Processing Record 4 of Set 5 | cairns
# Processing Record 5 of Set 5 | mount isa
# Processing Record 6 of Set 5 | kishtwar
# Processing Record 7 of Set 5 | marovoay
# Processing Record 8 of Set 5 | cockburn town
# Processing Record 9 of Set 5 | tuensang
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | tazovskiy
# Processing Record 12 of Set 5 | sambava
# Processing Record 13 of Set 5 | teguise
# Processing Record 14 of Set 5 | jalu
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | talnakh
# Processing Record 17 of Set 5 | labuhan
# Processing Record 18 of Set 5 | vestmannaeyjar
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | elizabeth city
# Processing Record 21 of Set 5 | raudeberg
# Processing Record 22 of Set 5 | kadoma
# mayor pablo lagerenza not found. Proceeding to the next city...
# Processing Record 23 of Set 5 | tecoanapa
# Processing Record 24 of Set 5 | coihaique
# Processing Record 25 of Set 5 | odweyne
# Processing Record 26 of Set 5 | sawtell
# Processing Record 27 of Set 5 | alofi
# Processing Record 28 of Set 5 | sisimiut
# Processing Record 29 of Set 5 | matara
# Processing Record 30 of Set 5 | beloha
# Processing Record 31 of Set 5 | marawi
# mrirt not found. Proceeding to the next city...
# Processing Record 32 of Set 5 | sorland
# ambodifototra not found. Proceeding to the next city...
# Processing Record 33 of Set 5 | emerald
# Processing Record 34 of Set 5 | prieska
# Processing Record 35 of Set 5 | fairbanks
# Processing Record 36 of Set 5 | ust-maya
# Processing Record 37 of Set 5 | manokwari
# la orilla not found. Proceeding to the next city...
# Processing Record 38 of Set 5 | pitimbu
# Processing Record 39 of Set 5 | tiznit
# Processing Record 40 of Set 5 | kiunga
# Processing Record 41 of Set 5 | ibra
# Processing Record 42 of Set 5 | vila franca do campo
# Processing Record 43 of Set 5 | qaanaaq
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | arlit
# Processing Record 46 of Set 5 | fort wellington
# Processing Record 47 of Set 5 | baruun-urt
# bolungarvik not found. Proceeding to the next city...
# Processing Record 48 of Set 5 | rockport
# Processing Record 49 of Set 5 | dingle
# saleaula not found. Proceeding to the next city...
# Processing Record 50 of Set 5 | kodiak
# Processing Record 1 of Set 6 | wladyslawowo
# amderma not found. Proceeding to the next city...
# Processing Record 2 of Set 6 | aitape
# Processing Record 3 of Set 6 | launceston
# Processing Record 4 of Set 6 | silver city
# Processing Record 5 of Set 6 | qaqortoq
# te anau not found. Proceeding to the next city...
# Processing Record 6 of Set 6 | consolacion del sur
# Processing Record 7 of Set 6 | makakilo city
# Processing Record 8 of Set 6 | hasaki
# westpunt not found. Proceeding to the next city...
# Processing Record 9 of Set 6 | aksu
# illoqqortoormiut not found. Proceeding to the next city...
# Processing Record 10 of Set 6 | ladario
# Processing Record 11 of Set 6 | terrasini
# Processing Record 12 of Set 6 | georgetown
# Processing Record 13 of Set 6 | hirara
# Processing Record 14 of Set 6 | tulum
# Processing Record 15 of Set 6 | stromness
# Processing Record 16 of Set 6 | sidney
# Processing Record 17 of Set 6 | nicoya
# Processing Record 18 of Set 6 | green river
# bargal not found. Proceeding to the next city...
# Processing Record 19 of Set 6 | cabo san lucas
# Processing Record 20 of Set 6 | capela
# Processing Record 21 of Set 6 | meulaboh
# Processing Record 22 of Set 6 | whitehorse
# Processing Record 23 of Set 6 | yueyang
# Processing Record 24 of Set 6 | santa barbara
# Processing Record 25 of Set 6 | pio xii
# Processing Record 26 of Set 6 | axim
# Processing Record 27 of Set 6 | carmen
# mocambique not found. Proceeding to the next city...
# Processing Record 28 of Set 6 | haileybury
# Processing Record 29 of Set 6 | benton harbor
# Processing Record 30 of Set 6 | igarka
# saint anthony not found. Proceeding to the next city...
# Processing Record 31 of Set 6 | castanos
# Processing Record 32 of Set 6 | zemio
# Processing Record 33 of Set 6 | meridian
# Processing Record 34 of Set 6 | fort morgan
# Processing Record 35 of Set 6 | betsiamites
# Processing Record 36 of Set 6 | itarema
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | liverpool
# Processing Record 39 of Set 6 | tiksi
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | chicama
# Processing Record 42 of Set 6 | jvari
# Processing Record 43 of Set 6 | dongargaon
# los llanos de aridane not found. Proceeding to the next city...
# Processing Record 44 of Set 6 | lakes entrance
# vaitupu not found. Proceeding to the next city...
# Processing Record 45 of Set 6 | mamaku
# Processing Record 46 of Set 6 | bambous virieux
# thunder bay not found. Proceeding to the next city...
# Processing Record 47 of Set 6 | waitati
# Processing Record 48 of Set 6 | eureka
# Processing Record 49 of Set 6 | nome
# Processing Record 50 of Set 6 | sao miguel
# Processing Record 1 of Set 7 | aykhal
# Processing Record 2 of Set 7 | faanui
# Processing Record 3 of Set 7 | ust-tsilma
# Processing Record 4 of Set 7 | kiama
# Processing Record 5 of Set 7 | south venice
# Processing Record 6 of Set 7 | caravelas
# Processing Record 7 of Set 7 | norilsk
# Processing Record 8 of Set 7 | rawson
# Processing Record 9 of Set 7 | vagay
# nanded not found. Proceeding to the next city...
# Processing Record 10 of Set 7 | beatrice
# Processing Record 11 of Set 7 | ullal
# Processing Record 12 of Set 7 | manaure
# Processing Record 13 of Set 7 | alyangula
# Processing Record 14 of Set 7 | berberati
# Processing Record 15 of Set 7 | deputatskiy
# karaul not found. Proceeding to the next city...
# Processing Record 16 of Set 7 | muroto
# Processing Record 17 of Set 7 | asyut
# Processing Record 18 of Set 7 | ilulissat
# yuzhno-yeniseyskiy not found. Proceeding to the next city...
# Processing Record 19 of Set 7 | yellandu
# Processing Record 20 of Set 7 | omboue
# Processing Record 21 of Set 7 | harper
# Processing Record 22 of Set 7 | lahat
# Processing Record 23 of Set 7 | ulladulla
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | sulmona
# Processing Record 26 of Set 7 | carnarvon
# Processing Record 27 of Set 7 | olafsvik
# Processing Record 28 of Set 7 | nadadores
# Processing Record 29 of Set 7 | udankudi
# Processing Record 30 of Set 7 | poum
# Processing Record 31 of Set 7 | baykit
# Processing Record 32 of Set 7 | riyadh
# Processing Record 33 of Set 7 | panzhihua
# Processing Record 34 of Set 7 | dauphin
# Processing Record 35 of Set 7 | klaksvik
# Processing Record 36 of Set 7 | karratha
# Processing Record 37 of Set 7 | tessalit
# khonuu not found. Proceeding to the next city...
# Processing Record 38 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 7 | vilyuysk
# Processing Record 40 of Set 7 | darhan
# Processing Record 41 of Set 7 | killybegs
# Processing Record 42 of Set 7 | mehamn
# Processing Record 43 of Set 7 | torbay
# Processing Record 44 of Set 7 | vanimo
# Processing Record 45 of Set 7 | abeche
# Processing Record 46 of Set 7 | sartana
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | prince rupert
# Processing Record 49 of Set 7 | mirpur sakro
# barao de melgaco not found. Proceeding to the next city...
# Processing Record 50 of Set 7 | dudinka
# Processing Record 1 of Set 8 | owando
# Processing Record 2 of Set 8 | labytnangi
# Processing Record 3 of Set 8 | samana
# Processing Record 4 of Set 8 | vallenar
# Processing Record 5 of Set 8 | sungaipenuh
# Processing Record 6 of Set 8 | yuli
# Processing Record 7 of Set 8 | palmerston
# Processing Record 8 of Set 8 | byron bay
# kamenskoye not found. Proceeding to the next city...
# Processing Record 9 of Set 8 | butte
# Processing Record 10 of Set 8 | chongwe
# Processing Record 11 of Set 8 | ekhabi
# Processing Record 12 of Set 8 | collie
# Processing Record 13 of Set 8 | noshiro
# Processing Record 14 of Set 8 | luanda
# Processing Record 15 of Set 8 | sur
# Processing Record 16 of Set 8 | hofn
# Processing Record 17 of Set 8 | kongsberg
# Processing Record 18 of Set 8 | camara de lobos
# tumannyy not found. Proceeding to the next city...
# palkaka not found. Proceeding to the next city...
# Processing Record 19 of Set 8 | bourail
# broken hill not found. Proceeding to the next city...
# Processing Record 20 of Set 8 | selenginsk
# Processing Record 21 of Set 8 | kroya
# Processing Record 22 of Set 8 | izhma
# Processing Record 23 of Set 8 | palasa
# Processing Record 24 of Set 8 | port-cartier
# Processing Record 25 of Set 8 | raga
# Processing Record 26 of Set 8 | kharp
# Processing Record 27 of Set 8 | chulman
# Processing Record 28 of Set 8 | cobija
# Processing Record 29 of Set 8 | mogadishu
# Processing Record 30 of Set 8 | awbari
# Processing Record 31 of Set 8 | belyy yar
# Processing Record 32 of Set 8 | sangar
# Processing Record 33 of Set 8 | tomatlan
# Processing Record 34 of Set 8 | northam
# Processing Record 35 of Set 8 | vanavara
# Processing Record 36 of Set 8 | rehoboth
# mutsamudu not found. Proceeding to the next city...
# Processing Record 37 of Set 8 | lakatoro
# henties bay not found. Proceeding to the next city...
# tidore not found. Proceeding to the next city...
# Processing Record 38 of Set 8 | morondava
# Processing Record 39 of Set 8 | burgeo
# Processing Record 40 of Set 8 | sinnamary
# Processing Record 41 of Set 8 | albanel
# Processing Record 42 of Set 8 | eyl
# Processing Record 43 of Set 8 | grand gaube
# Processing Record 44 of Set 8 | oksfjord
# Processing Record 45 of Set 8 | verkh-usugli
# paradwip not found. Proceeding to the next city...
# Processing Record 46 of Set 8 | stornoway
# tungkang not found. Proceeding to the next city...
# Processing Record 47 of Set 8 | leningradskiy
# Processing Record 48 of Set 8 | clonakilty
# Processing Record 49 of Set 8 | peniche
# Processing Record 50 of Set 8 | rocha
# Processing Record 1 of Set 9 | bom jesus da lapa
# Processing Record 2 of Set 9 | padang
# Processing Record 3 of Set 9 | port blair
# lolua not found. Proceeding to the next city...
# Processing Record 4 of Set 9 | ayan
# Processing Record 5 of Set 9 | north highlands
# Processing Record 6 of Set 9 | babati
# Processing Record 7 of Set 9 | weston
# tsihombe not found. Proceeding to the next city...
# Processing Record 8 of Set 9 | warrnambool
# Processing Record 9 of Set 9 | gumdag
# Processing Record 10 of Set 9 | nanortalik
# louisbourg not found. Proceeding to the next city...
# Processing Record 11 of Set 9 | berlevag
# Processing Record 12 of Set 9 | hostotipaquillo
# Processing Record 13 of Set 9 | dunedin
# Processing Record 14 of Set 9 | bathsheba
# Processing Record 15 of Set 9 | malartic
# Processing Record 16 of Set 9 | acapulco
# Processing Record 17 of Set 9 | jalgaon
# Processing Record 18 of Set 9 | gijon
# la rioja not found. Proceeding to the next city...
# Processing Record 19 of Set 9 | alekseyevka
# Processing Record 20 of Set 9 | thinadhoo
# shakhrinau not found. Proceeding to the next city...
# Processing Record 21 of Set 9 | bardiyah
# Processing Record 22 of Set 9 | mariestad
# Processing Record 23 of Set 9 | oneonta
# Processing Record 24 of Set 9 | touros
# Processing Record 25 of Set 9 | port augusta
# Processing Record 26 of Set 9 | bungu
# Processing Record 27 of Set 9 | ponta do sol
# Processing Record 28 of Set 9 | rostock
# the valley not found. Proceeding to the next city...
# Processing Record 29 of Set 9 | kintampo
# Processing Record 30 of Set 9 | martapura
# Processing Record 31 of Set 9 | fare
# Processing Record 32 of Set 9 | clyde river
# Processing Record 33 of Set 9 | maceio
# Processing Record 34 of Set 9 | praia da vitoria
# Processing Record 35 of Set 9 | alice town
# Processing Record 36 of Set 9 | anloga
# Processing Record 37 of Set 9 | plettenberg bay
# Processing Record 38 of Set 9 | lukovetskiy
# Processing Record 39 of Set 9 | yerbogachen
# Processing Record 40 of Set 9 | oistins
# Processing Record 41 of Set 9 | san vicente
# Processing Record 42 of Set 9 | kavaratti
# Processing Record 43 of Set 9 | kamaishi
# palabuhanratu not found. Proceeding to the next city...
# Processing Record 44 of Set 9 | korla
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | gizo
# Processing Record 47 of Set 9 | bandarbeyla
# Processing Record 48 of Set 9 | hambantota
# samusu not found. Proceeding to the next city...
# Processing Record 49 of Set 9 | trelew
# Processing Record 50 of Set 9 | bundaberg
# Processing Record 1 of Set 10 | aquiraz
# Processing Record 2 of Set 10 | itaituba
# Processing Record 3 of Set 10 | atkarsk
# Processing Record 4 of Set 10 | cao bang
# Processing Record 5 of Set 10 | semnan
# Processing Record 6 of Set 10 | jinxiang
# balykshi not found. Proceeding to the next city...
# Processing Record 7 of Set 10 | ixtapa
# Processing Record 8 of Set 10 | tahta
# Processing Record 9 of Set 10 | araraquara
# Processing Record 10 of Set 10 | portland
# Processing Record 11 of Set 10 | maragogi
# Processing Record 12 of Set 10 | mahabad
# taburi not found. Proceeding to the next city...
# Processing Record 13 of Set 10 | galle
# Processing Record 14 of Set 10 | barcelos
# Processing Record 15 of Set 10 | salalah
# Processing Record 16 of Set 10 | bambanglipuro
# Processing Record 17 of Set 10 | pervomayskoye
# saint peter not found. Proceeding to the next city...
# Processing Record 18 of Set 10 | farafangana
# Processing Record 19 of Set 10 | pacific grove
# Processing Record 20 of Set 10 | broome
# Processing Record 21 of Set 10 | old road
# Processing Record 22 of Set 10 | komadi
# Processing Record 23 of Set 10 | akersberga
# Processing Record 24 of Set 10 | pangnirtung
# Processing Record 25 of Set 10 | asosa
# Processing Record 26 of Set 10 | ucluelet
# Processing Record 27 of Set 10 | okato
# skalistyy not found. Proceeding to the next city...
# Processing Record 28 of Set 10 | kovdor
# Processing Record 29 of Set 10 | ushtobe
# Processing Record 30 of Set 10 | leh
# Processing Record 31 of Set 10 | palu
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | dongsheng
# Processing Record 34 of Set 10 | makaha
# Processing Record 35 of Set 10 | mitsamiouli
# Processing Record 36 of Set 10 | bowen
# Processing Record 37 of Set 10 | narsaq
# Processing Record 38 of Set 10 | las palmas
# Processing Record 39 of Set 10 | tabou
# Processing Record 40 of Set 10 | beringovskiy
# galiwinku not found. Proceeding to the next city...
# Processing Record 41 of Set 10 | pochutla
# Processing Record 42 of Set 10 | skibbereen
# Processing Record 43 of Set 10 | wageningen
# Processing Record 44 of Set 10 | rongcheng
# Processing Record 45 of Set 10 | puerto del rosario
# Processing Record 46 of Set 10 | chunskiy
# Processing Record 47 of Set 10 | ostrovnoy
# Processing Record 48 of Set 10 | sterling
# Processing Record 49 of Set 10 | yeniseysk
# Processing Record 50 of Set 10 | verkhnyaya inta
# Processing Record 1 of Set 11 | san matias
# Processing Record 2 of Set 11 | dieppe
# Processing Record 3 of Set 11 | yenagoa
# Processing Record 4 of Set 11 | san jeronimo
# Processing Record 5 of Set 11 | belaya gora
# Processing Record 6 of Set 11 | greensburg
# Processing Record 7 of Set 11 | guadalupe y calvo
# Processing Record 8 of Set 11 | pedernales
# Processing Record 9 of Set 11 | bhag
# Processing Record 10 of Set 11 | ipixuna
# Processing Record 11 of Set 11 | nuuk
# Processing Record 12 of Set 11 | siniscola
# Processing Record 13 of Set 11 | surt
# Processing Record 14 of Set 11 | jizan
# tra vinh not found. Proceeding to the next city...
# Processing Record 15 of Set 11 | bocaiuva
# Processing Record 16 of Set 11 | bulancak
# Processing Record 17 of Set 11 | urumqi
# Processing Record 18 of Set 11 | guerrero negro
# Processing Record 19 of Set 11 | puerto maldonado
# general roca not found. Proceeding to the next city...
# Processing Record 20 of Set 11 | loiza
# Processing Record 21 of Set 11 | brattleboro
# Processing Record 22 of Set 11 | dabakala
# Processing Record 23 of Set 11 | wiarton
# Processing Record 24 of Set 11 | alice springs
# Processing Record 25 of Set 11 | leshukonskoye
# Processing Record 26 of Set 11 | middelkerke
# Processing Record 27 of Set 11 | surok
# Processing Record 28 of Set 11 | togur
# Processing Record 29 of Set 11 | kahului
# Processing Record 30 of Set 11 | tabas
# Processing Record 31 of Set 11 | digboi
# lyubeshiv not found. Proceeding to the next city...
# Processing Record 32 of Set 11 | okha
# Processing Record 33 of Set 11 | sobolevo
# Processing Record 34 of Set 11 | alekseyevsk
# Processing Record 35 of Set 11 | lokoja
# halalo not found. Proceeding to the next city...
# Processing Record 36 of Set 11 | yushu
# Processing Record 37 of Set 11 | cap malheureux
# Processing Record 38 of Set 11 | tevriz
# Processing Record 39 of Set 11 | blahodatne
# Processing Record 40 of Set 11 | rio tuba
# Processing Record 41 of Set 11 | gornopravdinsk
# Processing Record 42 of Set 11 | bella union
# Processing Record 43 of Set 11 | pemangkat
# Processing Record 44 of Set 11 | srednekolymsk
# Processing Record 45 of Set 11 | benguela
# Processing Record 46 of Set 11 | medea
# Processing Record 47 of Set 11 | youkounkoun
# Processing Record 48 of Set 11 | bani walid
# Processing Record 49 of Set 11 | woodward
# Processing Record 50 of Set 11 | itoman
# Processing Record 1 of Set 12 | puerto baquerizo moreno
# Processing Record 2 of Set 12 | saint-georges
# Processing Record 3 of Set 12 | coihueco
# Processing Record 4 of Set 12 | gorontalo
# Processing Record 5 of Set 12 | camana
# Processing Record 6 of Set 12 | bonavista
# Processing Record 7 of Set 12 | komsomolskiy
# Processing Record 8 of Set 12 | bensonville
# Processing Record 9 of Set 12 | buraydah
# Processing Record 10 of Set 12 | carroll
# Processing Record 11 of Set 12 | puerto varas
# Processing Record 12 of Set 12 | sakaiminato
# Processing Record 13 of Set 12 | richards bay
# Processing Record 14 of Set 12 | san jose
# Processing Record 15 of Set 12 | yuanping
# Processing Record 16 of Set 12 | hay river
# Processing Record 17 of Set 12 | valle nacional
# Processing Record 18 of Set 12 | champerico
# Processing Record 19 of Set 12 | honningsvag
# Processing Record 20 of Set 12 | gat
# Processing Record 21 of Set 12 | nuevitas
# Processing Record 22 of Set 12 | soyo
# Processing Record 23 of Set 12 | qingdao
# Processing Record 24 of Set 12 | lamu
# Processing Record 25 of Set 12 | porto novo
# Processing Record 26 of Set 12 | teknaf
# Processing Record 27 of Set 12 | alihe
# Processing Record 28 of Set 12 | sakakah
# Processing Record 29 of Set 12 | tagusao
# Processing Record 30 of Set 12 | kanniyakumari
# Processing Record 31 of Set 12 | yerkoy
# Processing Record 32 of Set 12 | aosta
# Processing Record 33 of Set 12 | esil
# Processing Record 34 of Set 12 | mandera
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# The data generated from the API calls will be compiled into a new Data Fram
weather_data_frame = pd.DataFrame({
    'City':updated_city_list,
    'Lattitude':lattitude,
    'Longitude': longitude,
    'Max Temp': max_temp,
    'Humidity': humidity,
    'Cloudiness': cloudinesses,
    'Wind Speed': wind,
    'Country': country_list,
    'Date':dates
})

## Exporting the new DataFrame into a csv file
weather_data_frame.to_csv('..\Output_Data\Weather_Data_Collection.csv')

## Displaying the DataFrame
print(f'{weather_data_frame.shape[0]} cities, along with their weather information, have been collated\n')
weather_data_frame.head()
# Out:
# 584 cities, along with their weather information, have been collated
#            City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0    butaritari       3.07     172.79     27.30        79           0
# 1  puerto ayora      36.59      -6.23     15.00        93           3
# 2          auki      -8.77     160.70     27.89        77          31
# 3      cherskiy      68.75     161.30      6.86        61          99
# 4        noumea     -22.28     166.46     21.00        88          90
#
#    Wind Speed Country        Date
# 0        6.66      KI  1601273230
# 1        2.60      ES  1601273231
# 2        2.76      SB  1601273232
# 3        2.85      RU  1601273232
# 4        6.20      NC  1601273233

# %%
## Summary Statistics 
weather_data_frame.describe()
# Out:
#         Lattitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean    23.327055   22.372363   18.561455   72.467466   51.976027    3.697055
# std     31.618770   85.242466    9.031060   20.722018   36.844294    2.598762
# min    -54.800000 -175.200000  -11.200000    3.000000    0.000000    0.030000
# 25%     -1.307500  -48.335000   11.237500   60.000000   13.000000    1.740000
# 50%     27.835000   22.385000   20.390000   78.000000   56.000000    3.100000
# 75%     49.742500   91.165000   26.242500   88.000000   90.000000    5.100000
# max     78.220000  179.320000   37.900000  100.000000  100.000000   19.910000
#
#                Date
# count  5.840000e+02
# mean   1.601273e+09
# std    1.479643e+02
# min    1.601273e+09
# 25%    1.601273e+09
# 50%    1.601273e+09
# 75%    1.601274e+09
# max    1.601274e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking to see if there are cities with humidities over 100
weather_data_frame[weather_data_frame['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lattitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames_Over100 = weather_data_frame[weather_data_frame['Humidity']>100].index

# %%
if (len(indexNames_Over100)) > 0:
    print(f'There are cities with humidity over 100')
else:
    print(f'There are no cities with humidity over 100')
# Out:
# There are no cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data_frame.drop(indexNames_Over100, inplace=False)

# %%
print(f'There are {clean_city_data.shape[0]} cities to be assessed\n')
clean_city_data.head()
# Out:
# There are 584 cities to be assessed
#            City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0    butaritari       3.07     172.79     27.30        79           0
# 1  puerto ayora      36.59      -6.23     15.00        93           3
# 2          auki      -8.77     160.70     27.89        77          31
# 3      cherskiy      68.75     161.30      6.86        61          99
# 4        noumea     -22.28     166.46     21.00        88          90
#
#    Wind Speed Country        Date
# 0        6.66      KI  1601273230
# 1        2.60      ES  1601273231
# 2        2.76      SB  1601273232
# 3        2.85      RU  1601273232
# 4        6.20      NC  1601273233

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# A scatter plot will be used in order to determine the relationship between temperature and lattitudes
x_lattitude = clean_city_data['Lattitude']
y_temperature = clean_city_data['Max Temp']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Temperature',fontsize=15)
ax1.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_temperature, edgecolors='black', c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Temperature.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# We will use the previous x_label and create a new Y label pertaining to humidity
y_humidity = clean_city_data['Humidity']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Humidity',fontsize=15)
ax1.set_ylabel('Humidity', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_humidity, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# We will set a new y_ variable pertaining to Cloudiness
y_cloudiness = clean_city_data['Cloudiness']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Cloudiness',fontsize=15)
ax1.set_ylabel('Cloudiness(%)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_cloudiness, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# We wil set a new y_ variable pertaining to Wind Speed
y_windspeed = clean_city_data['Wind Speed']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Wind Speed',fontsize=15)
ax1.set_ylabel('Wind Speed (mph)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_windspeed, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_WindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Northern Hemisphere Latitudes vs Max Temperature

# %%
# All cities within the Northern Hemisphere will be in the lattitude range of 0(equator) to 90. 
# We will need to filter the dataframe to contain cities within the northern hemisphere (nh)

northern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']>=0]

x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_max_temp = northern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_max_temp)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.7518590452427847

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# All cities within the Southern Hemisphere will be in the lattitude range of 0(equator) to -90. 
# We will need to filter the dataframe to contain cities within the southern hemisphere (sh)

southern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']<=0]

x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_max_temp = southern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_max_temp)

# Linear Regression Label
line_eq_sh = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit_sh = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit_sh,'black')
ax2.scatter(x_sh_latitude,y_sh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.5878904520888241

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_humidity = northern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.03083305907823263

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_humidity = southern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.010711809183926817

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_cloudiness = northern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.02619266388472969

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_cloudiness = southern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.04833495202754337

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_windspeed = northern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Windspeed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Windspeed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.027371426960552964

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_windspeed = southern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Wind Speed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Wind Speed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.12643355872962084

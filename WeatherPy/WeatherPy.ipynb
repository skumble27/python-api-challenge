# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing the relevant modules for weather analyses
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import scipy.stats as st

# Importing the API Key
from api_keys import weather_api_key

# Setting Unit of Measurement for Temperature
celsius ='metric'

# Setting up the query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={celsius}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# Preparing lists to store random lattitude and longitude coordinates
random_lat_long = []
city_names = []

# Creting Random Lattitudes
ran_lattitude = np.random.uniform(low=-90.000, high=90.000, size=1500)
ran_longitude = np.random.uniform(low=-180.000, high=180.000, size=1500)
random_lat_long = zip(ran_lattitude,ran_longitude)

# Assigning the nearest city to the coordinates
for lat_long in random_lat_long:
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name

    # Ensuring only unique city names are added
    if city in city_names:
        next
    else:
        city_names.append(city)
print(f'The number of cities added are {len(city_names)}')
# Out:
# The number of cities added are 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
updated_city_list = []
cloudinesses = []
dates = []
humidity = []
lattitude = []
longitude = []
max_temp = []
wind = []
country_list = []

# set initial count quantities for organization
record_number = 0
record_sets = 1

# loops for creating dataframe columns
print(f'Data Retreival commencing\n---------------------\n')
for city in city_names:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lattitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        if record_number > 49:
            record_number = 1
            record_sets += 1
            updated_city_list.append(city)
        else:
            record_number += 1
            updated_city_list.append(city)
        print(f"Processing Record {record_number} of Set {record_sets} ---> {city}")
    except Exception:
        print(f"{city} not found. Proceeding to the next city...")
print("*******************************")
print("Data Retrieval Complete\n*******************************")
# Out:
# Data Retreival commencing
# ---------------------
#
# Processing Record 1 of Set 1 ---> shitanjing
# Processing Record 2 of Set 1 ---> yerbogachen
# Processing Record 3 of Set 1 ---> chengam
# Processing Record 4 of Set 1 ---> clyde river
# Processing Record 5 of Set 1 ---> nome
# Processing Record 6 of Set 1 ---> punta arenas
# Processing Record 7 of Set 1 ---> avarua
# belushya guba not found. Proceeding to the next city...
# zhanatas not found. Proceeding to the next city...
# Processing Record 8 of Set 1 ---> haines junction
# Processing Record 9 of Set 1 ---> cidreira
# Processing Record 10 of Set 1 ---> tamandare
# Processing Record 11 of Set 1 ---> bluff
# Processing Record 12 of Set 1 ---> hermanus
# Processing Record 13 of Set 1 ---> kodiak
# Processing Record 14 of Set 1 ---> jamestown
# Processing Record 15 of Set 1 ---> yeppoon
# ahumada not found. Proceeding to the next city...
# Processing Record 16 of Set 1 ---> qaanaaq
# Processing Record 17 of Set 1 ---> codrington
# rabo de peixe not found. Proceeding to the next city...
# Processing Record 18 of Set 1 ---> mataura
# Processing Record 19 of Set 1 ---> panguna
# Processing Record 20 of Set 1 ---> san patricio
# Processing Record 21 of Set 1 ---> maniitsoq
# Processing Record 22 of Set 1 ---> castro
# Processing Record 23 of Set 1 ---> carnarvon
# Processing Record 24 of Set 1 ---> korla
# Processing Record 25 of Set 1 ---> krasnyy oktyabr
# Processing Record 26 of Set 1 ---> talnakh
# Processing Record 27 of Set 1 ---> leningradskiy
# Processing Record 28 of Set 1 ---> toccoa
# Processing Record 29 of Set 1 ---> nabire
# Processing Record 30 of Set 1 ---> dukat
# Processing Record 31 of Set 1 ---> santiago del estero
# Processing Record 32 of Set 1 ---> palaikastron
# taolanaro not found. Proceeding to the next city...
# Processing Record 33 of Set 1 ---> beloha
# Processing Record 34 of Set 1 ---> arraial do cabo
# Processing Record 35 of Set 1 ---> diapaga
# Processing Record 36 of Set 1 ---> chokurdakh
# Processing Record 37 of Set 1 ---> bredasdorp
# sataua not found. Proceeding to the next city...
# illoqqortoormiut not found. Proceeding to the next city...
# Processing Record 38 of Set 1 ---> busselton
# Processing Record 39 of Set 1 ---> cape town
# Processing Record 40 of Set 1 ---> vuktyl
# Processing Record 41 of Set 1 ---> new norfolk
# Processing Record 42 of Set 1 ---> kaitangata
# urozhayne not found. Proceeding to the next city...
# Processing Record 43 of Set 1 ---> akyab
# Processing Record 44 of Set 1 ---> gat
# Processing Record 45 of Set 1 ---> colwyn bay
# Processing Record 46 of Set 1 ---> atuona
# Processing Record 47 of Set 1 ---> katobu
# Processing Record 48 of Set 1 ---> luderitz
# Processing Record 49 of Set 1 ---> qasigiannguit
# Processing Record 50 of Set 1 ---> san vicente
# Processing Record 1 of Set 2 ---> bambous virieux
# Processing Record 2 of Set 2 ---> barrow
# Processing Record 3 of Set 2 ---> gold coast
# Processing Record 4 of Set 2 ---> mount gambier
# Processing Record 5 of Set 2 ---> biltine
# Processing Record 6 of Set 2 ---> qui nhon
# Processing Record 7 of Set 2 ---> padang
# Processing Record 8 of Set 2 ---> portland
# Processing Record 9 of Set 2 ---> eyl
# Processing Record 10 of Set 2 ---> ribeira grande
# Processing Record 11 of Set 2 ---> ushuaia
# Processing Record 12 of Set 2 ---> sioux lookout
# Processing Record 13 of Set 2 ---> soyo
# Processing Record 14 of Set 2 ---> yaan
# Processing Record 15 of Set 2 ---> norman wells
# Processing Record 16 of Set 2 ---> upernavik
# Processing Record 17 of Set 2 ---> turayf
# Processing Record 18 of Set 2 ---> yellowknife
# Processing Record 19 of Set 2 ---> plastun
# Processing Record 20 of Set 2 ---> longyearbyen
# Processing Record 21 of Set 2 ---> beringovskiy
# Processing Record 22 of Set 2 ---> vaini
# Processing Record 23 of Set 2 ---> albany
# Processing Record 24 of Set 2 ---> kisangani
# Processing Record 25 of Set 2 ---> nikolskoye
# Processing Record 26 of Set 2 ---> kasongo
# Processing Record 27 of Set 2 ---> puerto ayora
# Processing Record 28 of Set 2 ---> maragogi
# one hundred mile house not found. Proceeding to the next city...
# Processing Record 29 of Set 2 ---> hohhot
# Processing Record 30 of Set 2 ---> severo-kurilsk
# Processing Record 31 of Set 2 ---> seoul
# Processing Record 32 of Set 2 ---> bimbo
# Processing Record 33 of Set 2 ---> rikitea
# Processing Record 34 of Set 2 ---> kapaa
# Processing Record 35 of Set 2 ---> victoria
# Processing Record 36 of Set 2 ---> hilo
# Processing Record 37 of Set 2 ---> dudinka
# Processing Record 38 of Set 2 ---> hobart
# jabiru not found. Proceeding to the next city...
# Processing Record 39 of Set 2 ---> saint-philippe
# Processing Record 40 of Set 2 ---> ponta do sol
# Processing Record 41 of Set 2 ---> esperance
# ust-kamchatsk not found. Proceeding to the next city...
# Processing Record 42 of Set 2 ---> progreso
# Processing Record 43 of Set 2 ---> porto novo
# Processing Record 44 of Set 2 ---> mar del plata
# Processing Record 45 of Set 2 ---> alofi
# Processing Record 46 of Set 2 ---> husavik
# Processing Record 47 of Set 2 ---> narsaq
# Processing Record 48 of Set 2 ---> chadiza
# Processing Record 49 of Set 2 ---> dikson
# Processing Record 50 of Set 2 ---> khudumelapye
# Processing Record 1 of Set 3 ---> sao filipe
# Processing Record 2 of Set 3 ---> barnstaple
# Processing Record 3 of Set 3 ---> srednekolymsk
# Processing Record 4 of Set 3 ---> kapit
# Processing Record 5 of Set 3 ---> port elizabeth
# Processing Record 6 of Set 3 ---> east london
# Processing Record 7 of Set 3 ---> aksha
# Processing Record 8 of Set 3 ---> tiksi
# Processing Record 9 of Set 3 ---> bratsk
# Processing Record 10 of Set 3 ---> fortuna
# Processing Record 11 of Set 3 ---> tura
# la asuncion not found. Proceeding to the next city...
# Processing Record 12 of Set 3 ---> kidal
# Processing Record 13 of Set 3 ---> cockburn harbour
# Processing Record 14 of Set 3 ---> butaritari
# Processing Record 15 of Set 3 ---> provideniya
# Processing Record 16 of Set 3 ---> margate
# Processing Record 17 of Set 3 ---> bengkulu
# Processing Record 18 of Set 3 ---> marakkanam
# Processing Record 19 of Set 3 ---> buraydah
# skagastrond not found. Proceeding to the next city...
# tsihombe not found. Proceeding to the next city...
# Processing Record 20 of Set 3 ---> ilulissat
# Processing Record 21 of Set 3 ---> mindelo
# tarudant not found. Proceeding to the next city...
# Processing Record 22 of Set 3 ---> cherskiy
# Processing Record 23 of Set 3 ---> vostok
# Processing Record 24 of Set 3 ---> tuktoyaktuk
# Processing Record 25 of Set 3 ---> mount isa
# attawapiskat not found. Proceeding to the next city...
# Processing Record 26 of Set 3 ---> ponta delgada
# Processing Record 27 of Set 3 ---> tagusao
# Processing Record 28 of Set 3 ---> khatanga
# Processing Record 29 of Set 3 ---> qaqortoq
# Processing Record 30 of Set 3 ---> isla mujeres
# Processing Record 31 of Set 3 ---> sao joao da barra
# Processing Record 32 of Set 3 ---> hasaki
# Processing Record 33 of Set 3 ---> gannan
# Processing Record 34 of Set 3 ---> saskylakh
# batemans bay not found. Proceeding to the next city...
# Processing Record 35 of Set 3 ---> rongcheng
# Processing Record 36 of Set 3 ---> khandbari
# Processing Record 37 of Set 3 ---> isangel
# Processing Record 38 of Set 3 ---> kudahuvadhoo
# Processing Record 39 of Set 3 ---> lusambo
# Processing Record 40 of Set 3 ---> morondava
# kamenskoye not found. Proceeding to the next city...
# Processing Record 41 of Set 3 ---> marovoay
# Processing Record 42 of Set 3 ---> beira
# Processing Record 43 of Set 3 ---> guerrero negro
# la romana not found. Proceeding to the next city...
# Processing Record 44 of Set 3 ---> chuy
# Processing Record 45 of Set 3 ---> huarmey
# Processing Record 46 of Set 3 ---> lahij
# Processing Record 47 of Set 3 ---> vao
# Processing Record 48 of Set 3 ---> ambilobe
# Processing Record 49 of Set 3 ---> bushehr
# Processing Record 50 of Set 3 ---> gorin
# vaitupu not found. Proceeding to the next city...
# Processing Record 1 of Set 4 ---> grand river south east
# Processing Record 2 of Set 4 ---> lebu
# Processing Record 3 of Set 4 ---> lugoba
# Processing Record 4 of Set 4 ---> komsomolskiy
# Processing Record 5 of Set 4 ---> murakami
# Processing Record 6 of Set 4 ---> pierre
# Processing Record 7 of Set 4 ---> port hawkesbury
# Processing Record 8 of Set 4 ---> karratha
# Processing Record 9 of Set 4 ---> fort-shevchenko
# Processing Record 10 of Set 4 ---> georgetown
# Processing Record 11 of Set 4 ---> hithadhoo
# barentsburg not found. Proceeding to the next city...
# Processing Record 12 of Set 4 ---> teahupoo
# Processing Record 13 of Set 4 ---> nenjiang
# Processing Record 14 of Set 4 ---> itarema
# Processing Record 15 of Set 4 ---> gizo
# krasnaya gora not found. Proceeding to the next city...
# Processing Record 16 of Set 4 ---> lompoc
# Processing Record 17 of Set 4 ---> tasiilaq
# Processing Record 18 of Set 4 ---> bitung
# Processing Record 19 of Set 4 ---> constitucion
# Processing Record 20 of Set 4 ---> nouadhibou
# Processing Record 21 of Set 4 ---> mys shmidta
# Processing Record 22 of Set 4 ---> thompson
# Processing Record 23 of Set 4 ---> zhuanghe
# Processing Record 24 of Set 4 ---> iqaluit
# Processing Record 25 of Set 4 ---> kayerkan
# Processing Record 26 of Set 4 ---> badou
# samalaeulu not found. Proceeding to the next city...
# karamea not found. Proceeding to the next city...
# bolungarvik not found. Proceeding to the next city...
# Processing Record 27 of Set 4 ---> banjarmasin
# Processing Record 28 of Set 4 ---> pisco
# Processing Record 29 of Set 4 ---> pundaguitan
# Processing Record 30 of Set 4 ---> westport
# Processing Record 31 of Set 4 ---> airai
# Processing Record 32 of Set 4 ---> pevek
# Processing Record 33 of Set 4 ---> otjiwarongo
# Processing Record 34 of Set 4 ---> port macquarie
# Processing Record 35 of Set 4 ---> migori
# det udom not found. Proceeding to the next city...
# karaul not found. Proceeding to the next city...
# phrai bung not found. Proceeding to the next city...
# Processing Record 36 of Set 4 ---> hofn
# Processing Record 37 of Set 4 ---> ostrovnoy
# Processing Record 38 of Set 4 ---> eslov
# marcona not found. Proceeding to the next city...
# the valley not found. Proceeding to the next city...
# Processing Record 39 of Set 4 ---> san antonio
# wulanhaote not found. Proceeding to the next city...
# Processing Record 40 of Set 4 ---> kyabram
# Processing Record 41 of Set 4 ---> anadyr
# Processing Record 42 of Set 4 ---> chicama
# Processing Record 43 of Set 4 ---> razole
# Processing Record 44 of Set 4 ---> talaya
# Processing Record 45 of Set 4 ---> acapulco
# Processing Record 46 of Set 4 ---> notodden
# Processing Record 47 of Set 4 ---> shingu
# Processing Record 48 of Set 4 ---> palmer
# Processing Record 49 of Set 4 ---> muros
# Processing Record 50 of Set 4 ---> vega de alatorre
# Processing Record 1 of Set 5 ---> tirumullaivasal
# Processing Record 2 of Set 5 ---> kang
# Processing Record 3 of Set 5 ---> quzhou
# Processing Record 4 of Set 5 ---> andenes
# Processing Record 5 of Set 5 ---> zhangye
# Processing Record 6 of Set 5 ---> touros
# Processing Record 7 of Set 5 ---> sitka
# wahran not found. Proceeding to the next city...
# Processing Record 8 of Set 5 ---> saint-leu
# Processing Record 9 of Set 5 ---> matamoros
# la ronge not found. Proceeding to the next city...
# Processing Record 10 of Set 5 ---> eseka
# Processing Record 11 of Set 5 ---> buluang
# Processing Record 12 of Set 5 ---> casablanca
# Processing Record 13 of Set 5 ---> vestmannaeyjar
# Processing Record 14 of Set 5 ---> aguimes
# Processing Record 15 of Set 5 ---> port alfred
# Processing Record 16 of Set 5 ---> punta gorda
# Processing Record 17 of Set 5 ---> gorontalo
# Processing Record 18 of Set 5 ---> murgab
# lolua not found. Proceeding to the next city...
# Processing Record 19 of Set 5 ---> inverell
# Processing Record 20 of Set 5 ---> hailar
# Processing Record 21 of Set 5 ---> meulaboh
# ha tinh not found. Proceeding to the next city...
# saint george not found. Proceeding to the next city...
# Processing Record 22 of Set 5 ---> maple creek
# Processing Record 23 of Set 5 ---> jales
# Processing Record 24 of Set 5 ---> port lincoln
# Processing Record 25 of Set 5 ---> bystrice nad pernstejnem
# Processing Record 26 of Set 5 ---> cap-chat
# Processing Record 27 of Set 5 ---> nemuro
# Processing Record 28 of Set 5 ---> mahebourg
# Processing Record 29 of Set 5 ---> mehamn
# Processing Record 30 of Set 5 ---> manyana
# Processing Record 31 of Set 5 ---> vyazma
# umzimvubu not found. Proceeding to the next city...
# Processing Record 32 of Set 5 ---> viedma
# Processing Record 33 of Set 5 ---> sena madureira
# yerofey pavlovich not found. Proceeding to the next city...
# Processing Record 34 of Set 5 ---> kaeo
# Processing Record 35 of Set 5 ---> freeport
# Processing Record 36 of Set 5 ---> talcahuano
# Processing Record 37 of Set 5 ---> bethel
# Processing Record 38 of Set 5 ---> amahai
# sofiysk not found. Proceeding to the next city...
# Processing Record 39 of Set 5 ---> santa cruz
# Processing Record 40 of Set 5 ---> rio grande
# Processing Record 41 of Set 5 ---> vaitape
# Processing Record 42 of Set 5 ---> morehead
# Processing Record 43 of Set 5 ---> nanortalik
# Processing Record 44 of Set 5 ---> enumclaw
# Processing Record 45 of Set 5 ---> warren
# Processing Record 46 of Set 5 ---> waddan
# Processing Record 47 of Set 5 ---> faanui
# tasbuget not found. Proceeding to the next city...
# Processing Record 48 of Set 5 ---> alta floresta
# Processing Record 49 of Set 5 ---> bathsheba
# Processing Record 50 of Set 5 ---> muisne
# tabulbah not found. Proceeding to the next city...
# Processing Record 1 of Set 6 ---> vanimo
# Processing Record 2 of Set 6 ---> lazaro cardenas
# dzhusaly not found. Proceeding to the next city...
# Processing Record 3 of Set 6 ---> xining
# great yarmouth not found. Proceeding to the next city...
# Processing Record 4 of Set 6 ---> novyy urengoy
# Processing Record 5 of Set 6 ---> samur
# Processing Record 6 of Set 6 ---> cayenne
# solovetskiy not found. Proceeding to the next city...
# Processing Record 7 of Set 6 ---> vazhiny
# Processing Record 8 of Set 6 ---> khlung
# Processing Record 9 of Set 6 ---> evensk
# Processing Record 10 of Set 6 ---> katsuura
# Processing Record 11 of Set 6 ---> sembakung
# Processing Record 12 of Set 6 ---> kortkeros
# Processing Record 13 of Set 6 ---> tezu
# Processing Record 14 of Set 6 ---> luz
# Processing Record 15 of Set 6 ---> taltal
# Processing Record 16 of Set 6 ---> hay river
# Processing Record 17 of Set 6 ---> goulburn
# Processing Record 18 of Set 6 ---> sazonovo
# Processing Record 19 of Set 6 ---> steinbach
# Processing Record 20 of Set 6 ---> grand-santi
# Processing Record 21 of Set 6 ---> port hardy
# Processing Record 22 of Set 6 ---> makakilo city
# Processing Record 23 of Set 6 ---> magan
# Processing Record 24 of Set 6 ---> faya
# Processing Record 25 of Set 6 ---> kijang
# Processing Record 26 of Set 6 ---> weilmunster
# Processing Record 27 of Set 6 ---> yulara
# Processing Record 28 of Set 6 ---> luquillo
# Processing Record 29 of Set 6 ---> kutum
# Processing Record 30 of Set 6 ---> gurupa
# Processing Record 31 of Set 6 ---> saint-georges
# Processing Record 32 of Set 6 ---> sosnogorsk
# Processing Record 33 of Set 6 ---> moindou
# Processing Record 34 of Set 6 ---> veraval
# barbar not found. Proceeding to the next city...
# Processing Record 35 of Set 6 ---> panaba
# Processing Record 36 of Set 6 ---> broome
# Processing Record 37 of Set 6 ---> whitecourt
# Processing Record 38 of Set 6 ---> kavieng
# Processing Record 39 of Set 6 ---> les cayes
# Processing Record 40 of Set 6 ---> tuatapere
# Processing Record 41 of Set 6 ---> kashi
# Processing Record 42 of Set 6 ---> moree
# umm lajj not found. Proceeding to the next city...
# Processing Record 43 of Set 6 ---> nantucket
# Processing Record 44 of Set 6 ---> clarence town
# Processing Record 45 of Set 6 ---> brownsville
# Processing Record 46 of Set 6 ---> vila velha
# alotau not found. Proceeding to the next city...
# te anau not found. Proceeding to the next city...
# Processing Record 47 of Set 6 ---> paramonga
# doctor arroyo not found. Proceeding to the next city...
# Processing Record 48 of Set 6 ---> lensk
# Processing Record 49 of Set 6 ---> grindavik
# Processing Record 50 of Set 6 ---> kendari
# Processing Record 1 of Set 7 ---> tangzhai
# Processing Record 2 of Set 7 ---> boguchany
# Processing Record 3 of Set 7 ---> maningrida
# Processing Record 4 of Set 7 ---> gusau
# Processing Record 5 of Set 7 ---> helena
# Processing Record 6 of Set 7 ---> bosaso
# Processing Record 7 of Set 7 ---> carmen
# Processing Record 8 of Set 7 ---> barra do garcas
# Processing Record 9 of Set 7 ---> sao felix do xingu
# Processing Record 10 of Set 7 ---> urumqi
# Processing Record 11 of Set 7 ---> hearst
# Processing Record 12 of Set 7 ---> san quintin
# Processing Record 13 of Set 7 ---> port blair
# Processing Record 14 of Set 7 ---> dolores
# Processing Record 15 of Set 7 ---> coaldale
# Processing Record 16 of Set 7 ---> shihezi
# Processing Record 17 of Set 7 ---> eastlake
# Processing Record 18 of Set 7 ---> tambilil
# Processing Record 19 of Set 7 ---> ust-nera
# Processing Record 20 of Set 7 ---> iralaya
# Processing Record 21 of Set 7 ---> cabedelo
# Processing Record 22 of Set 7 ---> whitehorse
# Processing Record 23 of Set 7 ---> hailun
# Processing Record 24 of Set 7 ---> gushikawa
# Processing Record 25 of Set 7 ---> ilovlya
# Processing Record 26 of Set 7 ---> cururupu
# Processing Record 27 of Set 7 ---> bandarbeyla
# Processing Record 28 of Set 7 ---> sarangani
# broken hill not found. Proceeding to the next city...
# coffs harbour not found. Proceeding to the next city...
# Processing Record 29 of Set 7 ---> katherine
# Processing Record 30 of Set 7 ---> saint-pierre
# Processing Record 31 of Set 7 ---> hamilton
# Processing Record 32 of Set 7 ---> poya
# Processing Record 33 of Set 7 ---> innisfail
# Processing Record 34 of Set 7 ---> turinsk
# saleaula not found. Proceeding to the next city...
# Processing Record 35 of Set 7 ---> makokou
# Processing Record 36 of Set 7 ---> kysyl-syr
# Processing Record 37 of Set 7 ---> flinders
# Processing Record 38 of Set 7 ---> guider
# Processing Record 39 of Set 7 ---> kenai
# Processing Record 40 of Set 7 ---> canico
# Processing Record 41 of Set 7 ---> kruisfontein
# Processing Record 42 of Set 7 ---> sungaipenuh
# Processing Record 43 of Set 7 ---> otofuke
# Processing Record 44 of Set 7 ---> yumen
# tapaua not found. Proceeding to the next city...
# Processing Record 45 of Set 7 ---> kuching
# Processing Record 46 of Set 7 ---> port-gentil
# Processing Record 47 of Set 7 ---> nefteyugansk
# Processing Record 48 of Set 7 ---> wilmington island
# Processing Record 49 of Set 7 ---> khon kaen
# kollumerland not found. Proceeding to the next city...
# Processing Record 50 of Set 7 ---> dzhebariki-khaya
# Processing Record 1 of Set 8 ---> torbay
# chiang klang not found. Proceeding to the next city...
# Processing Record 2 of Set 8 ---> axim
# amderma not found. Proceeding to the next city...
# Processing Record 3 of Set 8 ---> dargaville
# Processing Record 4 of Set 8 ---> allapalli
# Processing Record 5 of Set 8 ---> san felipe
# Processing Record 6 of Set 8 ---> alice springs
# Processing Record 7 of Set 8 ---> vondrozo
# Processing Record 8 of Set 8 ---> arcata
# Processing Record 9 of Set 8 ---> lokosovo
# Processing Record 10 of Set 8 ---> hambantota
# Processing Record 11 of Set 8 ---> misratah
# Processing Record 12 of Set 8 ---> humboldt
# Processing Record 13 of Set 8 ---> usinsk
# Processing Record 14 of Set 8 ---> pangkalanbuun
# Processing Record 15 of Set 8 ---> fare
# Processing Record 16 of Set 8 ---> cockburn town
# Processing Record 17 of Set 8 ---> somerset east
# Processing Record 18 of Set 8 ---> kontagora
# Processing Record 19 of Set 8 ---> kloulklubed
# Processing Record 20 of Set 8 ---> atar
# Processing Record 21 of Set 8 ---> moa
# conceicao do araguaia not found. Proceeding to the next city...
# Processing Record 22 of Set 8 ---> klaksvik
# Processing Record 23 of Set 8 ---> erzin
# Processing Record 24 of Set 8 ---> cabo san lucas
# Processing Record 25 of Set 8 ---> sorland
# Processing Record 26 of Set 8 ---> grand-lahou
# Processing Record 27 of Set 8 ---> nam tha
# Processing Record 28 of Set 8 ---> half moon bay
# karkaralinsk not found. Proceeding to the next city...
# Processing Record 29 of Set 8 ---> ahipara
# el guamo not found. Proceeding to the next city...
# Processing Record 30 of Set 8 ---> rio gallegos
# Processing Record 31 of Set 8 ---> botwood
# Processing Record 32 of Set 8 ---> tacoronte
# Processing Record 33 of Set 8 ---> ekhabi
# Processing Record 34 of Set 8 ---> dingle
# Processing Record 35 of Set 8 ---> iglesias
# Processing Record 36 of Set 8 ---> bur gabo
# Processing Record 37 of Set 8 ---> wanning
# Processing Record 38 of Set 8 ---> acari
# Processing Record 39 of Set 8 ---> samana
# Processing Record 40 of Set 8 ---> geraldton
# Processing Record 41 of Set 8 ---> sibolga
# Processing Record 42 of Set 8 ---> aquiraz
# Processing Record 43 of Set 8 ---> ailigandi
# Processing Record 44 of Set 8 ---> port keats
# Processing Record 45 of Set 8 ---> bom jardim
# umm kaddadah not found. Proceeding to the next city...
# Processing Record 46 of Set 8 ---> berlevag
# Processing Record 47 of Set 8 ---> tres lagoas
# samusu not found. Proceeding to the next city...
# ruatoria not found. Proceeding to the next city...
# Processing Record 48 of Set 8 ---> kholmsk
# Processing Record 49 of Set 8 ---> roanoke
# Processing Record 50 of Set 8 ---> buncrana
# Processing Record 1 of Set 9 ---> hualmay
# Processing Record 2 of Set 9 ---> champerico
# ngukurr not found. Proceeding to the next city...
# Processing Record 3 of Set 9 ---> durg
# Processing Record 4 of Set 9 ---> menongue
# Processing Record 5 of Set 9 ---> gamba
# Processing Record 6 of Set 9 ---> morant bay
# Processing Record 7 of Set 9 ---> jalu
# Processing Record 8 of Set 9 ---> ancud
# Processing Record 9 of Set 9 ---> corn island
# Processing Record 10 of Set 9 ---> swift current
# Processing Record 11 of Set 9 ---> itacare
# Processing Record 12 of Set 9 ---> roma
# Processing Record 13 of Set 9 ---> bugarama
# Processing Record 14 of Set 9 ---> bardiyah
# Processing Record 15 of Set 9 ---> marsh harbour
# Processing Record 16 of Set 9 ---> san luis rio colorado
# Processing Record 17 of Set 9 ---> sao lourenco do sul
# Processing Record 18 of Set 9 ---> arman
# Processing Record 19 of Set 9 ---> aranos
# Processing Record 20 of Set 9 ---> tigil
# Processing Record 21 of Set 9 ---> mali
# Processing Record 22 of Set 9 ---> namatanai
# tumannyy not found. Proceeding to the next city...
# Processing Record 23 of Set 9 ---> machico
# Processing Record 24 of Set 9 ---> ucluelet
# Processing Record 25 of Set 9 ---> warri
# Processing Record 26 of Set 9 ---> bilibino
# Processing Record 27 of Set 9 ---> xucheng
# Processing Record 28 of Set 9 ---> nishihara
# Processing Record 29 of Set 9 ---> fort nelson
# Processing Record 30 of Set 9 ---> syava
# Processing Record 31 of Set 9 ---> vila
# nizhneyansk not found. Proceeding to the next city...
# Processing Record 32 of Set 9 ---> jumla
# Processing Record 33 of Set 9 ---> comodoro rivadavia
# Processing Record 34 of Set 9 ---> lewistown
# sentyabrskiy not found. Proceeding to the next city...
# Processing Record 35 of Set 9 ---> batticaloa
# Processing Record 36 of Set 9 ---> lagoa
# Processing Record 37 of Set 9 ---> saldanha
# Processing Record 38 of Set 9 ---> biloela
# Processing Record 39 of Set 9 ---> quime
# Processing Record 40 of Set 9 ---> meadow lake
# Processing Record 41 of Set 9 ---> mantua
# Processing Record 42 of Set 9 ---> chumphon
# Processing Record 43 of Set 9 ---> souillac
# Processing Record 44 of Set 9 ---> marawi
# Processing Record 45 of Set 9 ---> terme
# am timan not found. Proceeding to the next city...
# Processing Record 46 of Set 9 ---> assiniboia
# Processing Record 47 of Set 9 ---> vardo
# Processing Record 48 of Set 9 ---> necochea
# Processing Record 49 of Set 9 ---> teguise
# bargal not found. Proceeding to the next city...
# saint anthony not found. Proceeding to the next city...
# eldikan not found. Proceeding to the next city...
# Processing Record 50 of Set 9 ---> puerto leguizamo
# Processing Record 1 of Set 10 ---> banda aceh
# Processing Record 2 of Set 10 ---> gravdal
# Processing Record 3 of Set 10 ---> melo
# conceicao do castelo not found. Proceeding to the next city...
# Processing Record 4 of Set 10 ---> northam
# Processing Record 5 of Set 10 ---> bairiki
# Processing Record 6 of Set 10 ---> shimoda
# Processing Record 7 of Set 10 ---> bonavista
# Processing Record 8 of Set 10 ---> toppenish
# Processing Record 9 of Set 10 ---> semey
# Processing Record 10 of Set 10 ---> tongliao
# Processing Record 11 of Set 10 ---> kamina
# Processing Record 12 of Set 10 ---> tambovka
# Processing Record 13 of Set 10 ---> odienne
# Processing Record 14 of Set 10 ---> tabas
# Processing Record 15 of Set 10 ---> emerald
# Processing Record 16 of Set 10 ---> ontario
# Processing Record 17 of Set 10 ---> bridlington
# toungoo not found. Proceeding to the next city...
# Processing Record 18 of Set 10 ---> sangmelima
# Processing Record 19 of Set 10 ---> buchanan
# Processing Record 20 of Set 10 ---> olga
# Processing Record 21 of Set 10 ---> salalah
# Processing Record 22 of Set 10 ---> san rafael
# Processing Record 23 of Set 10 ---> ararat
# palabuhanratu not found. Proceeding to the next city...
# quatre cocos not found. Proceeding to the next city...
# Processing Record 24 of Set 10 ---> voznesenye
# Processing Record 25 of Set 10 ---> paracuru
# Processing Record 26 of Set 10 ---> ende
# tuggurt not found. Proceeding to the next city...
# Processing Record 27 of Set 10 ---> tshikapa
# Processing Record 28 of Set 10 ---> boende
# Processing Record 29 of Set 10 ---> yar-sale
# Processing Record 30 of Set 10 ---> strathpeffer
# Processing Record 31 of Set 10 ---> miri
# Processing Record 32 of Set 10 ---> matara
# Processing Record 33 of Set 10 ---> norrtalje
# Processing Record 34 of Set 10 ---> san policarpo
# Processing Record 35 of Set 10 ---> ixtapa
# Processing Record 36 of Set 10 ---> glazov
# Processing Record 37 of Set 10 ---> maues
# Processing Record 38 of Set 10 ---> hami
# Processing Record 39 of Set 10 ---> kazanskoye
# Processing Record 40 of Set 10 ---> lavrentiya
# Processing Record 41 of Set 10 ---> homa bay
# Processing Record 42 of Set 10 ---> cagayan de tawi-tawi
# Processing Record 43 of Set 10 ---> parnamirim
# Processing Record 44 of Set 10 ---> illapel
# Processing Record 45 of Set 10 ---> lamu
# Processing Record 46 of Set 10 ---> mirskoy
# Processing Record 47 of Set 10 ---> tres arroyos
# Processing Record 48 of Set 10 ---> rorvik
# Processing Record 49 of Set 10 ---> dongsheng
# Processing Record 50 of Set 10 ---> ust-ilimsk
# Processing Record 1 of Set 11 ---> chumikan
# Processing Record 2 of Set 11 ---> kostino
# Processing Record 3 of Set 11 ---> lorengau
# Processing Record 4 of Set 11 ---> iquique
# wa not found. Proceeding to the next city...
# Processing Record 5 of Set 11 ---> abay
# Processing Record 6 of Set 11 ---> bud
# Processing Record 7 of Set 11 ---> middlesbrough
# tiruvottiyur not found. Proceeding to the next city...
# Processing Record 8 of Set 11 ---> sabha
# Processing Record 9 of Set 11 ---> kristiansund
# Processing Record 10 of Set 11 ---> jais
# Processing Record 11 of Set 11 ---> antofagasta
# meyungs not found. Proceeding to the next city...
# Processing Record 12 of Set 11 ---> nuuk
# bolshaya sosnova not found. Proceeding to the next city...
# Processing Record 13 of Set 11 ---> irupi
# Processing Record 14 of Set 11 ---> ilabaya
# Processing Record 15 of Set 11 ---> kopervik
# Processing Record 16 of Set 11 ---> sorong
# Processing Record 17 of Set 11 ---> tomatlan
# Processing Record 18 of Set 11 ---> smithers
# Processing Record 19 of Set 11 ---> naze
# Processing Record 20 of Set 11 ---> lasa
# *******************************
# Data Retrieval Complete
# *******************************

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# The data generated from the API calls will be compiled into a new Data Fram
weather_data_frame = pd.DataFrame({
    'City':updated_city_list,
    'Lattitude':lattitude,
    'Longitude': longitude,
    'Max Temp': max_temp,
    'Humidity': humidity,
    'Cloudiness': cloudinesses,
    'Wind Speed': wind,
    'Country': country_list,
    'Date':dates
})

## Exporting the new DataFrame into a csv file
weather_data_frame.to_csv('..\Output_Data\Weather_Data_Collection.csv')

## Displaying the DataFrame
print(f'{weather_data_frame.shape[0]} cities, along with their weather information, have been collated\n')
weather_data_frame.head()
# Out:
# 520 cities, along with their weather information, have been collated
#           City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0   shitanjing      39.23     106.34     16.17        56          84
# 1  yerbogachen      61.28     108.01      1.43        80           0
# 2      chengam      12.30      78.80     22.27        88         100
# 3  clyde river      41.30     -82.98     12.78        76          52
# 4         nome      64.50    -165.41      6.11        60          90
#
#    Wind Speed Country        Date
# 0        1.20      CN  1601430260
# 1        2.03      RU  1601430261
# 2        3.00      IN  1601430261
# 3        0.45      US  1601430262
# 4        3.60      US  1601430262

# %%
## Summary Statistics 
weather_data_frame.describe()
# Out:
#         Lattitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  520.000000  520.000000  520.000000  520.000000  520.000000  520.000000
# mean    21.685038   23.217635   17.745885   73.903846   53.217308    3.193096
# std     31.679584   88.232727    8.718298   19.276769   39.923879    2.248506
# min    -54.800000 -175.200000   -9.700000   10.000000    0.000000    0.090000
# 25%     -3.372500  -51.122500   11.000000   64.000000    7.750000    1.500000
# 50%     22.185000   21.750000   18.890000   77.500000   62.000000    2.715000
# 75%     47.262500  101.650000   25.000000   89.000000   93.000000    4.232500
# max     78.220000  179.320000   34.000000  100.000000  100.000000   12.420000
#
#                Date
# count  5.200000e+02
# mean   1.601430e+09
# std    1.186806e+02
# min    1.601430e+09
# 25%    1.601430e+09
# 50%    1.601430e+09
# 75%    1.601431e+09
# max    1.601431e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking to see if there are cities with humidities over 100
weather_data_frame[weather_data_frame['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lattitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames_Over100 = weather_data_frame[weather_data_frame['Humidity']>100].index

# %%
if (len(indexNames_Over100)) > 0:
    print(f'There are cities with humidity over 100')
else:
    print(f'There are no cities with humidity over 100')
# Out:
# There are no cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data_frame.drop(indexNames_Over100, inplace=False)

# %%
print(f'There are {clean_city_data.shape[0]} cities to be assessed\n')
clean_city_data.head()
# Out:
# There are 520 cities to be assessed
#           City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0   shitanjing      39.23     106.34     16.17        56          84
# 1  yerbogachen      61.28     108.01      1.43        80           0
# 2      chengam      12.30      78.80     22.27        88         100
# 3  clyde river      41.30     -82.98     12.78        76          52
# 4         nome      64.50    -165.41      6.11        60          90
#
#    Wind Speed Country        Date
# 0        1.20      CN  1601430260
# 1        2.03      RU  1601430261
# 2        3.00      IN  1601430261
# 3        0.45      US  1601430262
# 4        3.60      US  1601430262

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# A scatter plot will be used in order to determine the relationship between temperature and lattitudes
x_lattitude = clean_city_data['Lattitude']
y_temperature = clean_city_data['Max Temp']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Temperature',fontsize=15)
ax1.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_temperature, edgecolors='black', c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Temperature.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# We will use the previous x_label and create a new Y label pertaining to humidity
y_humidity = clean_city_data['Humidity']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Humidity',fontsize=15)
ax1.set_ylabel('Humidity', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_humidity, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# We will set a new y_ variable pertaining to Cloudiness
y_cloudiness = clean_city_data['Cloudiness']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Cloudiness',fontsize=15)
ax1.set_ylabel('Cloudiness(%)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_cloudiness, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# We wil set a new y_ variable pertaining to Wind Speed
y_windspeed = clean_city_data['Wind Speed']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Wind Speed',fontsize=15)
ax1.set_ylabel('Wind Speed (mph)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_windspeed, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_WindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Northern Hemisphere Latitudes vs Max Temperature

# %%
# All cities within the Northern Hemisphere will be in the lattitude range of 0(equator) to 90. 
# We will need to filter the dataframe to contain cities within the northern hemisphere (nh)

northern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']>=0]

x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_max_temp = northern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_max_temp)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.7533785070575987

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# All cities within the Southern Hemisphere will be in the lattitude range of 0(equator) to -90. 
# We will need to filter the dataframe to contain cities within the southern hemisphere (sh)

southern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']<=0]

x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_max_temp = southern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_max_temp)

# Linear Regression Label
line_eq_sh = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit_sh = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit_sh,'black')
ax2.scatter(x_sh_latitude,y_sh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.5268344466190786

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_humidity = northern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.007986128793526235

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_humidity = southern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.0019508696608274078

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_cloudiness = northern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.00140491773049189

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_cloudiness = southern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.01422101378548443

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_windspeed = northern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Windspeed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Windspeed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.03534996221926389

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_windspeed = southern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Wind Speed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Wind Speed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.0718758748644816

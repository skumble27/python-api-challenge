# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing the relevant modules for weather analyses
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import scipy.stats as st
import matplotlib
from datetime import datetime

# Importing the API Key
from api_keys import weather_api_key

# Setting Unit of Measurement for Temperature
celsius ='metric'

# Setting up the query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={celsius}&q="

# Creating a timestamp to plot in the graphs
current_time = datetime.now()

# %% [markdown]
# ## Generate Cities List

# %%
# Preparing lists to store random lattitude and longitude coordinates
random_lat_long = []
city_names = []

# Creting Random Lattitudes
ran_lattitude = np.random.uniform(low=-90.000, high=90.000, size=1500)
ran_longitude = np.random.uniform(low=-180.000, high=180.000, size=1500)
random_lat_long = zip(ran_lattitude,ran_longitude)

# Assigning the nearest city to the coordinates
for lat_long in random_lat_long:
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name

    # Ensuring only unique city names are added
    if city in city_names:
        next
    else:
        city_names.append(city)
print(f'The number of cities added are {len(city_names)}')
# Out:
# The number of cities added are 649

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
updated_city_list = []
cloudinesses = []
dates = []
humidity = []
lattitude = []
longitude = []
max_temp = []
wind = []
country_list = []

# set initial count quantities for organization
record_number = 0
record_sets = 1

# loops for creating dataframe columns
print(f'Data Retreival commencing\n---------------------\n')
for city in city_names:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lattitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        if record_number > 49:
            record_number = 1
            record_sets += 1
            updated_city_list.append(city)
        else:
            record_number += 1
            updated_city_list.append(city)
        print(f"Processing Record {record_number} of Set {record_sets} ---> {city}")
    except Exception:
        print(f"{city} not found. Proceeding to the next city...")
print("*******************************")
print("Data Retrieval Complete\n*******************************")
# Out:
# Data Retreival commencing
# ---------------------
#
# Processing Record 1 of Set 1 ---&gt; atuona
# Processing Record 2 of Set 1 ---&gt; klaksvik
# Processing Record 3 of Set 1 ---&gt; kodiak
# Processing Record 4 of Set 1 ---&gt; tasiilaq
# Processing Record 5 of Set 1 ---&gt; kabompo
# manoel urbano not found. Proceeding to the next city...
# Processing Record 6 of Set 1 ---&gt; seymchan
# Processing Record 7 of Set 1 ---&gt; fort nelson
# Processing Record 8 of Set 1 ---&gt; jamestown
# Processing Record 9 of Set 1 ---&gt; georgetown
# Processing Record 10 of Set 1 ---&gt; hervey bay
# burica not found. Proceeding to the next city...
# Processing Record 11 of Set 1 ---&gt; cap malheureux
# Processing Record 12 of Set 1 ---&gt; biak
# Processing Record 13 of Set 1 ---&gt; busselton
# Processing Record 14 of Set 1 ---&gt; poum
# Processing Record 15 of Set 1 ---&gt; talnakh
# Processing Record 16 of Set 1 ---&gt; yertsevo
# Processing Record 17 of Set 1 ---&gt; puerto escondido
# Processing Record 18 of Set 1 ---&gt; acapulco
# Processing Record 19 of Set 1 ---&gt; gopalpur
# Processing Record 20 of Set 1 ---&gt; itarema
# Processing Record 21 of Set 1 ---&gt; upernavik
# Processing Record 22 of Set 1 ---&gt; port alfred
# Processing Record 23 of Set 1 ---&gt; punta arenas
# Processing Record 24 of Set 1 ---&gt; mahebourg
# Processing Record 25 of Set 1 ---&gt; oranjemund
# Processing Record 26 of Set 1 ---&gt; saint-philippe
# Processing Record 27 of Set 1 ---&gt; bambous virieux
# Processing Record 28 of Set 1 ---&gt; manjacaze
# Processing Record 29 of Set 1 ---&gt; rikitea
# tsihombe not found. Proceeding to the next city...
# sentyabrskiy not found. Proceeding to the next city...
# Processing Record 30 of Set 1 ---&gt; ushuaia
# Processing Record 31 of Set 1 ---&gt; hobart
# Processing Record 32 of Set 1 ---&gt; sanandaj
# Processing Record 33 of Set 1 ---&gt; souillac
# taolanaro not found. Proceeding to the next city...
# Processing Record 34 of Set 1 ---&gt; bredasdorp
# Processing Record 35 of Set 1 ---&gt; selizharovo
# Processing Record 36 of Set 1 ---&gt; hilo
# Processing Record 37 of Set 1 ---&gt; nikolskoye
# Processing Record 38 of Set 1 ---&gt; gold coast
# Processing Record 39 of Set 1 ---&gt; amurzet
# Processing Record 40 of Set 1 ---&gt; avarua
# Processing Record 41 of Set 1 ---&gt; mataura
# Processing Record 42 of Set 1 ---&gt; salalah
# Processing Record 43 of Set 1 ---&gt; vestmannaeyjar
# belushya guba not found. Proceeding to the next city...
# Processing Record 44 of Set 1 ---&gt; bethel
# Processing Record 45 of Set 1 ---&gt; kaeo
# Processing Record 46 of Set 1 ---&gt; minjur
# Processing Record 47 of Set 1 ---&gt; lebu
# Processing Record 48 of Set 1 ---&gt; luderitz
# Processing Record 49 of Set 1 ---&gt; puerto ayora
# Processing Record 50 of Set 1 ---&gt; san ramon
# Processing Record 1 of Set 2 ---&gt; paracale
# Processing Record 2 of Set 2 ---&gt; hermanus
# sindand not found. Proceeding to the next city...
# Processing Record 3 of Set 2 ---&gt; kindu
# Processing Record 4 of Set 2 ---&gt; burnie
# Processing Record 5 of Set 2 ---&gt; oistins
# Processing Record 6 of Set 2 ---&gt; redcliffe
# Processing Record 7 of Set 2 ---&gt; bukama
# kazalinsk not found. Proceeding to the next city...
# Processing Record 8 of Set 2 ---&gt; faanui
# Processing Record 9 of Set 2 ---&gt; tuktoyaktuk
# Processing Record 10 of Set 2 ---&gt; faya
# Processing Record 11 of Set 2 ---&gt; ribeira grande
# Processing Record 12 of Set 2 ---&gt; vaini
# Processing Record 13 of Set 2 ---&gt; arraial do cabo
# Processing Record 14 of Set 2 ---&gt; bluff
# Processing Record 15 of Set 2 ---&gt; vokhma
# Processing Record 16 of Set 2 ---&gt; pevek
# Processing Record 17 of Set 2 ---&gt; jieshi
# Processing Record 18 of Set 2 ---&gt; stornoway
# Processing Record 19 of Set 2 ---&gt; pitea
# Processing Record 20 of Set 2 ---&gt; yellowknife
# Processing Record 21 of Set 2 ---&gt; kahului
# Processing Record 22 of Set 2 ---&gt; castro
# Processing Record 23 of Set 2 ---&gt; weyburn
# Processing Record 24 of Set 2 ---&gt; sembe
# Processing Record 25 of Set 2 ---&gt; kalmunai
# Processing Record 26 of Set 2 ---&gt; lagoa
# Processing Record 27 of Set 2 ---&gt; datong
# Processing Record 28 of Set 2 ---&gt; victoria
# Processing Record 29 of Set 2 ---&gt; hay river
# vaitupu not found. Proceeding to the next city...
# Processing Record 30 of Set 2 ---&gt; champerico
# Processing Record 31 of Set 2 ---&gt; tuatapere
# Processing Record 32 of Set 2 ---&gt; kiranur
# Processing Record 33 of Set 2 ---&gt; albany
# Processing Record 34 of Set 2 ---&gt; port-gentil
# Processing Record 35 of Set 2 ---&gt; ketchikan
# Processing Record 36 of Set 2 ---&gt; chernyshevskiy
# the valley not found. Proceeding to the next city...
# Processing Record 37 of Set 2 ---&gt; qaanaaq
# Processing Record 38 of Set 2 ---&gt; pinsk
# Processing Record 39 of Set 2 ---&gt; katangli
# Processing Record 40 of Set 2 ---&gt; itoman
# Processing Record 41 of Set 2 ---&gt; kaitangata
# illoqqortoormiut not found. Proceeding to the next city...
# Processing Record 42 of Set 2 ---&gt; camopi
# Processing Record 43 of Set 2 ---&gt; coquimbo
# Processing Record 44 of Set 2 ---&gt; cape town
# Processing Record 45 of Set 2 ---&gt; new norfolk
# Processing Record 46 of Set 2 ---&gt; pangnirtung
# Processing Record 47 of Set 2 ---&gt; chara
# Processing Record 48 of Set 2 ---&gt; east london
# lolua not found. Proceeding to the next city...
# Processing Record 49 of Set 2 ---&gt; berlevag
# Processing Record 50 of Set 2 ---&gt; xai-xai
# nerchinskiy zavod not found. Proceeding to the next city...
# Processing Record 1 of Set 3 ---&gt; matara
# Processing Record 2 of Set 3 ---&gt; karagay
# Processing Record 3 of Set 3 ---&gt; saskylakh
# Processing Record 4 of Set 3 ---&gt; kaseda
# Processing Record 5 of Set 3 ---&gt; khatanga
# Processing Record 6 of Set 3 ---&gt; tura
# Processing Record 7 of Set 3 ---&gt; ansalta
# Processing Record 8 of Set 3 ---&gt; chokurdakh
# Processing Record 9 of Set 3 ---&gt; tiksi
# Processing Record 10 of Set 3 ---&gt; natal
# Processing Record 11 of Set 3 ---&gt; butaritari
# Processing Record 12 of Set 3 ---&gt; griffith
# Processing Record 13 of Set 3 ---&gt; kasaragod
# Processing Record 14 of Set 3 ---&gt; kushima
# amderma not found. Proceeding to the next city...
# Processing Record 15 of Set 3 ---&gt; mandapam
# Processing Record 16 of Set 3 ---&gt; zabol
# Processing Record 17 of Set 3 ---&gt; san cristobal
# Processing Record 18 of Set 3 ---&gt; tefe
# Processing Record 19 of Set 3 ---&gt; thompson
# Processing Record 20 of Set 3 ---&gt; mao
# Processing Record 21 of Set 3 ---&gt; barrow
# Processing Record 22 of Set 3 ---&gt; rudsar
# Processing Record 23 of Set 3 ---&gt; carnarvon
# nizhneyansk not found. Proceeding to the next city...
# Processing Record 24 of Set 3 ---&gt; jalu
# Processing Record 25 of Set 3 ---&gt; kruisfontein
# Processing Record 26 of Set 3 ---&gt; moengo
# Processing Record 27 of Set 3 ---&gt; ancud
# Processing Record 28 of Set 3 ---&gt; chiredzi
# Processing Record 29 of Set 3 ---&gt; kapaa
# Processing Record 30 of Set 3 ---&gt; avera
# Processing Record 31 of Set 3 ---&gt; green valley
# Processing Record 32 of Set 3 ---&gt; nanortalik
# Processing Record 33 of Set 3 ---&gt; bure
# Processing Record 34 of Set 3 ---&gt; praia
# Processing Record 35 of Set 3 ---&gt; basco
# Processing Record 36 of Set 3 ---&gt; pithapuram
# Processing Record 37 of Set 3 ---&gt; hasaki
# Processing Record 38 of Set 3 ---&gt; santa cruz
# Processing Record 39 of Set 3 ---&gt; santa maria
# Processing Record 40 of Set 3 ---&gt; norman wells
# Processing Record 41 of Set 3 ---&gt; moerai
# Processing Record 42 of Set 3 ---&gt; viedma
# Processing Record 43 of Set 3 ---&gt; touros
# Processing Record 44 of Set 3 ---&gt; dunedin
# saint george not found. Proceeding to the next city...
# Processing Record 45 of Set 3 ---&gt; carballo
# Processing Record 46 of Set 3 ---&gt; ulladulla
# Processing Record 47 of Set 3 ---&gt; peniche
# Processing Record 48 of Set 3 ---&gt; tilichiki
# Processing Record 49 of Set 3 ---&gt; flinders
# Processing Record 50 of Set 3 ---&gt; longyearbyen
# Processing Record 1 of Set 4 ---&gt; esperance
# Processing Record 2 of Set 4 ---&gt; roald
# Processing Record 3 of Set 4 ---&gt; sinnamary
# Processing Record 4 of Set 4 ---&gt; sistranda
# Processing Record 5 of Set 4 ---&gt; saint-pierre
# Processing Record 6 of Set 4 ---&gt; severnoye
# Processing Record 7 of Set 4 ---&gt; moose factory
# Processing Record 8 of Set 4 ---&gt; bengkulu
# Processing Record 9 of Set 4 ---&gt; taoudenni
# Processing Record 10 of Set 4 ---&gt; tadine
# Processing Record 11 of Set 4 ---&gt; lasa
# Processing Record 12 of Set 4 ---&gt; diamantino
# Processing Record 13 of Set 4 ---&gt; mosetse
# los llanos de aridane not found. Proceeding to the next city...
# Processing Record 14 of Set 4 ---&gt; ardakan
# Processing Record 15 of Set 4 ---&gt; hochstadt
# Processing Record 16 of Set 4 ---&gt; killybegs
# Processing Record 17 of Set 4 ---&gt; maraa
# Processing Record 18 of Set 4 ---&gt; port hardy
# Processing Record 19 of Set 4 ---&gt; provideniya
# Processing Record 20 of Set 4 ---&gt; tessalit
# Processing Record 21 of Set 4 ---&gt; hithadhoo
# Processing Record 22 of Set 4 ---&gt; fortuna
# Processing Record 23 of Set 4 ---&gt; buala
# Processing Record 24 of Set 4 ---&gt; ugra
# Processing Record 25 of Set 4 ---&gt; nalut
# Processing Record 26 of Set 4 ---&gt; puri
# Processing Record 27 of Set 4 ---&gt; kosa
# Processing Record 28 of Set 4 ---&gt; sorland
# Processing Record 29 of Set 4 ---&gt; karakol
# Processing Record 30 of Set 4 ---&gt; nome
# Processing Record 31 of Set 4 ---&gt; gizo
# Processing Record 32 of Set 4 ---&gt; assiniboia
# Processing Record 33 of Set 4 ---&gt; haldia
# Processing Record 34 of Set 4 ---&gt; inhambane
# Processing Record 35 of Set 4 ---&gt; mys shmidta
# ksenyevka not found. Proceeding to the next city...
# Processing Record 36 of Set 4 ---&gt; kokoda
# Processing Record 37 of Set 4 ---&gt; yarada
# Processing Record 38 of Set 4 ---&gt; mecca
# Processing Record 39 of Set 4 ---&gt; alice springs
# Processing Record 40 of Set 4 ---&gt; ponta do sol
# Processing Record 41 of Set 4 ---&gt; lorengau
# Processing Record 42 of Set 4 ---&gt; beringovskiy
# Processing Record 43 of Set 4 ---&gt; cherskiy
# Processing Record 44 of Set 4 ---&gt; qasigiannguit
# tongsa not found. Proceeding to the next city...
# Processing Record 45 of Set 4 ---&gt; darhan
# Processing Record 46 of Set 4 ---&gt; komsomolskiy
# Processing Record 47 of Set 4 ---&gt; portland
# Processing Record 48 of Set 4 ---&gt; adrar
# Processing Record 49 of Set 4 ---&gt; sainte-maxime
# Processing Record 50 of Set 4 ---&gt; aklavik
# Processing Record 1 of Set 5 ---&gt; saldanha
# Processing Record 2 of Set 5 ---&gt; mogadishu
# Processing Record 3 of Set 5 ---&gt; phuket
# Processing Record 4 of Set 5 ---&gt; akdepe
# Processing Record 5 of Set 5 ---&gt; concepcion
# Processing Record 6 of Set 5 ---&gt; angoche
# Processing Record 7 of Set 5 ---&gt; abu samrah
# Processing Record 8 of Set 5 ---&gt; hamilton
# Processing Record 9 of Set 5 ---&gt; mount isa
# Processing Record 10 of Set 5 ---&gt; salinopolis
# Processing Record 11 of Set 5 ---&gt; urucara
# Processing Record 12 of Set 5 ---&gt; gerash
# Processing Record 13 of Set 5 ---&gt; san angelo
# Processing Record 14 of Set 5 ---&gt; mildura
# Processing Record 15 of Set 5 ---&gt; neiafu
# Processing Record 16 of Set 5 ---&gt; mar del plata
# Processing Record 17 of Set 5 ---&gt; amapa
# Processing Record 18 of Set 5 ---&gt; chuy
# slave lake not found. Proceeding to the next city...
# Processing Record 19 of Set 5 ---&gt; altay
# Processing Record 20 of Set 5 ---&gt; manitouwadge
# Processing Record 21 of Set 5 ---&gt; egvekinot
# Processing Record 22 of Set 5 ---&gt; san luis
# Processing Record 23 of Set 5 ---&gt; dikson
# Processing Record 24 of Set 5 ---&gt; dingle
# Processing Record 25 of Set 5 ---&gt; montepuez
# Processing Record 26 of Set 5 ---&gt; severo-kurilsk
# Processing Record 27 of Set 5 ---&gt; college
# Processing Record 28 of Set 5 ---&gt; obukhiv
# Processing Record 29 of Set 5 ---&gt; baracoa
# Processing Record 30 of Set 5 ---&gt; dullewala
# Processing Record 31 of Set 5 ---&gt; lima
# Processing Record 32 of Set 5 ---&gt; shimoda
# Processing Record 33 of Set 5 ---&gt; yaan
# Processing Record 34 of Set 5 ---&gt; serebryansk
# Processing Record 35 of Set 5 ---&gt; ampanihy
# Processing Record 36 of Set 5 ---&gt; wenling
# Processing Record 37 of Set 5 ---&gt; skjervoy
# Processing Record 38 of Set 5 ---&gt; opuwo
# Processing Record 39 of Set 5 ---&gt; mizusawa
# attawapiskat not found. Proceeding to the next city...
# Processing Record 40 of Set 5 ---&gt; torbay
# Processing Record 41 of Set 5 ---&gt; taltal
# Processing Record 42 of Set 5 ---&gt; cazin
# Processing Record 43 of Set 5 ---&gt; klyuchi
# Processing Record 44 of Set 5 ---&gt; goure
# Processing Record 45 of Set 5 ---&gt; kunming
# Processing Record 46 of Set 5 ---&gt; ajdabiya
# meyungs not found. Proceeding to the next city...
# umzimvubu not found. Proceeding to the next city...
# Processing Record 47 of Set 5 ---&gt; peleduy
# Processing Record 48 of Set 5 ---&gt; praia da vitoria
# Processing Record 49 of Set 5 ---&gt; comodoro rivadavia
# hunza not found. Proceeding to the next city...
# kadykchan not found. Proceeding to the next city...
# Processing Record 50 of Set 5 ---&gt; coahuayana
# Processing Record 1 of Set 6 ---&gt; najran
# Processing Record 2 of Set 6 ---&gt; havelock
# Processing Record 3 of Set 6 ---&gt; marawi
# quatre cocos not found. Proceeding to the next city...
# Processing Record 4 of Set 6 ---&gt; atambua
# Processing Record 5 of Set 6 ---&gt; cayenne
# Processing Record 6 of Set 6 ---&gt; paamiut
# Processing Record 7 of Set 6 ---&gt; grindavik
# malwan not found. Proceeding to the next city...
# Processing Record 8 of Set 6 ---&gt; yumen
# Processing Record 9 of Set 6 ---&gt; ambon
# Processing Record 10 of Set 6 ---&gt; batouri
# Processing Record 11 of Set 6 ---&gt; pangody
# Processing Record 12 of Set 6 ---&gt; port lincoln
# Processing Record 13 of Set 6 ---&gt; bubaque
# Processing Record 14 of Set 6 ---&gt; veraval
# Processing Record 15 of Set 6 ---&gt; asau
# Processing Record 16 of Set 6 ---&gt; byron bay
# sahrak not found. Proceeding to the next city...
# Processing Record 17 of Set 6 ---&gt; sauda
# Processing Record 18 of Set 6 ---&gt; boa vista
# ambodifototra not found. Proceeding to the next city...
# Processing Record 19 of Set 6 ---&gt; puerto madryn
# Processing Record 20 of Set 6 ---&gt; changli
# barentsburg not found. Proceeding to the next city...
# Processing Record 21 of Set 6 ---&gt; tadepallegudem
# Processing Record 22 of Set 6 ---&gt; mandalgovi
# Processing Record 23 of Set 6 ---&gt; kavaratti
# Processing Record 24 of Set 6 ---&gt; leningradskiy
# Processing Record 25 of Set 6 ---&gt; kotelnikovo
# uwayl not found. Proceeding to the next city...
# Processing Record 26 of Set 6 ---&gt; mendi
# Processing Record 27 of Set 6 ---&gt; toguchin
# Processing Record 28 of Set 6 ---&gt; naze
# Processing Record 29 of Set 6 ---&gt; geraldton
# Processing Record 30 of Set 6 ---&gt; codrington
# Processing Record 31 of Set 6 ---&gt; benguela
# Processing Record 32 of Set 6 ---&gt; bathsheba
# Processing Record 33 of Set 6 ---&gt; cabo san lucas
# Processing Record 34 of Set 6 ---&gt; jumla
# Processing Record 35 of Set 6 ---&gt; aranos
# Processing Record 36 of Set 6 ---&gt; lata
# Processing Record 37 of Set 6 ---&gt; japura
# Processing Record 38 of Set 6 ---&gt; laguna
# Processing Record 39 of Set 6 ---&gt; kawalu
# Processing Record 40 of Set 6 ---&gt; huilong
# Processing Record 41 of Set 6 ---&gt; nizwa
# Processing Record 42 of Set 6 ---&gt; plettenberg bay
# Processing Record 43 of Set 6 ---&gt; nsanje
# Processing Record 44 of Set 6 ---&gt; cidreira
# Processing Record 45 of Set 6 ---&gt; yenagoa
# Processing Record 46 of Set 6 ---&gt; olafsvik
# dianopolis not found. Proceeding to the next city...
# Processing Record 47 of Set 6 ---&gt; cockburn town
# Processing Record 48 of Set 6 ---&gt; rocha
# Processing Record 49 of Set 6 ---&gt; lakhipur
# Processing Record 50 of Set 6 ---&gt; yar-sale
# Processing Record 1 of Set 7 ---&gt; bac lieu
# Processing Record 2 of Set 7 ---&gt; launceston
# Processing Record 3 of Set 7 ---&gt; diapaga
# Processing Record 4 of Set 7 ---&gt; touba
# Processing Record 5 of Set 7 ---&gt; urumqi
# Processing Record 6 of Set 7 ---&gt; airai
# Processing Record 7 of Set 7 ---&gt; port elizabeth
# Processing Record 8 of Set 7 ---&gt; tateyama
# Processing Record 9 of Set 7 ---&gt; trofors
# Processing Record 10 of Set 7 ---&gt; mastic beach
# Processing Record 11 of Set 7 ---&gt; clyde river
# Processing Record 12 of Set 7 ---&gt; tabou
# Processing Record 13 of Set 7 ---&gt; kem
# Processing Record 14 of Set 7 ---&gt; canon city
# Processing Record 15 of Set 7 ---&gt; iralaya
# Processing Record 16 of Set 7 ---&gt; port macquarie
# Processing Record 17 of Set 7 ---&gt; jiwani
# marcona not found. Proceeding to the next city...
# Processing Record 18 of Set 7 ---&gt; saint-denis
# ondorhaan not found. Proceeding to the next city...
# Processing Record 19 of Set 7 ---&gt; rio grande
# Processing Record 20 of Set 7 ---&gt; kampot
# Processing Record 21 of Set 7 ---&gt; ouallam
# Processing Record 22 of Set 7 ---&gt; yulara
# Processing Record 23 of Set 7 ---&gt; kozmodemyansk
# Processing Record 24 of Set 7 ---&gt; san jeronimo
# Processing Record 25 of Set 7 ---&gt; turek
# Processing Record 26 of Set 7 ---&gt; yigou
# Processing Record 27 of Set 7 ---&gt; murray bridge
# Processing Record 28 of Set 7 ---&gt; lufilufi
# Processing Record 29 of Set 7 ---&gt; north bend
# glubokoe not found. Proceeding to the next city...
# Processing Record 30 of Set 7 ---&gt; pacific grove
# Processing Record 31 of Set 7 ---&gt; kavieng
# Processing Record 32 of Set 7 ---&gt; point pedro
# Processing Record 33 of Set 7 ---&gt; mount gambier
# Processing Record 34 of Set 7 ---&gt; ginda
# Processing Record 35 of Set 7 ---&gt; sosnovo-ozerskoye
# Processing Record 36 of Set 7 ---&gt; buseresere
# nombre de dios not found. Proceeding to the next city...
# Processing Record 37 of Set 7 ---&gt; caravelas
# Processing Record 38 of Set 7 ---&gt; antsohihy
# tumannyy not found. Proceeding to the next city...
# Processing Record 39 of Set 7 ---&gt; redmond
# Processing Record 40 of Set 7 ---&gt; alexandria
# Processing Record 41 of Set 7 ---&gt; kanniyakumari
# palabuhanratu not found. Proceeding to the next city...
# Processing Record 42 of Set 7 ---&gt; narsaq
# Processing Record 43 of Set 7 ---&gt; barcelos
# Processing Record 44 of Set 7 ---&gt; phan thiet
# Processing Record 45 of Set 7 ---&gt; manokwari
# Processing Record 46 of Set 7 ---&gt; gamba
# saint-pacome not found. Proceeding to the next city...
# Processing Record 47 of Set 7 ---&gt; sant feliu de guixols
# Processing Record 48 of Set 7 ---&gt; umea
# Processing Record 49 of Set 7 ---&gt; venado tuerto
# Processing Record 50 of Set 7 ---&gt; ridgecrest
# Processing Record 1 of Set 8 ---&gt; batagay-alyta
# Processing Record 2 of Set 8 ---&gt; andalan
# Processing Record 3 of Set 8 ---&gt; lompoc
# Processing Record 4 of Set 8 ---&gt; matagami
# Processing Record 5 of Set 8 ---&gt; toora-khem
# Processing Record 6 of Set 8 ---&gt; rudnogorsk
# Processing Record 7 of Set 8 ---&gt; manuk mangkaw
# Processing Record 8 of Set 8 ---&gt; grand river south east
# Processing Record 9 of Set 8 ---&gt; constitucion
# Processing Record 10 of Set 8 ---&gt; sao domingos do maranhao
# te anau not found. Proceeding to the next city...
# Processing Record 11 of Set 8 ---&gt; morondava
# Processing Record 12 of Set 8 ---&gt; rondonopolis
# Processing Record 13 of Set 8 ---&gt; iesolo
# Processing Record 14 of Set 8 ---&gt; hambantota
# Processing Record 15 of Set 8 ---&gt; hirara
# Processing Record 16 of Set 8 ---&gt; bahar
# Processing Record 17 of Set 8 ---&gt; novobiryusinskiy
# Processing Record 18 of Set 8 ---&gt; ahipara
# luis correia not found. Proceeding to the next city...
# Processing Record 19 of Set 8 ---&gt; labuhan
# Processing Record 20 of Set 8 ---&gt; serchhip
# Processing Record 21 of Set 8 ---&gt; kathu
# Processing Record 22 of Set 8 ---&gt; yermakovskoye
# Processing Record 23 of Set 8 ---&gt; namagiripettai
# Processing Record 24 of Set 8 ---&gt; ziro
# Processing Record 25 of Set 8 ---&gt; karpathos
# Processing Record 26 of Set 8 ---&gt; paragominas
# Processing Record 27 of Set 8 ---&gt; hays
# Processing Record 28 of Set 8 ---&gt; namibe
# Processing Record 29 of Set 8 ---&gt; vaitape
# Processing Record 30 of Set 8 ---&gt; richards bay
# Processing Record 31 of Set 8 ---&gt; mayumba
# Processing Record 32 of Set 8 ---&gt; fare
# Processing Record 33 of Set 8 ---&gt; sitka
# Processing Record 34 of Set 8 ---&gt; tamiahua
# Processing Record 35 of Set 8 ---&gt; sarankhola
# Processing Record 36 of Set 8 ---&gt; lidkoping
# Processing Record 37 of Set 8 ---&gt; houma
# Processing Record 38 of Set 8 ---&gt; kargasok
# Processing Record 39 of Set 8 ---&gt; mandera
# Processing Record 40 of Set 8 ---&gt; namatanai
# de land not found. Proceeding to the next city...
# Processing Record 41 of Set 8 ---&gt; minot
# Processing Record 42 of Set 8 ---&gt; boves
# Processing Record 43 of Set 8 ---&gt; omboue
# Processing Record 44 of Set 8 ---&gt; cruzeiro do sul
# Processing Record 45 of Set 8 ---&gt; srednekolymsk
# Processing Record 46 of Set 8 ---&gt; pilar
# Processing Record 47 of Set 8 ---&gt; zhengjiatun
# Processing Record 48 of Set 8 ---&gt; sirumugai
# Processing Record 49 of Set 8 ---&gt; ixtapa
# Processing Record 50 of Set 8 ---&gt; yueyang
# Processing Record 1 of Set 9 ---&gt; santo domingo
# Processing Record 2 of Set 9 ---&gt; marsa matruh
# Processing Record 3 of Set 9 ---&gt; marzuq
# Processing Record 4 of Set 9 ---&gt; kuybyshevskiy zaton
# Processing Record 5 of Set 9 ---&gt; maceio
# Processing Record 6 of Set 9 ---&gt; lahaina
# Processing Record 7 of Set 9 ---&gt; banda aceh
# Processing Record 8 of Set 9 ---&gt; noumea
# Processing Record 9 of Set 9 ---&gt; mocuba
# Processing Record 10 of Set 9 ---&gt; hornepayne
# Processing Record 11 of Set 9 ---&gt; pedernales
# Processing Record 12 of Set 9 ---&gt; bijar
# karamea not found. Proceeding to the next city...
# Processing Record 13 of Set 9 ---&gt; xining
# Processing Record 14 of Set 9 ---&gt; tazovskiy
# Processing Record 15 of Set 9 ---&gt; candolim
# Processing Record 16 of Set 9 ---&gt; price
# Processing Record 17 of Set 9 ---&gt; fort saint john
# Processing Record 18 of Set 9 ---&gt; linguere
# Processing Record 19 of Set 9 ---&gt; point fortin
# Processing Record 20 of Set 9 ---&gt; puerto del rosario
# Processing Record 21 of Set 9 ---&gt; ilulissat
# Processing Record 22 of Set 9 ---&gt; mindelo
# Processing Record 23 of Set 9 ---&gt; san patricio
# rungata not found. Proceeding to the next city...
# Processing Record 24 of Set 9 ---&gt; kanye
# Processing Record 25 of Set 9 ---&gt; tynda
# Processing Record 26 of Set 9 ---&gt; juneau
# Processing Record 27 of Set 9 ---&gt; ternate
# Processing Record 28 of Set 9 ---&gt; bilibino
# presidencia roque saenz pena not found. Proceeding to the next city...
# Processing Record 29 of Set 9 ---&gt; fairbanks
# Processing Record 30 of Set 9 ---&gt; camacha
# Processing Record 31 of Set 9 ---&gt; iqaluit
# Processing Record 32 of Set 9 ---&gt; kutum
# ketchenery not found. Proceeding to the next city...
# Processing Record 33 of Set 9 ---&gt; rio gallegos
# Processing Record 34 of Set 9 ---&gt; konstantinovskiy
# Processing Record 35 of Set 9 ---&gt; bukachacha
# Processing Record 36 of Set 9 ---&gt; zhigansk
# Processing Record 37 of Set 9 ---&gt; pecos
# Processing Record 38 of Set 9 ---&gt; muli
# Processing Record 39 of Set 9 ---&gt; numan
# andevoranto not found. Proceeding to the next city...
# Processing Record 40 of Set 9 ---&gt; impfondo
# Processing Record 41 of Set 9 ---&gt; damietta
# Processing Record 42 of Set 9 ---&gt; lavrentiya
# Processing Record 43 of Set 9 ---&gt; gigmoto
# Processing Record 44 of Set 9 ---&gt; plymouth
# Processing Record 45 of Set 9 ---&gt; paidha
# Processing Record 46 of Set 9 ---&gt; trincomalee
# Processing Record 47 of Set 9 ---&gt; bacolod
# Processing Record 48 of Set 9 ---&gt; payo
# Processing Record 49 of Set 9 ---&gt; mazsalaca
# Processing Record 50 of Set 9 ---&gt; kribi
# Processing Record 1 of Set 10 ---&gt; lakatoro
# Processing Record 2 of Set 10 ---&gt; pisco
# Processing Record 3 of Set 10 ---&gt; tigzirt
# Processing Record 4 of Set 10 ---&gt; vadu pasii
# da lat not found. Proceeding to the next city...
# Processing Record 5 of Set 10 ---&gt; rosarito
# Processing Record 6 of Set 10 ---&gt; merrill
# Processing Record 7 of Set 10 ---&gt; elmira
# Processing Record 8 of Set 10 ---&gt; christchurch
# Processing Record 9 of Set 10 ---&gt; sundargarh
# Processing Record 10 of Set 10 ---&gt; bereda
# Processing Record 11 of Set 10 ---&gt; zyryanka
# Processing Record 12 of Set 10 ---&gt; saint-leu
# Processing Record 13 of Set 10 ---&gt; trairi
# tapaua not found. Proceeding to the next city...
# Processing Record 14 of Set 10 ---&gt; port augusta
# rawannawi not found. Proceeding to the next city...
# Processing Record 15 of Set 10 ---&gt; ronneby
# Processing Record 16 of Set 10 ---&gt; juba
# Processing Record 17 of Set 10 ---&gt; pitimbu
# Processing Record 18 of Set 10 ---&gt; sangar
# Processing Record 19 of Set 10 ---&gt; vilhena
# ahumada not found. Proceeding to the next city...
# Processing Record 20 of Set 10 ---&gt; pechenga
# Processing Record 21 of Set 10 ---&gt; vila do maio
# Processing Record 22 of Set 10 ---&gt; chaparral
# Processing Record 23 of Set 10 ---&gt; anloga
# qingan not found. Proceeding to the next city...
# Processing Record 24 of Set 10 ---&gt; alofi
# Processing Record 25 of Set 10 ---&gt; poltavka
# Processing Record 26 of Set 10 ---&gt; qandala
# Processing Record 27 of Set 10 ---&gt; vila velha
# Processing Record 28 of Set 10 ---&gt; ostrovnoy
# ozgon not found. Proceeding to the next city...
# Processing Record 29 of Set 10 ---&gt; bud
# Processing Record 30 of Set 10 ---&gt; cukai
# Processing Record 31 of Set 10 ---&gt; husavik
# Processing Record 32 of Set 10 ---&gt; wenzhou
# Processing Record 33 of Set 10 ---&gt; raga
# Processing Record 34 of Set 10 ---&gt; severo-yeniseyskiy
# Processing Record 35 of Set 10 ---&gt; iquitos
# Processing Record 36 of Set 10 ---&gt; sakaraha
# Processing Record 37 of Set 10 ---&gt; san marcos
# Processing Record 38 of Set 10 ---&gt; repalle
# Processing Record 39 of Set 10 ---&gt; half moon bay
# Processing Record 40 of Set 10 ---&gt; verkh-usugli
# Processing Record 41 of Set 10 ---&gt; mayna
# Processing Record 42 of Set 10 ---&gt; sioux lookout
# Processing Record 43 of Set 10 ---&gt; sao borja
# samusu not found. Proceeding to the next city...
# Processing Record 44 of Set 10 ---&gt; santona
# Processing Record 45 of Set 10 ---&gt; prieska
# Processing Record 46 of Set 10 ---&gt; san francisco
# Processing Record 47 of Set 10 ---&gt; bonaventure
# Processing Record 48 of Set 10 ---&gt; san quintin
# Processing Record 49 of Set 10 ---&gt; itanhem
# Processing Record 50 of Set 10 ---&gt; santa vitoria do palmar
# Processing Record 1 of Set 11 ---&gt; aksarayskiy
# Processing Record 2 of Set 11 ---&gt; jennings
# Processing Record 3 of Set 11 ---&gt; hofn
# Processing Record 4 of Set 11 ---&gt; pingzhuang
# saint anthony not found. Proceeding to the next city...
# Processing Record 5 of Set 11 ---&gt; deputatskiy
# Processing Record 6 of Set 11 ---&gt; paka
# umm lajj not found. Proceeding to the next city...
# Processing Record 7 of Set 11 ---&gt; magadan
# Processing Record 8 of Set 11 ---&gt; zelenoborsk
# Processing Record 9 of Set 11 ---&gt; lixourion
# Processing Record 10 of Set 11 ---&gt; coihaique
# Processing Record 11 of Set 11 ---&gt; villa carlos paz
# Processing Record 12 of Set 11 ---&gt; mamallapuram
# Processing Record 13 of Set 11 ---&gt; nemuro
# Processing Record 14 of Set 11 ---&gt; surazh
# Processing Record 15 of Set 11 ---&gt; eyemouth
# Processing Record 16 of Set 11 ---&gt; arona
# Processing Record 17 of Set 11 ---&gt; changping
# Processing Record 18 of Set 11 ---&gt; labuan
# Processing Record 19 of Set 11 ---&gt; myitkyina
# Processing Record 20 of Set 11 ---&gt; esil
# Processing Record 21 of Set 11 ---&gt; arua
# Processing Record 22 of Set 11 ---&gt; rastolita
# samalaeulu not found. Proceeding to the next city...
# Processing Record 23 of Set 11 ---&gt; luganville
# saleaula not found. Proceeding to the next city...
# Processing Record 24 of Set 11 ---&gt; lakes entrance
# Processing Record 25 of Set 11 ---&gt; auki
# Processing Record 26 of Set 11 ---&gt; warrington
# Processing Record 27 of Set 11 ---&gt; pauini
# Processing Record 28 of Set 11 ---&gt; kismayo
# ciudad del maiz not found. Proceeding to the next city...
# Processing Record 29 of Set 11 ---&gt; mehriz
# Processing Record 30 of Set 11 ---&gt; pathein
# Processing Record 31 of Set 11 ---&gt; kudahuvadhoo
# Processing Record 32 of Set 11 ---&gt; sept-iles
# Processing Record 33 of Set 11 ---&gt; teberda
# Processing Record 34 of Set 11 ---&gt; svetlogorsk
# Processing Record 35 of Set 11 ---&gt; hovd
# Processing Record 36 of Set 11 ---&gt; indian head
# Processing Record 37 of Set 11 ---&gt; kant
# Processing Record 38 of Set 11 ---&gt; ola
# Processing Record 39 of Set 11 ---&gt; yerbogachen
# Processing Record 40 of Set 11 ---&gt; manggar
# Processing Record 41 of Set 11 ---&gt; otjiwarongo
# Processing Record 42 of Set 11 ---&gt; nsukka
# Processing Record 43 of Set 11 ---&gt; port keats
# Processing Record 44 of Set 11 ---&gt; bardiyah
# Processing Record 45 of Set 11 ---&gt; port moresby
# Processing Record 46 of Set 11 ---&gt; jablah
# Processing Record 47 of Set 11 ---&gt; davila
# Processing Record 48 of Set 11 ---&gt; beyneu
# Processing Record 49 of Set 11 ---&gt; petropavlovsk-kamchatskiy
# Processing Record 50 of Set 11 ---&gt; yakeshi
# Processing Record 1 of Set 12 ---&gt; encruzilhada do sul
# Processing Record 2 of Set 12 ---&gt; vila franca do campo
# Processing Record 3 of Set 12 ---&gt; ontario
# Processing Record 4 of Set 12 ---&gt; okha
# Processing Record 5 of Set 12 ---&gt; korla
# Processing Record 6 of Set 12 ---&gt; dukat
# Processing Record 7 of Set 12 ---&gt; semey
# Processing Record 8 of Set 12 ---&gt; tiznit
# tarudant not found. Proceeding to the next city...
# Processing Record 9 of Set 12 ---&gt; san rafael del sur
# betare oya not found. Proceeding to the next city...
# Processing Record 10 of Set 12 ---&gt; tete
# Processing Record 11 of Set 12 ---&gt; ballina
# Processing Record 12 of Set 12 ---&gt; corrientes
# labutta not found. Proceeding to the next city...
# Processing Record 13 of Set 12 ---&gt; vardo
# Processing Record 14 of Set 12 ---&gt; agirish
# Processing Record 15 of Set 12 ---&gt; horadiz
# Processing Record 16 of Set 12 ---&gt; carutapera
# Processing Record 17 of Set 12 ---&gt; guerrero negro
# Processing Record 18 of Set 12 ---&gt; gimli
# Processing Record 19 of Set 12 ---&gt; san francisco del mar
# Processing Record 20 of Set 12 ---&gt; alihe
# Processing Record 21 of Set 12 ---&gt; taihe
# Processing Record 22 of Set 12 ---&gt; goderich
# Processing Record 23 of Set 12 ---&gt; tahoua
# Processing Record 24 of Set 12 ---&gt; makokou
# Processing Record 25 of Set 12 ---&gt; matamoros
# Processing Record 26 of Set 12 ---&gt; ilave
# Processing Record 27 of Set 12 ---&gt; senador jose porfirio
# Processing Record 28 of Set 12 ---&gt; eyl
# Processing Record 29 of Set 12 ---&gt; calama
# Processing Record 30 of Set 12 ---&gt; bangui
# joao pinheiro not found. Proceeding to the next city...
# Processing Record 31 of Set 12 ---&gt; mareeba
# Processing Record 32 of Set 12 ---&gt; vao
# Processing Record 33 of Set 12 ---&gt; palmer
# Processing Record 34 of Set 12 ---&gt; vanimo
# Processing Record 35 of Set 12 ---&gt; mnogovershinnyy
# Processing Record 36 of Set 12 ---&gt; ginir
# *******************************
# Data Retrieval Complete
# *******************************

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# The data generated from the API calls will be compiled into a new Data Fram
weather_data_frame = pd.DataFrame({
    'City':updated_city_list,
    'Lattitude':lattitude,
    'Longitude': longitude,
    'Max Temp': max_temp,
    'Humidity': humidity,
    'Cloudiness': cloudinesses,
    'Wind Speed': wind,
    'Country': country_list,
    'Date':dates
})

## Exporting the new DataFrame into a csv file
weather_data_frame.to_csv('..\Output_Data\Weather_Data_Collection.csv')

## Displaying the DataFrame
print(f'{weather_data_frame.shape[0]} cities, along with their weather information, have been collated\n')
weather_data_frame.head()
# Out:
# 586 cities, along with their weather information, have been collated
#        City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    atuona      -9.80    -139.03     25.76        78           4       10.65
# 1  klaksvik      62.23      -6.59     13.00        76          89        8.70
# 2    kodiak      57.79    -152.41     10.00        87          90       11.30
# 3  tasiilaq      65.61     -37.64      2.00        74         100       12.90
# 4   kabompo     -13.59      24.20     24.93        39           0        2.01
#
#   Country        Date
# 0      PF  1601619564
# 1      FO  1601619844
# 2      US  1601619845
# 3      GL  1601619818
# 4      ZM  1601619845

# %%
## Summary Statistics 
weather_data_frame.describe()
# Out:
#         Lattitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  586.000000  586.000000  586.000000  586.000000  586.000000  586.000000
# mean    22.045904   23.690819   18.418771   71.397611   53.819113    3.532440
# std     31.267486   85.962617    9.530631   20.283308   38.177472    2.537811
# min    -54.800000 -179.170000   -8.230000    9.000000    0.000000    0.160000
# 25%     -2.562500  -40.227500   10.560000   60.250000   17.000000    1.762500
# 50%     23.630000   26.250000   20.560000   75.000000   60.500000    3.015000
# 75%     48.185000   91.305000   26.280000   87.000000   90.000000    4.607500
# max     78.220000  179.320000   36.000000  100.000000  100.000000   23.910000
#
#                Date
# count  5.860000e+02
# mean   1.601620e+09
# std    1.249592e+02
# min    1.601619e+09
# 25%    1.601620e+09
# 50%    1.601620e+09
# 75%    1.601620e+09
# max    1.601620e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking to see if there are cities with humidities over 100
weather_data_frame[weather_data_frame['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lattitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames_Over100 = weather_data_frame[weather_data_frame['Humidity']>100].index

# %%
if (len(indexNames_Over100)) > 0:
    print(f'There are cities with humidity over 100')
else:
    print(f'There are no cities with humidity over 100')
# Out:
# There are no cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data_frame.drop(indexNames_Over100, inplace=False)

# %%
print(f'There are {clean_city_data.shape[0]} cities to be assessed\n')
clean_city_data.head()
# Out:
# There are 586 cities to be assessed
#        City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    atuona      -9.80    -139.03     25.76        78           4       10.65
# 1  klaksvik      62.23      -6.59     13.00        76          89        8.70
# 2    kodiak      57.79    -152.41     10.00        87          90       11.30
# 3  tasiilaq      65.61     -37.64      2.00        74         100       12.90
# 4   kabompo     -13.59      24.20     24.93        39           0        2.01
#
#   Country        Date
# 0      PF  1601619564
# 1      FO  1601619844
# 2      US  1601619845
# 3      GL  1601619818
# 4      ZM  1601619845

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# A scatter plot will be used in order to determine the relationship between temperature and lattitudes


x_lattitude = clean_city_data['Lattitude']
y_temperature = clean_city_data['Max Temp']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Temperature\n Analysed on {current_time}',fontsize=15)
ax1.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_temperature, edgecolors='black', c='#eb63c6')
ax1.grid(True)

fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Temperature.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# We will use the previous x_label and create a new Y label pertaining to humidity
y_humidity = clean_city_data['Humidity']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Humidity\n Analysed on {current_time}',fontsize=15)
ax1.set_ylabel('Humidity', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_humidity, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Humidity.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# We will set a new y_ variable pertaining to Cloudiness
y_cloudiness = clean_city_data['Cloudiness']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Cloudiness\nAnalysed on {current_time}',fontsize=15)
ax1.set_ylabel('Cloudiness(%)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_cloudiness, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Cloudiness.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# We wil set a new y_ variable pertaining to Wind Speed
y_windspeed = clean_city_data['Wind Speed']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Wind Speed\nAnalysed on {current_time}',fontsize=15)
ax1.set_ylabel('Wind Speed (mph)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_windspeed, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_WindSpeed.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Northern Hemisphere Latitudes vs Max Temperature

# %%
# All cities within the Northern Hemisphere will be in the lattitude range of 0(equator) to 90. 
# We will need to filter the dataframe to contain cities within the northern hemisphere (nh)

northern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']>=0]

x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_max_temp = northern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_max_temp)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Max Temp vs. Latitude Linear Regression\nAnalysed on {current_time}',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Max_Temp.png')
print(f'The r-squaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-squaured value is 0.7291721082333348
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# All cities within the Southern Hemisphere will be in the lattitude range of 0(equator) to -90. 
# We will need to filter the dataframe to contain cities within the southern hemisphere (sh)

southern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']<=0]

x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_max_temp = southern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_max_temp)

# Linear Regression Label
line_eq_sh = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit_sh = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Max Temp vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit_sh,'black')
ax2.scatter(x_sh_latitude,y_sh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.40788550437133836
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_humidity = northern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Humidity vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.02412172386918369
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_humidity = southern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Humidity vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.03575958226774321
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_cloudiness = northern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Cloudiness vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.012153472765590043
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_cloudiness = southern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Cloudiness vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.014625706791926917
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_windspeed = northern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Windspeed vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Windspeed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.041006220417962
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_windspeed = southern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Wind Speed vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Wind Speed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.12008772299568082
# &lt;Figure size 432x288 with 1 Axes&gt;

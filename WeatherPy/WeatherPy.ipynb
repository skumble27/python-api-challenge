# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing the relevant modules for weather analyses
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import scipy.stats as st

# Importing the API Key
from api_keys import weather_api_key

# Setting Unit of Measurement for Temperature
celsius ='metric'

# Setting up the query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={celsius}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# Preparing lists to store random lattitude and longitude coordinates
random_lat_long = []
city_names = []

# Creting Random Lattitudes
ran_lattitude = np.random.uniform(low=-90.000, high=90.000, size=1500)
ran_longitude = np.random.uniform(low=-180.000, high=180.000, size=1500)
random_lat_long = zip(ran_lattitude,ran_longitude)

# Assigning the nearest city to the coordinates
for lat_long in random_lat_long:
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name

    # Ensuring only unique city names are added
    if city in city_names:
        next
    else:
        city_names.append(city)
print(f'The number of cities added are {len(city_names)}')
# Out:
# The number of cities added are 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
updated_city_list = []
cloudinesses = []
dates = []
humidity = []
lattitude = []
longitude = []
max_temp = []
wind = []
country_list = []

# set initial count quantities for organization
record_number = 0
record_sets = 1

# loops for creating dataframe columns
print(f'Data Retreival commencing\n---------------------\n')
for city in city_names:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lattitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        if record_number > 49:
            record_number = 1
            record_sets += 1
            updated_city_list.append(city)
        else:
            record_number += 1
            updated_city_list.append(city)
        print(f"Processing Record {record_number} of Set {record_sets} ---> {city}")
    except Exception:
        print(f"{city} not found. Proceeding to the next city...")
print("*******************************")
print("Data Retrieval Complete\n*******************************")
# Out:
# Data Retreival commencing
# ---------------------
#
# Processing Record 1 of Set 1 ---&gt; pindwara
# Processing Record 2 of Set 1 ---&gt; linxia
# Processing Record 3 of Set 1 ---&gt; kiblawan
# Processing Record 4 of Set 1 ---&gt; atuona
# Processing Record 5 of Set 1 ---&gt; kavieng
# Processing Record 6 of Set 1 ---&gt; dikson
# belushya guba not found. Proceeding to the next city...
# Processing Record 7 of Set 1 ---&gt; mingshui
# Processing Record 8 of Set 1 ---&gt; srednekolymsk
# Processing Record 9 of Set 1 ---&gt; busselton
# Processing Record 10 of Set 1 ---&gt; san lawrenz
# Processing Record 11 of Set 1 ---&gt; port alfred
# Processing Record 12 of Set 1 ---&gt; hermanus
# Processing Record 13 of Set 1 ---&gt; nanortalik
# Processing Record 14 of Set 1 ---&gt; kodiak
# Processing Record 15 of Set 1 ---&gt; finschhafen
# Processing Record 16 of Set 1 ---&gt; kauhajoki
# Processing Record 17 of Set 1 ---&gt; ancud
# Processing Record 18 of Set 1 ---&gt; albany
# Processing Record 19 of Set 1 ---&gt; rikitea
# Processing Record 20 of Set 1 ---&gt; ribeira grande
# Processing Record 21 of Set 1 ---&gt; seymchan
# Processing Record 22 of Set 1 ---&gt; cidreira
# Processing Record 23 of Set 1 ---&gt; tasiilaq
# Processing Record 24 of Set 1 ---&gt; guangyuan
# Processing Record 25 of Set 1 ---&gt; salalah
# taolanaro not found. Proceeding to the next city...
# Processing Record 26 of Set 1 ---&gt; mataura
# Processing Record 27 of Set 1 ---&gt; verkh-usugli
# Processing Record 28 of Set 1 ---&gt; iwaki
# Processing Record 29 of Set 1 ---&gt; urucara
# Processing Record 30 of Set 1 ---&gt; mar del plata
# attawapiskat not found. Proceeding to the next city...
# Processing Record 31 of Set 1 ---&gt; touros
# Processing Record 32 of Set 1 ---&gt; mount gambier
# Processing Record 33 of Set 1 ---&gt; mogadishu
# Processing Record 34 of Set 1 ---&gt; oneonta
# Processing Record 35 of Set 1 ---&gt; saint-pierre
# Processing Record 36 of Set 1 ---&gt; san patricio
# Processing Record 37 of Set 1 ---&gt; gat
# Processing Record 38 of Set 1 ---&gt; bay city
# Processing Record 39 of Set 1 ---&gt; torbay
# Processing Record 40 of Set 1 ---&gt; esperance
# Processing Record 41 of Set 1 ---&gt; new norfolk
# Processing Record 42 of Set 1 ---&gt; lom sak
# Processing Record 43 of Set 1 ---&gt; jalu
# aflu not found. Proceeding to the next city...
# Processing Record 44 of Set 1 ---&gt; grand river south east
# Processing Record 45 of Set 1 ---&gt; castro
# Processing Record 46 of Set 1 ---&gt; kapaa
# Processing Record 47 of Set 1 ---&gt; ushuaia
# Processing Record 48 of Set 1 ---&gt; elbrus
# Processing Record 49 of Set 1 ---&gt; upington
# Processing Record 50 of Set 1 ---&gt; iqaluit
# Processing Record 1 of Set 2 ---&gt; vaini
# Processing Record 2 of Set 2 ---&gt; bronnoysund
# te anau not found. Proceeding to the next city...
# Processing Record 3 of Set 2 ---&gt; butaritari
# Processing Record 4 of Set 2 ---&gt; avera
# Processing Record 5 of Set 2 ---&gt; bredasdorp
# Processing Record 6 of Set 2 ---&gt; ndele
# Processing Record 7 of Set 2 ---&gt; cape town
# gulshat not found. Proceeding to the next city...
# Processing Record 8 of Set 2 ---&gt; saint-philippe
# Processing Record 9 of Set 2 ---&gt; ucluelet
# Processing Record 10 of Set 2 ---&gt; mys shmidta
# Processing Record 11 of Set 2 ---&gt; caravelas
# Processing Record 12 of Set 2 ---&gt; ponta do sol
# Processing Record 13 of Set 2 ---&gt; toora-khem
# Processing Record 14 of Set 2 ---&gt; havelock
# Processing Record 15 of Set 2 ---&gt; jamestown
# Processing Record 16 of Set 2 ---&gt; ahuimanu
# Processing Record 17 of Set 2 ---&gt; balkanabat
# Processing Record 18 of Set 2 ---&gt; yellowknife
# barentsburg not found. Proceeding to the next city...
# phrai bung not found. Proceeding to the next city...
# Processing Record 19 of Set 2 ---&gt; bitkine
# shahr-e babak not found. Proceeding to the next city...
# Processing Record 20 of Set 2 ---&gt; biltine
# Processing Record 21 of Set 2 ---&gt; sayyan
# Processing Record 22 of Set 2 ---&gt; east london
# Processing Record 23 of Set 2 ---&gt; namatanai
# Processing Record 24 of Set 2 ---&gt; almaznyy
# Processing Record 25 of Set 2 ---&gt; jabinyanah
# illoqqortoormiut not found. Proceeding to the next city...
# Processing Record 26 of Set 2 ---&gt; barkot
# Processing Record 27 of Set 2 ---&gt; bethel
# Processing Record 28 of Set 2 ---&gt; katsuura
# Processing Record 29 of Set 2 ---&gt; severo-kurilsk
# saint george not found. Proceeding to the next city...
# Processing Record 30 of Set 2 ---&gt; hofn
# Processing Record 31 of Set 2 ---&gt; hervey bay
# Processing Record 32 of Set 2 ---&gt; mutoko
# Processing Record 33 of Set 2 ---&gt; robore
# Processing Record 34 of Set 2 ---&gt; charlestown
# Processing Record 35 of Set 2 ---&gt; puerto escondido
# Processing Record 36 of Set 2 ---&gt; husavik
# Processing Record 37 of Set 2 ---&gt; padang
# Processing Record 38 of Set 2 ---&gt; yanji
# Processing Record 39 of Set 2 ---&gt; gurupa
# Processing Record 40 of Set 2 ---&gt; puerto ayora
# Processing Record 41 of Set 2 ---&gt; barzas
# Processing Record 42 of Set 2 ---&gt; labuhan
# Processing Record 43 of Set 2 ---&gt; kargil
# Processing Record 44 of Set 2 ---&gt; qaanaaq
# Processing Record 45 of Set 2 ---&gt; kurilsk
# Processing Record 46 of Set 2 ---&gt; lompoc
# Processing Record 47 of Set 2 ---&gt; bluff
# Processing Record 48 of Set 2 ---&gt; mackay
# Processing Record 49 of Set 2 ---&gt; itaituba
# Processing Record 50 of Set 2 ---&gt; taylorville
# Processing Record 1 of Set 3 ---&gt; kabalo
# Processing Record 2 of Set 3 ---&gt; faanui
# saleaula not found. Proceeding to the next city...
# Processing Record 3 of Set 3 ---&gt; tairua
# Processing Record 4 of Set 3 ---&gt; provideniya
# Processing Record 5 of Set 3 ---&gt; cuamba
# Processing Record 6 of Set 3 ---&gt; krasnoselkup
# Processing Record 7 of Set 3 ---&gt; hilo
# Processing Record 8 of Set 3 ---&gt; talcahuano
# Processing Record 9 of Set 3 ---&gt; bambous virieux
# Processing Record 10 of Set 3 ---&gt; longyearbyen
# Processing Record 11 of Set 3 ---&gt; aleppo
# Processing Record 12 of Set 3 ---&gt; barrow
# Processing Record 13 of Set 3 ---&gt; chokurdakh
# Processing Record 14 of Set 3 ---&gt; nome
# Processing Record 15 of Set 3 ---&gt; tuktoyaktuk
# Processing Record 16 of Set 3 ---&gt; nikolskoye
# Processing Record 17 of Set 3 ---&gt; tiksi
# Processing Record 18 of Set 3 ---&gt; leningradskiy
# Processing Record 19 of Set 3 ---&gt; hailin
# calpan not found. Proceeding to the next city...
# le port not found. Proceeding to the next city...
# Processing Record 20 of Set 3 ---&gt; upernavik
# Processing Record 21 of Set 3 ---&gt; flin flon
# Processing Record 22 of Set 3 ---&gt; rawson
# Processing Record 23 of Set 3 ---&gt; san cristobal
# Processing Record 24 of Set 3 ---&gt; mahebourg
# Processing Record 25 of Set 3 ---&gt; axim
# tsihombe not found. Proceeding to the next city...
# Processing Record 26 of Set 3 ---&gt; ghatanji
# Processing Record 27 of Set 3 ---&gt; punta arenas
# Processing Record 28 of Set 3 ---&gt; dunedin
# Processing Record 29 of Set 3 ---&gt; vardo
# Processing Record 30 of Set 3 ---&gt; thompson
# Processing Record 31 of Set 3 ---&gt; nouadhibou
# Processing Record 32 of Set 3 ---&gt; leh
# Processing Record 33 of Set 3 ---&gt; kamina
# Processing Record 34 of Set 3 ---&gt; burns lake
# Processing Record 35 of Set 3 ---&gt; pevek
# Processing Record 36 of Set 3 ---&gt; najran
# Processing Record 37 of Set 3 ---&gt; kilindoni
# Processing Record 38 of Set 3 ---&gt; saskylakh
# Processing Record 39 of Set 3 ---&gt; victoria
# Processing Record 40 of Set 3 ---&gt; kaitangata
# Processing Record 41 of Set 3 ---&gt; tazovskiy
# Processing Record 42 of Set 3 ---&gt; atar
# Processing Record 43 of Set 3 ---&gt; atchison
# Processing Record 44 of Set 3 ---&gt; aklavik
# Processing Record 45 of Set 3 ---&gt; khvoynaya
# Processing Record 46 of Set 3 ---&gt; tautira
# Processing Record 47 of Set 3 ---&gt; talnakh
# nizhneyansk not found. Proceeding to the next city...
# Processing Record 48 of Set 3 ---&gt; sao filipe
# Processing Record 49 of Set 3 ---&gt; benghazi
# Processing Record 50 of Set 3 ---&gt; ilulissat
# Processing Record 1 of Set 4 ---&gt; hobart
# Processing Record 2 of Set 4 ---&gt; saint-augustin
# Processing Record 3 of Set 4 ---&gt; codrington
# Processing Record 4 of Set 4 ---&gt; narsaq
# Processing Record 5 of Set 4 ---&gt; garissa
# Processing Record 6 of Set 4 ---&gt; olafsvik
# Processing Record 7 of Set 4 ---&gt; uglovskoye
# Processing Record 8 of Set 4 ---&gt; minna
# Processing Record 9 of Set 4 ---&gt; cururupu
# Processing Record 10 of Set 4 ---&gt; juanjui
# Processing Record 11 of Set 4 ---&gt; sitka
# Processing Record 12 of Set 4 ---&gt; chapais
# hvide sande not found. Proceeding to the next city...
# Processing Record 13 of Set 4 ---&gt; les cayes
# Processing Record 14 of Set 4 ---&gt; arraial do cabo
# Processing Record 15 of Set 4 ---&gt; vestmannaeyjar
# Processing Record 16 of Set 4 ---&gt; ayr
# Processing Record 17 of Set 4 ---&gt; falam
# Processing Record 18 of Set 4 ---&gt; pangnirtung
# Processing Record 19 of Set 4 ---&gt; georgetown
# Processing Record 20 of Set 4 ---&gt; colares
# Processing Record 21 of Set 4 ---&gt; half moon bay
# Processing Record 22 of Set 4 ---&gt; tezu
# Processing Record 23 of Set 4 ---&gt; san ramon
# Processing Record 24 of Set 4 ---&gt; mbanza-ngungu
# Processing Record 25 of Set 4 ---&gt; kemijarvi
# Processing Record 26 of Set 4 ---&gt; high level
# Processing Record 27 of Set 4 ---&gt; ahipara
# Processing Record 28 of Set 4 ---&gt; hasaki
# Processing Record 29 of Set 4 ---&gt; anadyr
# Processing Record 30 of Set 4 ---&gt; arman
# Processing Record 31 of Set 4 ---&gt; augustow
# Processing Record 32 of Set 4 ---&gt; korinos
# Processing Record 33 of Set 4 ---&gt; holme
# toliary not found. Proceeding to the next city...
# Processing Record 34 of Set 4 ---&gt; airai
# Processing Record 35 of Set 4 ---&gt; cabo san lucas
# Processing Record 36 of Set 4 ---&gt; constitucion
# Processing Record 37 of Set 4 ---&gt; bereda
# Processing Record 38 of Set 4 ---&gt; port elizabeth
# Processing Record 39 of Set 4 ---&gt; alofi
# Processing Record 40 of Set 4 ---&gt; candido de abreu
# Processing Record 41 of Set 4 ---&gt; hithadhoo
# Processing Record 42 of Set 4 ---&gt; brae
# Processing Record 43 of Set 4 ---&gt; noumea
# Processing Record 44 of Set 4 ---&gt; karratha
# Processing Record 45 of Set 4 ---&gt; adrar
# Processing Record 46 of Set 4 ---&gt; praia da vitoria
# Processing Record 47 of Set 4 ---&gt; lovozero
# Processing Record 48 of Set 4 ---&gt; pisco
# Processing Record 49 of Set 4 ---&gt; ulladulla
# Processing Record 50 of Set 4 ---&gt; banjar
# Processing Record 1 of Set 5 ---&gt; oskarshamn
# Processing Record 2 of Set 5 ---&gt; bushehr
# Processing Record 3 of Set 5 ---&gt; vera cruz
# Processing Record 4 of Set 5 ---&gt; ostrovnoy
# Processing Record 5 of Set 5 ---&gt; katobu
# Processing Record 6 of Set 5 ---&gt; panguna
# Processing Record 7 of Set 5 ---&gt; kununurra
# Processing Record 8 of Set 5 ---&gt; santa rosa
# the valley not found. Proceeding to the next city...
# Processing Record 9 of Set 5 ---&gt; port macquarie
# Processing Record 10 of Set 5 ---&gt; zambezi
# Processing Record 11 of Set 5 ---&gt; nosy varika
# Processing Record 12 of Set 5 ---&gt; lagoa
# Processing Record 13 of Set 5 ---&gt; ulaanbaatar
# Processing Record 14 of Set 5 ---&gt; geraldton
# Processing Record 15 of Set 5 ---&gt; takoradi
# Processing Record 16 of Set 5 ---&gt; zhuravka
# venustiano carranza not found. Proceeding to the next city...
# Processing Record 17 of Set 5 ---&gt; kahului
# Processing Record 18 of Set 5 ---&gt; huescar
# Processing Record 19 of Set 5 ---&gt; buenos aires
# utiroa not found. Proceeding to the next city...
# Processing Record 20 of Set 5 ---&gt; formosa
# Processing Record 21 of Set 5 ---&gt; dingle
# Processing Record 22 of Set 5 ---&gt; opuwo
# Processing Record 23 of Set 5 ---&gt; grindavik
# Processing Record 24 of Set 5 ---&gt; ardahan
# Processing Record 25 of Set 5 ---&gt; pedernales
# Processing Record 26 of Set 5 ---&gt; kabanjahe
# Processing Record 27 of Set 5 ---&gt; chuy
# Processing Record 28 of Set 5 ---&gt; vila
# Processing Record 29 of Set 5 ---&gt; belmonte
# Processing Record 30 of Set 5 ---&gt; bodden town
# Processing Record 31 of Set 5 ---&gt; lakshettipet
# Processing Record 32 of Set 5 ---&gt; irtyshskiy
# Processing Record 33 of Set 5 ---&gt; pangkalanbuun
# Processing Record 34 of Set 5 ---&gt; kargopol
# usva not found. Proceeding to the next city...
# Processing Record 35 of Set 5 ---&gt; tual
# Processing Record 36 of Set 5 ---&gt; pahrump
# Processing Record 37 of Set 5 ---&gt; cabra
# Processing Record 38 of Set 5 ---&gt; teahupoo
# Processing Record 39 of Set 5 ---&gt; klaksvik
# Processing Record 40 of Set 5 ---&gt; avarua
# Processing Record 41 of Set 5 ---&gt; kodinar
# Processing Record 42 of Set 5 ---&gt; aden
# Processing Record 43 of Set 5 ---&gt; port blair
# Processing Record 44 of Set 5 ---&gt; meulaboh
# palabuhanratu not found. Proceeding to the next city...
# Processing Record 45 of Set 5 ---&gt; evensk
# Processing Record 46 of Set 5 ---&gt; samarai
# Processing Record 47 of Set 5 ---&gt; trofors
# Processing Record 48 of Set 5 ---&gt; qandala
# Processing Record 49 of Set 5 ---&gt; swan river
# Processing Record 50 of Set 5 ---&gt; akdepe
# Processing Record 1 of Set 6 ---&gt; isangel
# Processing Record 2 of Set 6 ---&gt; lata
# Processing Record 3 of Set 6 ---&gt; ranong
# Processing Record 4 of Set 6 ---&gt; biala podlaska
# ijaki not found. Proceeding to the next city...
# Processing Record 5 of Set 6 ---&gt; santiago del estero
# Processing Record 6 of Set 6 ---&gt; khatanga
# Processing Record 7 of Set 6 ---&gt; acarau
# Processing Record 8 of Set 6 ---&gt; tura
# Processing Record 9 of Set 6 ---&gt; ponta delgada
# Processing Record 10 of Set 6 ---&gt; leiyang
# Processing Record 11 of Set 6 ---&gt; trelew
# umm lajj not found. Proceeding to the next city...
# Processing Record 12 of Set 6 ---&gt; komsomolskiy
# Processing Record 13 of Set 6 ---&gt; visby
# Processing Record 14 of Set 6 ---&gt; matamoros
# Processing Record 15 of Set 6 ---&gt; harlingen
# Processing Record 16 of Set 6 ---&gt; bansang
# Processing Record 17 of Set 6 ---&gt; atambua
# Processing Record 18 of Set 6 ---&gt; pokrovsk
# Processing Record 19 of Set 6 ---&gt; shimoda
# vaitupu not found. Proceeding to the next city...
# Processing Record 20 of Set 6 ---&gt; nishihara
# Processing Record 21 of Set 6 ---&gt; oranjestad
# Processing Record 22 of Set 6 ---&gt; biak
# Processing Record 23 of Set 6 ---&gt; bulgan
# safwah not found. Proceeding to the next city...
# Processing Record 24 of Set 6 ---&gt; zeya
# Processing Record 25 of Set 6 ---&gt; lebu
# Processing Record 26 of Set 6 ---&gt; maragogi
# Processing Record 27 of Set 6 ---&gt; bengkulu
# Processing Record 28 of Set 6 ---&gt; gold coast
# los llanos de aridane not found. Proceeding to the next city...
# Processing Record 29 of Set 6 ---&gt; oussouye
# Processing Record 30 of Set 6 ---&gt; price
# Processing Record 31 of Set 6 ---&gt; halifax
# Processing Record 32 of Set 6 ---&gt; saldanha
# Processing Record 33 of Set 6 ---&gt; taybad
# Processing Record 34 of Set 6 ---&gt; deputatskiy
# Processing Record 35 of Set 6 ---&gt; vanimo
# Processing Record 36 of Set 6 ---&gt; mount isa
# Processing Record 37 of Set 6 ---&gt; valdivia
# Processing Record 38 of Set 6 ---&gt; fort frances
# Processing Record 39 of Set 6 ---&gt; nantucket
# yirol not found. Proceeding to the next city...
# Processing Record 40 of Set 6 ---&gt; bam
# Processing Record 41 of Set 6 ---&gt; balaguer
# Processing Record 42 of Set 6 ---&gt; wagar
# Processing Record 43 of Set 6 ---&gt; kropotkin
# Processing Record 44 of Set 6 ---&gt; canico
# Processing Record 45 of Set 6 ---&gt; cherskiy
# Processing Record 46 of Set 6 ---&gt; gilgit
# Processing Record 47 of Set 6 ---&gt; portobelo
# Processing Record 48 of Set 6 ---&gt; oudtshoorn
# Processing Record 49 of Set 6 ---&gt; kalispell
# Processing Record 50 of Set 6 ---&gt; saint-georges
# Processing Record 1 of Set 7 ---&gt; kommunar
# Processing Record 2 of Set 7 ---&gt; harper
# Processing Record 3 of Set 7 ---&gt; tres arroyos
# duz not found. Proceeding to the next city...
# Processing Record 4 of Set 7 ---&gt; sola
# Processing Record 5 of Set 7 ---&gt; puerto del rosario
# Processing Record 6 of Set 7 ---&gt; sai buri
# Processing Record 7 of Set 7 ---&gt; zhezkazgan
# Processing Record 8 of Set 7 ---&gt; pacific grove
# Processing Record 9 of Set 7 ---&gt; sotnikovskoye
# Processing Record 10 of Set 7 ---&gt; shitanjing
# Processing Record 11 of Set 7 ---&gt; dunda
# Processing Record 12 of Set 7 ---&gt; luderitz
# Processing Record 13 of Set 7 ---&gt; laguna
# Processing Record 14 of Set 7 ---&gt; carlow
# Processing Record 15 of Set 7 ---&gt; andenes
# Processing Record 16 of Set 7 ---&gt; port hardy
# Processing Record 17 of Set 7 ---&gt; along
# Processing Record 18 of Set 7 ---&gt; liwale
# Processing Record 19 of Set 7 ---&gt; tahoua
# Processing Record 20 of Set 7 ---&gt; norman wells
# Processing Record 21 of Set 7 ---&gt; chumikan
# Processing Record 22 of Set 7 ---&gt; vitim
# Processing Record 23 of Set 7 ---&gt; klyuchi
# los angeles not found. Proceeding to the next city...
# Processing Record 24 of Set 7 ---&gt; paamiut
# kamenskoye not found. Proceeding to the next city...
# Processing Record 25 of Set 7 ---&gt; amahai
# Processing Record 26 of Set 7 ---&gt; north platte
# zhitikara not found. Proceeding to the next city...
# Processing Record 27 of Set 7 ---&gt; kavaratti
# Processing Record 28 of Set 7 ---&gt; oktyabrskiy
# samusu not found. Proceeding to the next city...
# Processing Record 29 of Set 7 ---&gt; korla
# Processing Record 30 of Set 7 ---&gt; kingisepp
# Processing Record 31 of Set 7 ---&gt; mahibadhoo
# Processing Record 32 of Set 7 ---&gt; puquio
# Processing Record 33 of Set 7 ---&gt; cedar city
# galgani not found. Proceeding to the next city...
# Processing Record 34 of Set 7 ---&gt; nuuk
# Processing Record 35 of Set 7 ---&gt; lorengau
# Processing Record 36 of Set 7 ---&gt; kolokani
# Processing Record 37 of Set 7 ---&gt; sao luis
# show low not found. Proceeding to the next city...
# tuggurt not found. Proceeding to the next city...
# Processing Record 38 of Set 7 ---&gt; bonavista
# Processing Record 39 of Set 7 ---&gt; razole
# Processing Record 40 of Set 7 ---&gt; hirara
# Processing Record 41 of Set 7 ---&gt; ambon
# Processing Record 42 of Set 7 ---&gt; santa rosalia
# Processing Record 43 of Set 7 ---&gt; mountain home
# Processing Record 44 of Set 7 ---&gt; makinsk
# Processing Record 45 of Set 7 ---&gt; warri
# Processing Record 46 of Set 7 ---&gt; byron bay
# Processing Record 47 of Set 7 ---&gt; tahe
# Processing Record 48 of Set 7 ---&gt; porto walter
# Processing Record 49 of Set 7 ---&gt; sydney
# Processing Record 50 of Set 7 ---&gt; sumter
# Processing Record 1 of Set 8 ---&gt; carnarvon
# Processing Record 2 of Set 8 ---&gt; cayenne
# Processing Record 3 of Set 8 ---&gt; beringovskiy
# Processing Record 4 of Set 8 ---&gt; wewak
# Processing Record 5 of Set 8 ---&gt; nemuro
# Processing Record 6 of Set 8 ---&gt; okhotsk
# la paz not found. Proceeding to the next city...
# Processing Record 7 of Set 8 ---&gt; mosjoen
# Processing Record 8 of Set 8 ---&gt; grand forks
# Processing Record 9 of Set 8 ---&gt; yeppoon
# Processing Record 10 of Set 8 ---&gt; port lincoln
# sentyabrskiy not found. Proceeding to the next city...
# Processing Record 11 of Set 8 ---&gt; majalgaon
# Processing Record 12 of Set 8 ---&gt; dalen
# Processing Record 13 of Set 8 ---&gt; sinamar
# Processing Record 14 of Set 8 ---&gt; kilcoole
# Processing Record 15 of Set 8 ---&gt; banes
# Processing Record 16 of Set 8 ---&gt; urengoy
# Processing Record 17 of Set 8 ---&gt; bosaso
# Processing Record 18 of Set 8 ---&gt; riwaka
# Processing Record 19 of Set 8 ---&gt; shizunai
# Processing Record 20 of Set 8 ---&gt; datong
# Processing Record 21 of Set 8 ---&gt; vila franca do campo
# Processing Record 22 of Set 8 ---&gt; kemise
# Processing Record 23 of Set 8 ---&gt; coquimbo
# Processing Record 24 of Set 8 ---&gt; sayat
# Processing Record 25 of Set 8 ---&gt; dukat
# Processing Record 26 of Set 8 ---&gt; guerrero negro
# Processing Record 27 of Set 8 ---&gt; samoded
# Processing Record 28 of Set 8 ---&gt; moose factory
# ust-kamchatsk not found. Proceeding to the next city...
# Processing Record 29 of Set 8 ---&gt; sao joao da barra
# Processing Record 30 of Set 8 ---&gt; talaya
# Processing Record 31 of Set 8 ---&gt; champerico
# pagman not found. Proceeding to the next city...
# Processing Record 32 of Set 8 ---&gt; pangody
# Processing Record 33 of Set 8 ---&gt; moerai
# mergui not found. Proceeding to the next city...
# Processing Record 34 of Set 8 ---&gt; mitsamiouli
# bazarnyye mataki not found. Proceeding to the next city...
# Processing Record 35 of Set 8 ---&gt; tulum
# Processing Record 36 of Set 8 ---&gt; malpe
# Processing Record 37 of Set 8 ---&gt; omboue
# Processing Record 38 of Set 8 ---&gt; berlevag
# Processing Record 39 of Set 8 ---&gt; asyut
# Processing Record 40 of Set 8 ---&gt; boa vista
# Processing Record 41 of Set 8 ---&gt; soro
# viligili not found. Proceeding to the next city...
# Processing Record 42 of Set 8 ---&gt; jega
# Processing Record 43 of Set 8 ---&gt; mecca
# Processing Record 44 of Set 8 ---&gt; cooma
# tasbuget not found. Proceeding to the next city...
# Processing Record 45 of Set 8 ---&gt; chambar
# Processing Record 46 of Set 8 ---&gt; torzhok
# Processing Record 47 of Set 8 ---&gt; segovia
# Processing Record 48 of Set 8 ---&gt; jumla
# Processing Record 49 of Set 8 ---&gt; sopelana
# Processing Record 50 of Set 8 ---&gt; omsukchan
# Processing Record 1 of Set 9 ---&gt; fairbanks
# velikiy novgorod not found. Proceeding to the next city...
# Processing Record 2 of Set 9 ---&gt; ayame
# Processing Record 3 of Set 9 ---&gt; ayacucho
# Processing Record 4 of Set 9 ---&gt; naze
# Processing Record 5 of Set 9 ---&gt; araouane
# Processing Record 6 of Set 9 ---&gt; tilichiki
# Processing Record 7 of Set 9 ---&gt; fortuna
# Processing Record 8 of Set 9 ---&gt; campos sales
# Processing Record 9 of Set 9 ---&gt; marawi
# Processing Record 10 of Set 9 ---&gt; arriaga
# Processing Record 11 of Set 9 ---&gt; clifton
# Processing Record 12 of Set 9 ---&gt; broome
# Processing Record 13 of Set 9 ---&gt; kadiri
# Processing Record 14 of Set 9 ---&gt; clarence town
# one hundred mile house not found. Proceeding to the next city...
# Processing Record 15 of Set 9 ---&gt; sulangan
# Processing Record 16 of Set 9 ---&gt; galle
# barbar not found. Proceeding to the next city...
# Processing Record 17 of Set 9 ---&gt; pemangkat
# bajram curri not found. Proceeding to the next city...
# Processing Record 18 of Set 9 ---&gt; lavumisa
# Processing Record 19 of Set 9 ---&gt; herat
# Processing Record 20 of Set 9 ---&gt; pathein
# Processing Record 21 of Set 9 ---&gt; batagay-alyta
# Processing Record 22 of Set 9 ---&gt; banjarmasin
# Processing Record 23 of Set 9 ---&gt; tomatlan
# Processing Record 24 of Set 9 ---&gt; oparino
# tawkar not found. Proceeding to the next city...
# Processing Record 25 of Set 9 ---&gt; ginda
# Processing Record 26 of Set 9 ---&gt; hamilton
# Processing Record 27 of Set 9 ---&gt; olinda
# Processing Record 28 of Set 9 ---&gt; bubaque
# barawe not found. Proceeding to the next city...
# Processing Record 29 of Set 9 ---&gt; teya
# Processing Record 30 of Set 9 ---&gt; sumbe
# Processing Record 31 of Set 9 ---&gt; eureka
# Processing Record 32 of Set 9 ---&gt; bida
# milingimbi not found. Proceeding to the next city...
# Processing Record 33 of Set 9 ---&gt; robe
# Processing Record 34 of Set 9 ---&gt; roald
# zachagansk not found. Proceeding to the next city...
# Processing Record 35 of Set 9 ---&gt; akureyri
# Processing Record 36 of Set 9 ---&gt; bilibino
# amderma not found. Proceeding to the next city...
# Processing Record 37 of Set 9 ---&gt; kepno
# Processing Record 38 of Set 9 ---&gt; necochea
# Processing Record 39 of Set 9 ---&gt; porto santo
# Processing Record 40 of Set 9 ---&gt; villa union
# Processing Record 41 of Set 9 ---&gt; muslyumovo
# Processing Record 42 of Set 9 ---&gt; neuquen
# Processing Record 43 of Set 9 ---&gt; troitsko-pechorsk
# Processing Record 44 of Set 9 ---&gt; baie-saint-paul
# Processing Record 45 of Set 9 ---&gt; mana
# Processing Record 46 of Set 9 ---&gt; lasa
# Processing Record 47 of Set 9 ---&gt; balsas
# Processing Record 48 of Set 9 ---&gt; finsterwalde
# Processing Record 49 of Set 9 ---&gt; dauriya
# Processing Record 50 of Set 9 ---&gt; okato
# Processing Record 1 of Set 10 ---&gt; kaeo
# Processing Record 2 of Set 10 ---&gt; oranjemund
# Processing Record 3 of Set 10 ---&gt; abilene
# Processing Record 4 of Set 10 ---&gt; taoudenni
# Processing Record 5 of Set 10 ---&gt; clyde river
# Processing Record 6 of Set 10 ---&gt; bozova
# Processing Record 7 of Set 10 ---&gt; ishigaki
# batemans bay not found. Proceeding to the next city...
# Processing Record 8 of Set 10 ---&gt; rio grande
# Processing Record 9 of Set 10 ---&gt; dharchula
# Processing Record 10 of Set 10 ---&gt; kongoussi
# Processing Record 11 of Set 10 ---&gt; alice springs
# Processing Record 12 of Set 10 ---&gt; mariana
# Processing Record 13 of Set 10 ---&gt; bunbury
# Processing Record 14 of Set 10 ---&gt; koumac
# Processing Record 15 of Set 10 ---&gt; jasper
# tidore not found. Proceeding to the next city...
# Processing Record 16 of Set 10 ---&gt; uruzgan
# Processing Record 17 of Set 10 ---&gt; marzuq
# Processing Record 18 of Set 10 ---&gt; camabatela
# Processing Record 19 of Set 10 ---&gt; llanes
# Processing Record 20 of Set 10 ---&gt; soyo
# Processing Record 21 of Set 10 ---&gt; kudahuvadhoo
# Processing Record 22 of Set 10 ---&gt; hay river
# Processing Record 23 of Set 10 ---&gt; fredericia
# Processing Record 24 of Set 10 ---&gt; san lorenzo
# Processing Record 25 of Set 10 ---&gt; gidole
# Processing Record 26 of Set 10 ---&gt; uddevalla
# Processing Record 27 of Set 10 ---&gt; poya
# Processing Record 28 of Set 10 ---&gt; westport
# Processing Record 29 of Set 10 ---&gt; grand gaube
# Processing Record 30 of Set 10 ---&gt; tanout
# Processing Record 31 of Set 10 ---&gt; aykhal
# Processing Record 32 of Set 10 ---&gt; disna
# Processing Record 33 of Set 10 ---&gt; vologda
# Processing Record 34 of Set 10 ---&gt; buluang
# Processing Record 35 of Set 10 ---&gt; altay
# Processing Record 36 of Set 10 ---&gt; tias
# Processing Record 37 of Set 10 ---&gt; luanda
# Processing Record 38 of Set 10 ---&gt; nola
# Processing Record 39 of Set 10 ---&gt; padilla
# Processing Record 40 of Set 10 ---&gt; mantua
# Processing Record 41 of Set 10 ---&gt; ayan
# Processing Record 42 of Set 10 ---&gt; luba
# Processing Record 43 of Set 10 ---&gt; surab
# Processing Record 44 of Set 10 ---&gt; uyar
# Processing Record 45 of Set 10 ---&gt; comodoro rivadavia
# Processing Record 46 of Set 10 ---&gt; adelaide
# Processing Record 47 of Set 10 ---&gt; roebourne
# Processing Record 48 of Set 10 ---&gt; uribia
# Processing Record 49 of Set 10 ---&gt; hobyo
# Processing Record 50 of Set 10 ---&gt; swellendam
# Processing Record 1 of Set 11 ---&gt; aksarka
# Processing Record 2 of Set 11 ---&gt; arti
# Processing Record 3 of Set 11 ---&gt; kloulklubed
# Processing Record 4 of Set 11 ---&gt; soe
# satitoa not found. Proceeding to the next city...
# Processing Record 5 of Set 11 ---&gt; sechura
# Processing Record 6 of Set 11 ---&gt; antofagasta
# Processing Record 7 of Set 11 ---&gt; zhangye
# Processing Record 8 of Set 11 ---&gt; williams lake
# Processing Record 9 of Set 11 ---&gt; ried
# Processing Record 10 of Set 11 ---&gt; aboso
# Processing Record 11 of Set 11 ---&gt; ugra
# Processing Record 12 of Set 11 ---&gt; ico
# Processing Record 13 of Set 11 ---&gt; gizo
# Processing Record 14 of Set 11 ---&gt; miri
# Processing Record 15 of Set 11 ---&gt; marfino
# Processing Record 16 of Set 11 ---&gt; leshukonskoye
# Processing Record 17 of Set 11 ---&gt; kidal
# Processing Record 18 of Set 11 ---&gt; nagod
# Processing Record 19 of Set 11 ---&gt; galveston
# Processing Record 20 of Set 11 ---&gt; mundwa
# Processing Record 21 of Set 11 ---&gt; santiago
# Processing Record 22 of Set 11 ---&gt; gazanjyk
# Processing Record 23 of Set 11 ---&gt; dakar
# Processing Record 24 of Set 11 ---&gt; pingzhuang
# Processing Record 25 of Set 11 ---&gt; uyskoye
# geresk not found. Proceeding to the next city...
# Processing Record 26 of Set 11 ---&gt; rafai
# Processing Record 27 of Set 11 ---&gt; vila velha
# Processing Record 28 of Set 11 ---&gt; muros
# Processing Record 29 of Set 11 ---&gt; petropavlovsk-kamchatskiy
# Processing Record 30 of Set 11 ---&gt; kirakira
# Processing Record 31 of Set 11 ---&gt; piranshahr
# Processing Record 32 of Set 11 ---&gt; zyryanka
# Processing Record 33 of Set 11 ---&gt; wajir
# Processing Record 34 of Set 11 ---&gt; tuatapere
# Processing Record 35 of Set 11 ---&gt; loikaw
# Processing Record 36 of Set 11 ---&gt; dobrinka
# Processing Record 37 of Set 11 ---&gt; sonamura
# Processing Record 38 of Set 11 ---&gt; naryan-mar
# *******************************
# Data Retrieval Complete
# *******************************

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# The data generated from the API calls will be compiled into a new Data Fram
weather_data_frame = pd.DataFrame({
    'City':updated_city_list,
    'Lattitude':lattitude,
    'Longitude': longitude,
    'Max Temp': max_temp,
    'Humidity': humidity,
    'Cloudiness': cloudinesses,
    'Wind Speed': wind,
    'Country': country_list,
    'Date':dates
})

## Exporting the new DataFrame into a csv file
weather_data_frame.to_csv('..\Output_Data\Weather_Data_Collection.csv')

## Displaying the DataFrame
print(f'{weather_data_frame.shape[0]} cities, along with their weather information, have been collated\n')
weather_data_frame.head()
# Out:
# 538 cities, along with their weather information, have been collated
#        City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pindwara      24.80      73.07     30.38        47           0        2.68
# 1    linxia      35.60     103.21     14.58        55          86        1.62
# 2  kiblawan       6.61     125.24     32.00        59          40        5.10
# 3    atuona      -9.80    -139.03     25.79        77           3        9.78
# 4   kavieng      -2.57     150.80     29.15        70          93        2.15
#
#   Country        Date
# 0      IN  1601527781
# 1      CN  1601527781
# 2      PH  1601527782
# 3      PF  1601527783
# 4      PG  1601527784

# %%
## Summary Statistics 
weather_data_frame.describe()
# Out:
#         Lattitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  538.000000  538.000000  538.000000  538.000000  538.000000  538.000000
# mean    22.934554   25.080651   17.628420   71.327138   50.496283    3.387993
# std     31.950808   85.763348    9.105769   20.451533   38.326406    2.287619
# min    -54.800000 -175.200000  -11.670000   10.000000    0.000000    0.230000
# 25%     -2.677500  -39.902500   11.000000   61.000000    8.000000    1.640000
# 50%     28.045000   23.040000   17.780000   75.000000   49.500000    3.000000
# 75%     48.792500   94.760000   25.385000   87.000000   90.000000    4.600000
# max     78.220000  179.320000   35.000000  100.000000  100.000000   12.000000
#
#                Date
# count  5.380000e+02
# mean   1.601528e+09
# std    1.129777e+02
# min    1.601527e+09
# 25%    1.601528e+09
# 50%    1.601528e+09
# 75%    1.601528e+09
# max    1.601528e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking to see if there are cities with humidities over 100
weather_data_frame[weather_data_frame['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lattitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames_Over100 = weather_data_frame[weather_data_frame['Humidity']>100].index

# %%
if (len(indexNames_Over100)) > 0:
    print(f'There are cities with humidity over 100')
else:
    print(f'There are no cities with humidity over 100')
# Out:
# There are no cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data_frame.drop(indexNames_Over100, inplace=False)

# %%
print(f'There are {clean_city_data.shape[0]} cities to be assessed\n')
clean_city_data.head()
# Out:
# There are 538 cities to be assessed
#        City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pindwara      24.80      73.07     30.38        47           0        2.68
# 1    linxia      35.60     103.21     14.58        55          86        1.62
# 2  kiblawan       6.61     125.24     32.00        59          40        5.10
# 3    atuona      -9.80    -139.03     25.79        77           3        9.78
# 4   kavieng      -2.57     150.80     29.15        70          93        2.15
#
#   Country        Date
# 0      IN  1601527781
# 1      CN  1601527781
# 2      PH  1601527782
# 3      PF  1601527783
# 4      PG  1601527784

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# A scatter plot will be used in order to determine the relationship between temperature and lattitudes
x_lattitude = clean_city_data['Lattitude']
y_temperature = clean_city_data['Max Temp']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Temperature',fontsize=15)
ax1.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_temperature, edgecolors='black', c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Temperature.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# We will use the previous x_label and create a new Y label pertaining to humidity
y_humidity = clean_city_data['Humidity']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Humidity',fontsize=15)
ax1.set_ylabel('Humidity', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_humidity, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Humidity.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# We will set a new y_ variable pertaining to Cloudiness
y_cloudiness = clean_city_data['Cloudiness']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Cloudiness',fontsize=15)
ax1.set_ylabel('Cloudiness(%)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_cloudiness, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Cloudiness.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# We wil set a new y_ variable pertaining to Wind Speed
y_windspeed = clean_city_data['Wind Speed']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Wind Speed',fontsize=15)
ax1.set_ylabel('Wind Speed (mph)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_windspeed, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_WindSpeed.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Northern Hemisphere Latitudes vs Max Temperature

# %%
# All cities within the Northern Hemisphere will be in the lattitude range of 0(equator) to 90. 
# We will need to filter the dataframe to contain cities within the northern hemisphere (nh)

northern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']>=0]

x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_max_temp = northern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_max_temp)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Max_Temp.png')
print(f'The r-squaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-squaured value is 0.7670510385963711
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# All cities within the Southern Hemisphere will be in the lattitude range of 0(equator) to -90. 
# We will need to filter the dataframe to contain cities within the southern hemisphere (sh)

southern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']<=0]

x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_max_temp = southern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_max_temp)

# Linear Regression Label
line_eq_sh = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit_sh = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit_sh,'black')
ax2.scatter(x_sh_latitude,y_sh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.5134902521819085
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_humidity = northern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.017670690528298227
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_humidity = southern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.011386720072344769
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_cloudiness = northern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.009843930331280712
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_cloudiness = southern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.008869425003408154
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_windspeed = northern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Windspeed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Windspeed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.011870473122641504
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_windspeed = southern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Wind Speed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Wind Speed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.046864425534734244
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing the relevant modules for weather analyses
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import scipy.stats as st

# Importing the API Key
from api_keys import weather_api_key

# Setting Unit of Measurement for Temperature
celsius ='metric'

# Setting up the query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={celsius}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# Preparing lists to store random lattitude and longitude coordinates
random_lat_long = []
city_names = []

# Creting Random Lattitudes
ran_lattitude = np.random.uniform(low=-90.000, high=90.000, size=1500)
ran_longitude = np.random.uniform(low=-180.000, high=180.000, size=1500)
random_lat_long = zip(ran_lattitude,ran_longitude)

# Assigning the nearest city to the coordinates
for lat_long in random_lat_long:
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name

    # Ensuring only unique city names are added
    if city in city_names:
        next
    else:
        city_names.append(city)
print(f'The number of cities added are {len(city_names)}')
# Out:
# The number of cities added are 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
updated_city_list = []
cloudinesses = []
dates = []
humidity = []
lattitude = []
longitude = []
max_temp = []
wind = []
country_list = []

# set initial count quantities for organization
record_number = 0
record_sets = 1

# loops for creating dataframe columns
print(f'Data Retreival commencing\n---------------------\n')
for city in city_names:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lattitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        if record_number > 49:
            record_number = 1
            record_sets += 1
            updated_city_list.append(city)
        else:
            record_number += 1
            updated_city_list.append(city)
        print(f"Processing Record {record_number} of Set {record_sets} ---> {city}")
    except Exception:
        print(f"{city} not found. Proceeding to the next city...")
print("*******************************")
print("Data Retrieval Complete\n*******************************")
# Out:
# Data Retreival commencing
# ---------------------
#
# Processing Record 1 of Set 1 ---> gazi
# Processing Record 2 of Set 1 ---> bluff
# Processing Record 3 of Set 1 ---> cape town
# Processing Record 4 of Set 1 ---> porto velho
# Processing Record 5 of Set 1 ---> mataura
# Processing Record 6 of Set 1 ---> ilulissat
# Processing Record 7 of Set 1 ---> kingussie
# Processing Record 8 of Set 1 ---> rikitea
# Processing Record 9 of Set 1 ---> east london
# Processing Record 10 of Set 1 ---> biak
# Processing Record 11 of Set 1 ---> harper
# Processing Record 12 of Set 1 ---> atuona
# Processing Record 13 of Set 1 ---> trinidad
# Processing Record 14 of Set 1 ---> agadir
# Processing Record 15 of Set 1 ---> port townsend
# amderma not found. Proceeding to the next city...
# Processing Record 16 of Set 1 ---> mahebourg
# Processing Record 17 of Set 1 ---> punta arenas
# Processing Record 18 of Set 1 ---> dingzhou
# Processing Record 19 of Set 1 ---> busselton
# Processing Record 20 of Set 1 ---> ushuaia
# Processing Record 21 of Set 1 ---> mar del plata
# Processing Record 22 of Set 1 ---> pechenga
# Processing Record 23 of Set 1 ---> vaini
# Processing Record 24 of Set 1 ---> naze
# Processing Record 25 of Set 1 ---> tigil
# Processing Record 26 of Set 1 ---> hermanus
# Processing Record 27 of Set 1 ---> anadyr
# Processing Record 28 of Set 1 ---> butaritari
# Processing Record 29 of Set 1 ---> silale
# Processing Record 30 of Set 1 ---> puerto ayora
# quatre cocos not found. Proceeding to the next city...
# Processing Record 31 of Set 1 ---> jinchang
# Processing Record 32 of Set 1 ---> homer
# Processing Record 33 of Set 1 ---> sohagpur
# Processing Record 34 of Set 1 ---> carnarvon
# Processing Record 35 of Set 1 ---> thompson
# Processing Record 36 of Set 1 ---> half moon bay
# taolanaro not found. Proceeding to the next city...
# Processing Record 37 of Set 1 ---> lebu
# Processing Record 38 of Set 1 ---> nara
# Processing Record 39 of Set 1 ---> san cristobal
# Processing Record 40 of Set 1 ---> bredasdorp
# Processing Record 41 of Set 1 ---> san jose
# Processing Record 42 of Set 1 ---> kahului
# Processing Record 43 of Set 1 ---> havoysund
# Processing Record 44 of Set 1 ---> kamloops
# barentsburg not found. Proceeding to the next city...
# Processing Record 45 of Set 1 ---> port blair
# Processing Record 46 of Set 1 ---> port alfred
# Processing Record 47 of Set 1 ---> mizdah
# illoqqortoormiut not found. Proceeding to the next city...
# Processing Record 48 of Set 1 ---> katsuura
# Processing Record 49 of Set 1 ---> geraldton
# Processing Record 50 of Set 1 ---> durban
# Processing Record 1 of Set 2 ---> nakatsu
# Processing Record 2 of Set 2 ---> sivaki
# Processing Record 3 of Set 2 ---> yatou
# Processing Record 4 of Set 2 ---> barrow
# Processing Record 5 of Set 2 ---> port augusta
# Processing Record 6 of Set 2 ---> zyryanskoye
# Processing Record 7 of Set 2 ---> new norfolk
# Processing Record 8 of Set 2 ---> kruisfontein
# Processing Record 9 of Set 2 ---> tuatapere
# eskasem not found. Proceeding to the next city...
# Processing Record 10 of Set 2 ---> pombas
# Processing Record 11 of Set 2 ---> jamestown
# Processing Record 12 of Set 2 ---> kirakira
# attawapiskat not found. Proceeding to the next city...
# Processing Record 13 of Set 2 ---> longyearbyen
# palabuhanratu not found. Proceeding to the next city...
# Processing Record 14 of Set 2 ---> sao pedro do sul
# Processing Record 15 of Set 2 ---> albany
# tuyen quang not found. Proceeding to the next city...
# urdzhar not found. Proceeding to the next city...
# Processing Record 16 of Set 2 ---> sorong
# batemans bay not found. Proceeding to the next city...
# Processing Record 17 of Set 2 ---> provideniya
# Processing Record 18 of Set 2 ---> arraial do cabo
# Processing Record 19 of Set 2 ---> benghazi
# Processing Record 20 of Set 2 ---> faya
# Processing Record 21 of Set 2 ---> kaitangata
# Processing Record 22 of Set 2 ---> ndele
# Processing Record 23 of Set 2 ---> san patricio
# Processing Record 24 of Set 2 ---> amarillo
# Processing Record 25 of Set 2 ---> grand river south east
# Processing Record 26 of Set 2 ---> bukachacha
# Processing Record 27 of Set 2 ---> nikolskoye
# Processing Record 28 of Set 2 ---> cherskiy
# Processing Record 29 of Set 2 ---> bethel
# Processing Record 30 of Set 2 ---> avarua
# Processing Record 31 of Set 2 ---> tasiilaq
# Processing Record 32 of Set 2 ---> gilgit
# Processing Record 33 of Set 2 ---> isangel
# Processing Record 34 of Set 2 ---> samarai
# Processing Record 35 of Set 2 ---> puerto del rosario
# Processing Record 36 of Set 2 ---> mys shmidta
# Processing Record 37 of Set 2 ---> torbay
# Processing Record 38 of Set 2 ---> cidreira
# Processing Record 39 of Set 2 ---> hilo
# Processing Record 40 of Set 2 ---> hithadhoo
# Processing Record 41 of Set 2 ---> myitkyina
# Processing Record 42 of Set 2 ---> lensk
# Processing Record 43 of Set 2 ---> rio grande
# Processing Record 44 of Set 2 ---> severo-kurilsk
# Processing Record 45 of Set 2 ---> meadow lake
# Processing Record 46 of Set 2 ---> vestmannaeyjar
# Processing Record 47 of Set 2 ---> kodiak
# Processing Record 48 of Set 2 ---> qaanaaq
# Processing Record 49 of Set 2 ---> jiwani
# Processing Record 50 of Set 2 ---> port elizabeth
# Processing Record 1 of Set 3 ---> fukue
# Processing Record 2 of Set 3 ---> bontang
# Processing Record 3 of Set 3 ---> grindavik
# Processing Record 4 of Set 3 ---> georgetown
# Processing Record 5 of Set 3 ---> norman wells
# Processing Record 6 of Set 3 ---> dikson
# saleaula not found. Proceeding to the next city...
# Processing Record 7 of Set 3 ---> chuy
# Processing Record 8 of Set 3 ---> luderitz
# Processing Record 9 of Set 3 ---> yellowknife
# Processing Record 10 of Set 3 ---> madison
# Processing Record 11 of Set 3 ---> xining
# Processing Record 12 of Set 3 ---> fowa
# Processing Record 13 of Set 3 ---> nome
# Processing Record 14 of Set 3 ---> tiksi
# Processing Record 15 of Set 3 ---> roma
# Processing Record 16 of Set 3 ---> pangnirtung
# Processing Record 17 of Set 3 ---> taree
# Processing Record 18 of Set 3 ---> japura
# Processing Record 19 of Set 3 ---> koslan
# Processing Record 20 of Set 3 ---> fairbanks
# Processing Record 21 of Set 3 ---> caucaia
# Processing Record 22 of Set 3 ---> lagoa
# Processing Record 23 of Set 3 ---> nanning
# Processing Record 24 of Set 3 ---> kapaa
# Processing Record 25 of Set 3 ---> bengkulu
# Processing Record 26 of Set 3 ---> tomatlan
# Processing Record 27 of Set 3 ---> poum
# Processing Record 28 of Set 3 ---> vila franca do campo
# Processing Record 29 of Set 3 ---> haines junction
# Processing Record 30 of Set 3 ---> hualmay
# khonuu not found. Proceeding to the next city...
# Processing Record 31 of Set 3 ---> saint-philippe
# Processing Record 32 of Set 3 ---> denpasar
# kamenskoye not found. Proceeding to the next city...
# Processing Record 33 of Set 3 ---> svetlyy
# Processing Record 34 of Set 3 ---> weihe
# Processing Record 35 of Set 3 ---> pacific grove
# Processing Record 36 of Set 3 ---> hobart
# Processing Record 37 of Set 3 ---> upernavik
# Processing Record 38 of Set 3 ---> asau
# Processing Record 39 of Set 3 ---> bay roberts
# Processing Record 40 of Set 3 ---> maningrida
# Processing Record 41 of Set 3 ---> beira
# Processing Record 42 of Set 3 ---> zalantun
# Processing Record 43 of Set 3 ---> tilichiki
# Processing Record 44 of Set 3 ---> sao jose da coroa grande
# Processing Record 45 of Set 3 ---> caravelas
# Processing Record 46 of Set 3 ---> apostolove
# Processing Record 47 of Set 3 ---> tsevie
# Processing Record 48 of Set 3 ---> birmitrapur
# Processing Record 49 of Set 3 ---> ilo
# Processing Record 50 of Set 3 ---> oranjestad
# Processing Record 1 of Set 4 ---> tommot
# Processing Record 2 of Set 4 ---> saldanha
# Processing Record 3 of Set 4 ---> keningau
# Processing Record 4 of Set 4 ---> causapscal
# Processing Record 5 of Set 4 ---> hay river
# mudyuga not found. Proceeding to the next city...
# Processing Record 6 of Set 4 ---> usinsk
# Processing Record 7 of Set 4 ---> hamilton
# Processing Record 8 of Set 4 ---> guerrero negro
# Processing Record 9 of Set 4 ---> ampanihy
# Processing Record 10 of Set 4 ---> narsaq
# Processing Record 11 of Set 4 ---> palmas de monte alto
# rungata not found. Proceeding to the next city...
# Processing Record 12 of Set 4 ---> bukama
# Processing Record 13 of Set 4 ---> flinders
# Processing Record 14 of Set 4 ---> tuktoyaktuk
# Processing Record 15 of Set 4 ---> tiznit
# Processing Record 16 of Set 4 ---> gushikawa
# Processing Record 17 of Set 4 ---> khatanga
# tungkang not found. Proceeding to the next city...
# los llanos de aridane not found. Proceeding to the next city...
# Processing Record 18 of Set 4 ---> bubaque
# Processing Record 19 of Set 4 ---> odienne
# Processing Record 20 of Set 4 ---> chokurdakh
# Processing Record 21 of Set 4 ---> eureka
# Processing Record 22 of Set 4 ---> ayan
# saint george not found. Proceeding to the next city...
# Processing Record 23 of Set 4 ---> colares
# Processing Record 24 of Set 4 ---> esperance
# saint anthony not found. Proceeding to the next city...
# Processing Record 25 of Set 4 ---> mnogovershinnyy
# artyk not found. Proceeding to the next city...
# Processing Record 26 of Set 4 ---> college
# Processing Record 27 of Set 4 ---> bilma
# taburao not found. Proceeding to the next city...
# Processing Record 28 of Set 4 ---> victoria
# Processing Record 29 of Set 4 ---> atambua
# Processing Record 30 of Set 4 ---> solton
# Processing Record 31 of Set 4 ---> pevek
# Processing Record 32 of Set 4 ---> billings
# Processing Record 33 of Set 4 ---> kastamonu
# Processing Record 34 of Set 4 ---> luganville
# Processing Record 35 of Set 4 ---> port hardy
# Processing Record 36 of Set 4 ---> sao filipe
# Processing Record 37 of Set 4 ---> mishan
# vaitupu not found. Proceeding to the next city...
# Processing Record 38 of Set 4 ---> vardo
# Processing Record 39 of Set 4 ---> salinas
# Processing Record 40 of Set 4 ---> bilibino
# Processing Record 41 of Set 4 ---> linxia
# Processing Record 42 of Set 4 ---> omboue
# Processing Record 43 of Set 4 ---> muli
# Processing Record 44 of Set 4 ---> mocuba
# Processing Record 45 of Set 4 ---> carbonia
# Processing Record 46 of Set 4 ---> verkhovazhye
# Processing Record 47 of Set 4 ---> namatanai
# Processing Record 48 of Set 4 ---> rawson
# Processing Record 49 of Set 4 ---> markova
# Processing Record 50 of Set 4 ---> tulsipur
# Processing Record 1 of Set 5 ---> alofi
# Processing Record 2 of Set 5 ---> yazman
# Processing Record 3 of Set 5 ---> khomutovka
# Processing Record 4 of Set 5 ---> airai
# Processing Record 5 of Set 5 ---> nantucket
# Processing Record 6 of Set 5 ---> saskylakh
# Processing Record 7 of Set 5 ---> ribeira grande
# Processing Record 8 of Set 5 ---> floro
# Processing Record 9 of Set 5 ---> san juan
# Processing Record 10 of Set 5 ---> tortoli
# Processing Record 11 of Set 5 ---> nizwa
# Processing Record 12 of Set 5 ---> tirlyanskiy
# Processing Record 13 of Set 5 ---> chateaubelair
# Processing Record 14 of Set 5 ---> cabedelo
# Processing Record 15 of Set 5 ---> bambous virieux
# belushya guba not found. Proceeding to the next city...
# umzimvubu not found. Proceeding to the next city...
# Processing Record 16 of Set 5 ---> altay
# Processing Record 17 of Set 5 ---> damnagar
# Processing Record 18 of Set 5 ---> lavrentiya
# Processing Record 19 of Set 5 ---> constitucion
# Processing Record 20 of Set 5 ---> ust-nera
# Processing Record 21 of Set 5 ---> evensk
# Processing Record 22 of Set 5 ---> ugoofaaru
# Processing Record 23 of Set 5 ---> jardim do serido
# Processing Record 24 of Set 5 ---> fortuna
# russkaya polyana not found. Proceeding to the next city...
# tumannyy not found. Proceeding to the next city...
# meyungs not found. Proceeding to the next city...
# Processing Record 25 of Set 5 ---> hervey bay
# Processing Record 26 of Set 5 ---> taoudenni
# Processing Record 27 of Set 5 ---> hammerfest
# Processing Record 28 of Set 5 ---> petropavlovsk-kamchatskiy
# Processing Record 29 of Set 5 ---> pogar
# Processing Record 30 of Set 5 ---> psebay
# Processing Record 31 of Set 5 ---> caico
# Processing Record 32 of Set 5 ---> bose
# Processing Record 33 of Set 5 ---> bima
# Processing Record 34 of Set 5 ---> turukhansk
# Processing Record 35 of Set 5 ---> dakar
# Processing Record 36 of Set 5 ---> inirida
# Processing Record 37 of Set 5 ---> darnah
# Processing Record 38 of Set 5 ---> sabang
# Processing Record 39 of Set 5 ---> port-cartier
# Processing Record 40 of Set 5 ---> sola
# Processing Record 41 of Set 5 ---> effium
# Processing Record 42 of Set 5 ---> meulaboh
# Processing Record 43 of Set 5 ---> olafsvik
# Processing Record 44 of Set 5 ---> strezhevoy
# Processing Record 45 of Set 5 ---> barabai
# mukhanovo not found. Proceeding to the next city...
# Processing Record 46 of Set 5 ---> lorengau
# Processing Record 47 of Set 5 ---> cam ranh
# Processing Record 48 of Set 5 ---> muisne
# Processing Record 49 of Set 5 ---> santiago del estero
# Processing Record 50 of Set 5 ---> bernalda
# Processing Record 1 of Set 6 ---> give
# Processing Record 2 of Set 6 ---> sitka
# Processing Record 3 of Set 6 ---> madisonville
# Processing Record 4 of Set 6 ---> mali
# Processing Record 5 of Set 6 ---> saint-louis
# Processing Record 6 of Set 6 ---> cockburn town
# Processing Record 7 of Set 6 ---> kidal
# Processing Record 8 of Set 6 ---> arkhara
# Processing Record 9 of Set 6 ---> najran
# Processing Record 10 of Set 6 ---> jackson
# sumbawa not found. Proceeding to the next city...
# Processing Record 11 of Set 6 ---> aykhal
# Processing Record 12 of Set 6 ---> enid
# Processing Record 13 of Set 6 ---> lamballe
# Processing Record 14 of Set 6 ---> hailar
# Processing Record 15 of Set 6 ---> makakilo city
# Processing Record 16 of Set 6 ---> tevriz
# Processing Record 17 of Set 6 ---> baiyin
# Processing Record 18 of Set 6 ---> san miguel
# warqla not found. Proceeding to the next city...
# Processing Record 19 of Set 6 ---> korla
# Processing Record 20 of Set 6 ---> thornaby
# foam lake not found. Proceeding to the next city...
# Processing Record 21 of Set 6 ---> bechem
# Processing Record 22 of Set 6 ---> srednekolymsk
# Processing Record 23 of Set 6 ---> tomiya
# Processing Record 24 of Set 6 ---> nunkini
# the pas not found. Proceeding to the next city...
# Processing Record 25 of Set 6 ---> tiarei
# Processing Record 26 of Set 6 ---> tabou
# Processing Record 27 of Set 6 ---> klaksvik
# Processing Record 28 of Set 6 ---> kalmar
# Processing Record 29 of Set 6 ---> luban
# Processing Record 30 of Set 6 ---> huanren
# Processing Record 31 of Set 6 ---> bitung
# Processing Record 32 of Set 6 ---> kieta
# Processing Record 33 of Set 6 ---> leningradskiy
# Processing Record 34 of Set 6 ---> berlevag
# Processing Record 35 of Set 6 ---> namuac
# Processing Record 36 of Set 6 ---> itarema
# Processing Record 37 of Set 6 ---> mahibadhoo
# Processing Record 38 of Set 6 ---> yaan
# Processing Record 39 of Set 6 ---> jaguaruana
# Processing Record 40 of Set 6 ---> russell
# Processing Record 41 of Set 6 ---> lyuban
# Processing Record 42 of Set 6 ---> lakes entrance
# nizhneyansk not found. Proceeding to the next city...
# Processing Record 43 of Set 6 ---> washougal
# Processing Record 44 of Set 6 ---> kavieng
# Processing Record 45 of Set 6 ---> manaure
# Processing Record 46 of Set 6 ---> srandakan
# Processing Record 47 of Set 6 ---> finschhafen
# Processing Record 48 of Set 6 ---> ostrovnoy
# Processing Record 49 of Set 6 ---> manaus
# Processing Record 50 of Set 6 ---> mathathane
# Processing Record 1 of Set 7 ---> phangnga
# Processing Record 2 of Set 7 ---> karratha
# Processing Record 3 of Set 7 ---> czarnkow
# Processing Record 4 of Set 7 ---> monrovia
# umm lajj not found. Proceeding to the next city...
# Processing Record 5 of Set 7 ---> iskateley
# gusinoye ozero not found. Proceeding to the next city...
# Processing Record 6 of Set 7 ---> umtata
# maykain not found. Proceeding to the next city...
# Processing Record 7 of Set 7 ---> voh
# Processing Record 8 of Set 7 ---> nakamura
# Processing Record 9 of Set 7 ---> kvareli
# Processing Record 10 of Set 7 ---> souillac
# Processing Record 11 of Set 7 ---> saint-georges
# Processing Record 12 of Set 7 ---> baculin
# Processing Record 13 of Set 7 ---> nanortalik
# Processing Record 14 of Set 7 ---> valleyview
# Processing Record 15 of Set 7 ---> sinnamary
# tsihombe not found. Proceeding to the next city...
# Processing Record 16 of Set 7 ---> leshukonskoye
# Processing Record 17 of Set 7 ---> baillif
# Processing Record 18 of Set 7 ---> paita
# Processing Record 19 of Set 7 ---> bonavista
# burica not found. Proceeding to the next city...
# sentyabrskiy not found. Proceeding to the next city...
# Processing Record 20 of Set 7 ---> olinda
# Processing Record 21 of Set 7 ---> yumen
# Processing Record 22 of Set 7 ---> whitecourt
# Processing Record 23 of Set 7 ---> laramie
# Processing Record 24 of Set 7 ---> nishihara
# Processing Record 25 of Set 7 ---> ponta do sol
# Processing Record 26 of Set 7 ---> maralal
# Processing Record 27 of Set 7 ---> arman
# Processing Record 28 of Set 7 ---> bahia honda
# Processing Record 29 of Set 7 ---> robertsport
# Processing Record 30 of Set 7 ---> padang
# Processing Record 31 of Set 7 ---> bathsheba
# Processing Record 32 of Set 7 ---> acarau
# Processing Record 33 of Set 7 ---> talaya
# Processing Record 34 of Set 7 ---> laguna
# Processing Record 35 of Set 7 ---> manresa
# Processing Record 36 of Set 7 ---> atherton
# Processing Record 37 of Set 7 ---> berwick
# Processing Record 38 of Set 7 ---> karla
# Processing Record 39 of Set 7 ---> mankono
# tiruvottiyur not found. Proceeding to the next city...
# Processing Record 40 of Set 7 ---> marsaxlokk
# Processing Record 41 of Set 7 ---> san carlos de bariloche
# Processing Record 42 of Set 7 ---> birjand
# Processing Record 43 of Set 7 ---> prado
# Processing Record 44 of Set 7 ---> egvekinot
# Processing Record 45 of Set 7 ---> bukit bakri
# Processing Record 46 of Set 7 ---> yulara
# Processing Record 47 of Set 7 ---> ambilobe
# Processing Record 48 of Set 7 ---> ingham
# Processing Record 49 of Set 7 ---> zhigansk
# Processing Record 50 of Set 7 ---> lompoc
# Processing Record 1 of Set 8 ---> beringovskiy
# Processing Record 2 of Set 8 ---> sur
# Processing Record 3 of Set 8 ---> aberdeen
# Processing Record 4 of Set 8 ---> vila velha
# ciudad bolivar not found. Proceeding to the next city...
# Processing Record 5 of Set 8 ---> huercal-overa
# Processing Record 6 of Set 8 ---> batticaloa
# Processing Record 7 of Set 8 ---> cabo san lucas
# Processing Record 8 of Set 8 ---> kenai
# Processing Record 9 of Set 8 ---> sangrur
# Processing Record 10 of Set 8 ---> clyde river
# Processing Record 11 of Set 8 ---> kapit
# Processing Record 12 of Set 8 ---> tura
# Processing Record 13 of Set 8 ---> castelbuono
# Processing Record 14 of Set 8 ---> dong hoi
# Processing Record 15 of Set 8 ---> keti bandar
# Processing Record 16 of Set 8 ---> comillas
# Processing Record 17 of Set 8 ---> borogontsy
# Processing Record 18 of Set 8 ---> atar
# Processing Record 19 of Set 8 ---> filingue
# Processing Record 20 of Set 8 ---> villazon
# Processing Record 21 of Set 8 ---> bregenz
# Processing Record 22 of Set 8 ---> mount isa
# Processing Record 23 of Set 8 ---> codrington
# Processing Record 24 of Set 8 ---> mbanza-ngungu
# Processing Record 25 of Set 8 ---> nangka
# Processing Record 26 of Set 8 ---> boston
# Processing Record 27 of Set 8 ---> assomada
# Processing Record 28 of Set 8 ---> palmerston north
# Processing Record 29 of Set 8 ---> san jeronimo
# Processing Record 30 of Set 8 ---> gao
# Processing Record 31 of Set 8 ---> cordoba
# Processing Record 32 of Set 8 ---> tilik
# afmadu not found. Proceeding to the next city...
# Processing Record 33 of Set 8 ---> jasper
# Processing Record 34 of Set 8 ---> ucluelet
# Processing Record 35 of Set 8 ---> at-bashi
# Processing Record 36 of Set 8 ---> mlonggo
# Processing Record 37 of Set 8 ---> nampula
# Processing Record 38 of Set 8 ---> dingle
# Processing Record 39 of Set 8 ---> nova prata
# staryy nadym not found. Proceeding to the next city...
# Processing Record 40 of Set 8 ---> tromso
# Processing Record 41 of Set 8 ---> vao
# Processing Record 42 of Set 8 ---> ambanja
# Processing Record 43 of Set 8 ---> inta
# Processing Record 44 of Set 8 ---> milkovo
# Processing Record 45 of Set 8 ---> kapoeta
# Processing Record 46 of Set 8 ---> castro
# Processing Record 47 of Set 8 ---> doha
# Processing Record 48 of Set 8 ---> hambantota
# Processing Record 49 of Set 8 ---> soure
# Processing Record 50 of Set 8 ---> ahmadnagar
# Processing Record 1 of Set 9 ---> hofn
# Processing Record 2 of Set 9 ---> port lincoln
# Processing Record 3 of Set 9 ---> griffith
# Processing Record 4 of Set 9 ---> mantua
# Processing Record 5 of Set 9 ---> lagunas
# Processing Record 6 of Set 9 ---> turayf
# Processing Record 7 of Set 9 ---> mawlaik
# Processing Record 8 of Set 9 ---> nicoya
# Processing Record 9 of Set 9 ---> huicheng
# Processing Record 10 of Set 9 ---> mayo
# Processing Record 11 of Set 9 ---> lamar
# Processing Record 12 of Set 9 ---> tarauaca
# Processing Record 13 of Set 9 ---> pedasi
# Processing Record 14 of Set 9 ---> pokhara
# Processing Record 15 of Set 9 ---> aklavik
# Processing Record 16 of Set 9 ---> xicotencatl
# Processing Record 17 of Set 9 ---> oyama
# Processing Record 18 of Set 9 ---> okha
# Processing Record 19 of Set 9 ---> necochea
# Processing Record 20 of Set 9 ---> dasoguz
# Processing Record 21 of Set 9 ---> illela
# Processing Record 22 of Set 9 ---> sept-iles
# Processing Record 23 of Set 9 ---> tezu
# lolua not found. Proceeding to the next city...
# Processing Record 24 of Set 9 ---> shawnee
# Processing Record 25 of Set 9 ---> iqaluit
# Processing Record 26 of Set 9 ---> erbaa
# Processing Record 27 of Set 9 ---> benjamin constant
# Processing Record 28 of Set 9 ---> kankakee
# Processing Record 29 of Set 9 ---> calama
# babanusah not found. Proceeding to the next city...
# el bagre not found. Proceeding to the next city...
# Processing Record 30 of Set 9 ---> sampit
# Processing Record 31 of Set 9 ---> zhezkazgan
# luang prabang not found. Proceeding to the next city...
# Processing Record 32 of Set 9 ---> turbat
# Processing Record 33 of Set 9 ---> pachperwa
# Processing Record 34 of Set 9 ---> beyneu
# Processing Record 35 of Set 9 ---> north battleford
# Processing Record 36 of Set 9 ---> coihaique
# Processing Record 37 of Set 9 ---> bonthe
# Processing Record 38 of Set 9 ---> peniche
# Processing Record 39 of Set 9 ---> falam
# Processing Record 40 of Set 9 ---> komsomolskiy
# Processing Record 41 of Set 9 ---> bodden town
# Processing Record 42 of Set 9 ---> khuzhir
# Processing Record 43 of Set 9 ---> honningsvag
# Processing Record 44 of Set 9 ---> mayya
# Processing Record 45 of Set 9 ---> palimbang
# Processing Record 46 of Set 9 ---> mirpur sakro
# Processing Record 47 of Set 9 ---> sisimiut
# Processing Record 48 of Set 9 ---> kendari
# Processing Record 49 of Set 9 ---> taseyevo
# Processing Record 50 of Set 9 ---> idenao
# le mars not found. Proceeding to the next city...
# ruatoria not found. Proceeding to the next city...
# Processing Record 1 of Set 10 ---> hwange
# Processing Record 2 of Set 10 ---> golyshmanovo
# Processing Record 3 of Set 10 ---> kizilskoye
# bargal not found. Proceeding to the next city...
# katha not found. Proceeding to the next city...
# Processing Record 4 of Set 10 ---> vaitape
# gangotri not found. Proceeding to the next city...
# Processing Record 5 of Set 10 ---> andenes
# Processing Record 6 of Set 10 ---> baykit
# Processing Record 7 of Set 10 ---> shetpe
# Processing Record 8 of Set 10 ---> colac
# Processing Record 9 of Set 10 ---> alamosa
# Processing Record 10 of Set 10 ---> champerico
# Processing Record 11 of Set 10 ---> ahipara
# Processing Record 12 of Set 10 ---> manzhouli
# Processing Record 13 of Set 10 ---> bowen
# Processing Record 14 of Set 10 ---> naberera
# Processing Record 15 of Set 10 ---> salamiyah
# Processing Record 16 of Set 10 ---> mandalgovi
# Processing Record 17 of Set 10 ---> narrabri
# Processing Record 18 of Set 10 ---> keta
# Processing Record 19 of Set 10 ---> antequera
# Processing Record 20 of Set 10 ---> jamiltepec
# Processing Record 21 of Set 10 ---> evanston
# Processing Record 22 of Set 10 ---> omsukchan
# Processing Record 23 of Set 10 ---> teseney
# Processing Record 24 of Set 10 ---> goderich
# Processing Record 25 of Set 10 ---> butembo
# Processing Record 26 of Set 10 ---> machiques
# Processing Record 27 of Set 10 ---> teya
# Processing Record 28 of Set 10 ---> kavaratti
# Processing Record 29 of Set 10 ---> hokitika
# Processing Record 30 of Set 10 ---> karasjok
# Processing Record 31 of Set 10 ---> kuryk
# Processing Record 32 of Set 10 ---> mana
# Processing Record 33 of Set 10 ---> port hedland
# Processing Record 34 of Set 10 ---> paamiut
# Processing Record 35 of Set 10 ---> wakkanai
# Processing Record 36 of Set 10 ---> ortona
# Processing Record 37 of Set 10 ---> aleksandrov gay
# Processing Record 38 of Set 10 ---> yazykovo
# Processing Record 39 of Set 10 ---> spearfish
# Processing Record 40 of Set 10 ---> sojat
# Processing Record 41 of Set 10 ---> ilebo
# Processing Record 42 of Set 10 ---> gigante
# Processing Record 43 of Set 10 ---> linhares
# Processing Record 44 of Set 10 ---> ancud
# Processing Record 45 of Set 10 ---> shubarkuduk
# Processing Record 46 of Set 10 ---> pisco
# Processing Record 47 of Set 10 ---> ayagoz
# Processing Record 48 of Set 10 ---> greymouth
# Processing Record 49 of Set 10 ---> san luis
# Processing Record 50 of Set 10 ---> barrhead
# Processing Record 1 of Set 11 ---> nisia floresta
# Processing Record 2 of Set 11 ---> coquimbo
# Processing Record 3 of Set 11 ---> ngunguru
# Processing Record 4 of Set 11 ---> miura
# Processing Record 5 of Set 11 ---> oistins
# Processing Record 6 of Set 11 ---> dera bugti
# Processing Record 7 of Set 11 ---> borovoy
# Processing Record 8 of Set 11 ---> ossora
# Processing Record 9 of Set 11 ---> waipawa
# Processing Record 10 of Set 11 ---> penzance
# Processing Record 11 of Set 11 ---> touros
# dinsor not found. Proceeding to the next city...
# Processing Record 12 of Set 11 ---> igbo ora
# Processing Record 13 of Set 11 ---> lieksa
# Processing Record 14 of Set 11 ---> san francisco
# Processing Record 15 of Set 11 ---> pinyug
# doctor pedro p. pena not found. Proceeding to the next city...
# Processing Record 16 of Set 11 ---> puerto madero
# mahadday weyne not found. Proceeding to the next city...
# Processing Record 17 of Set 11 ---> sala
# Processing Record 18 of Set 11 ---> miram shah
# Processing Record 19 of Set 11 ---> nelson bay
# Processing Record 20 of Set 11 ---> buala
# Processing Record 21 of Set 11 ---> lulea
# Processing Record 22 of Set 11 ---> valdez
# la ronge not found. Proceeding to the next city...
# Processing Record 23 of Set 11 ---> high level
# Processing Record 24 of Set 11 ---> kalmunai
# Processing Record 25 of Set 11 ---> hasaki
# Processing Record 26 of Set 11 ---> luanda
# Processing Record 27 of Set 11 ---> leh
# Processing Record 28 of Set 11 ---> naples
# Processing Record 29 of Set 11 ---> vuktyl
# Processing Record 30 of Set 11 ---> mabaruma
# Processing Record 31 of Set 11 ---> dengzhou
# Processing Record 32 of Set 11 ---> nyurba
# Processing Record 33 of Set 11 ---> tamandare
# Processing Record 34 of Set 11 ---> sorland
# Processing Record 35 of Set 11 ---> gizo
# borama not found. Proceeding to the next city...
# Processing Record 36 of Set 11 ---> itapeva
# Processing Record 37 of Set 11 ---> mount pleasant
# Processing Record 38 of Set 11 ---> nizhnevartovsk
# Processing Record 39 of Set 11 ---> kamaishi
# Processing Record 40 of Set 11 ---> severnoye
# Processing Record 41 of Set 11 ---> akyab
# Processing Record 42 of Set 11 ---> tabanan
# Processing Record 43 of Set 11 ---> phuntsholing
# Processing Record 44 of Set 11 ---> ipixuna
# *******************************
# Data Retrieval Complete
# *******************************

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# The data generated from the API calls will be compiled into a new Data Fram
weather_data_frame = pd.DataFrame({
    'City':updated_city_list,
    'Lattitude':lattitude,
    'Longitude': longitude,
    'Max Temp': max_temp,
    'Humidity': humidity,
    'Cloudiness': cloudinesses,
    'Wind Speed': wind,
    'Country': country_list,
    'Date':dates
})

## Exporting the new DataFrame into a csv file
weather_data_frame.to_csv('..\Output_Data\Weather_Data_Collection.csv')

## Displaying the DataFrame
print(f'{weather_data_frame.shape[0]} cities, along with their weather information, have been collated\n')
weather_data_frame.head()
# Out:
# 544 cities, along with their weather information, have been collated
#           City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0         gazi      35.33      25.07     26.11        78          40
# 1        bluff     -46.60     168.33      5.56        73          99
# 2    cape town     -36.41     -71.90      6.00       100         100
# 3  porto velho      41.15      -8.61     14.44        93          48
# 4      mataura     -46.19     168.86      5.56        73          94
#
#    Wind Speed Country        Date
# 0        2.60      GR  1601355047
# 1        9.39      NZ  1601355047
# 2        1.00      CL  1601355048
# 3        1.00      PT  1601355049
# 4        9.39      NZ  1601355049

# %%
## Summary Statistics 
weather_data_frame.describe()
# Out:
#         Lattitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  544.000000  544.000000  544.000000  544.000000  544.000000  544.000000
# mean    23.435423   23.733401   17.789099   72.025735   51.584559    3.397059
# std     31.747808   89.045649    9.182122   19.659610   38.475462    2.350545
# min    -54.800000 -179.170000  -10.730000    1.000000    0.000000    0.170000
# 25%     -1.825000  -48.820000   10.000000   60.000000   14.000000    1.580000
# 50%     28.300000   24.535000   18.420000   75.000000   50.000000    2.730000
# 75%     49.707500  100.705000   25.630000   87.000000   90.000000    4.680000
# max     78.220000  179.320000   35.090000  100.000000  100.000000   12.300000
#
#                Date
# count  5.440000e+02
# mean   1.601355e+09
# std    1.264329e+02
# min    1.601355e+09
# 25%    1.601355e+09
# 50%    1.601355e+09
# 75%    1.601355e+09
# max    1.601355e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking to see if there are cities with humidities over 100
weather_data_frame[weather_data_frame['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lattitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames_Over100 = weather_data_frame[weather_data_frame['Humidity']>100].index

# %%
if (len(indexNames_Over100)) > 0:
    print(f'There are cities with humidity over 100')
else:
    print(f'There are no cities with humidity over 100')
# Out:
# There are no cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data_frame.drop(indexNames_Over100, inplace=False)

# %%
print(f'There are {clean_city_data.shape[0]} cities to be assessed\n')
clean_city_data.head()
# Out:
# There are 544 cities to be assessed
#           City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0         gazi      35.33      25.07     26.11        78          40
# 1        bluff     -46.60     168.33      5.56        73          99
# 2    cape town     -36.41     -71.90      6.00       100         100
# 3  porto velho      41.15      -8.61     14.44        93          48
# 4      mataura     -46.19     168.86      5.56        73          94
#
#    Wind Speed Country        Date
# 0        2.60      GR  1601355047
# 1        9.39      NZ  1601355047
# 2        1.00      CL  1601355048
# 3        1.00      PT  1601355049
# 4        9.39      NZ  1601355049

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# A scatter plot will be used in order to determine the relationship between temperature and lattitudes
x_lattitude = clean_city_data['Lattitude']
y_temperature = clean_city_data['Max Temp']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Temperature',fontsize=15)
ax1.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_temperature, edgecolors='black', c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Temperature.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# We will use the previous x_label and create a new Y label pertaining to humidity
y_humidity = clean_city_data['Humidity']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Humidity',fontsize=15)
ax1.set_ylabel('Humidity', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_humidity, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# We will set a new y_ variable pertaining to Cloudiness
y_cloudiness = clean_city_data['Cloudiness']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Cloudiness',fontsize=15)
ax1.set_ylabel('Cloudiness(%)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_cloudiness, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# We wil set a new y_ variable pertaining to Wind Speed
y_windspeed = clean_city_data['Wind Speed']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Wind Speed',fontsize=15)
ax1.set_ylabel('Wind Speed (mph)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_windspeed, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_WindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Northern Hemisphere Latitudes vs Max Temperature

# %%
# All cities within the Northern Hemisphere will be in the lattitude range of 0(equator) to 90. 
# We will need to filter the dataframe to contain cities within the northern hemisphere (nh)

northern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']>=0]

x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_max_temp = northern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_max_temp)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.7312962112863544

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# All cities within the Southern Hemisphere will be in the lattitude range of 0(equator) to -90. 
# We will need to filter the dataframe to contain cities within the southern hemisphere (sh)

southern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']<=0]

x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_max_temp = southern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_max_temp)

# Linear Regression Label
line_eq_sh = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit_sh = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit_sh,'black')
ax2.scatter(x_sh_latitude,y_sh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.6267972794685757

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_humidity = northern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.011439530712768936

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_humidity = southern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.00029635526496690176

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_cloudiness = northern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.006374194915364483

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_cloudiness = southern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.00033851259503723396

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_windspeed = northern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Windspeed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Windspeed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.04836193332263944

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_windspeed = southern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Wind Speed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Wind Speed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.05085757646955503

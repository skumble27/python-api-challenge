# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing the relevant modules for weather analyses
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import scipy.stats as st

# Importing the API Key
from api_keys import weather_api_key

# Setting Unit of Measurement for Temperature
celsius ='metric'

# Setting up the query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={celsius}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# Preparing lists to store random lattitude and longitude coordinates
random_lat_long = []
city_names = []

# Creting Random Lattitudes
ran_lattitude = np.random.uniform(low=-90.000, high=90.000, size=1500)
ran_longitude = np.random.uniform(low=-180.000, high=180.000, size=1500)
random_lat_long = zip(ran_lattitude,ran_longitude)

# Assigning the nearest city to the coordinates
for lat_long in random_lat_long:
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name

    # Ensuring only unique city names are added
    if city in city_names:
        next
    else:
        city_names.append(city)
print(f'The number of cities added are {len(city_names)}')
# Out:
# The number of cities added are 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
updated_city_list = []
cloudinesses = []
dates = []
humidity = []
lattitude = []
longitude = []
max_temp = []
wind = []
country_list = []

# set initial count quantities for organization
record_number = 0
record_sets = 1

# loops for creating dataframe columns
print(f'Data Retreival commencing\n---------------------\n')
for city in city_names:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lattitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        if record_number > 49:
            record_number = 1
            record_sets += 1
            updated_city_list.append(city)
        else:
            record_number += 1
            updated_city_list.append(city)
        print(f"Processing Record {record_number} of Set {record_sets} ---> {city}")
    except Exception:
        print(f"{city} not found. Proceeding to the next city...")
print("*******************************")
print("Data Retrieval Complete\n*******************************")
# Out:
# Data Retreival commencing
# ---------------------
#
# Processing Record 1 of Set 1 ---&gt; portland
# Processing Record 2 of Set 1 ---&gt; hobart
# Processing Record 3 of Set 1 ---&gt; chapais
# Processing Record 4 of Set 1 ---&gt; kavarskas
# Processing Record 5 of Set 1 ---&gt; fairbanks
# Processing Record 6 of Set 1 ---&gt; vaini
# Processing Record 7 of Set 1 ---&gt; punta arenas
# Processing Record 8 of Set 1 ---&gt; hokitika
# Processing Record 9 of Set 1 ---&gt; maksatikha
# Processing Record 10 of Set 1 ---&gt; ajdabiya
# Processing Record 11 of Set 1 ---&gt; qaanaaq
# Processing Record 12 of Set 1 ---&gt; santa cruz
# Processing Record 13 of Set 1 ---&gt; srednekolymsk
# Processing Record 14 of Set 1 ---&gt; boa vista
# Processing Record 15 of Set 1 ---&gt; luderitz
# Processing Record 16 of Set 1 ---&gt; castro
# Processing Record 17 of Set 1 ---&gt; kapaa
# Processing Record 18 of Set 1 ---&gt; ushuaia
# Processing Record 19 of Set 1 ---&gt; acarau
# Processing Record 20 of Set 1 ---&gt; norman wells
# Processing Record 21 of Set 1 ---&gt; cape town
# Processing Record 22 of Set 1 ---&gt; ambon
# Processing Record 23 of Set 1 ---&gt; marathon
# Processing Record 24 of Set 1 ---&gt; thompson
# Processing Record 25 of Set 1 ---&gt; kavaratti
# Processing Record 26 of Set 1 ---&gt; alice springs
# Processing Record 27 of Set 1 ---&gt; mar del plata
# Processing Record 28 of Set 1 ---&gt; harmanli
# Processing Record 29 of Set 1 ---&gt; awbari
# Processing Record 30 of Set 1 ---&gt; san cristobal
# Processing Record 31 of Set 1 ---&gt; yulara
# Processing Record 32 of Set 1 ---&gt; new norfolk
# Processing Record 33 of Set 1 ---&gt; mataura
# Processing Record 34 of Set 1 ---&gt; ust-tsilma
# Processing Record 35 of Set 1 ---&gt; ilam
# Processing Record 36 of Set 1 ---&gt; sao francisco
# Processing Record 37 of Set 1 ---&gt; mehamn
# Processing Record 38 of Set 1 ---&gt; half moon bay
# saint george not found. Proceeding to the next city...
# Processing Record 39 of Set 1 ---&gt; dikson
# Processing Record 40 of Set 1 ---&gt; ribeira grande
# sorvag not found. Proceeding to the next city...
# Processing Record 41 of Set 1 ---&gt; chokurdakh
# Processing Record 42 of Set 1 ---&gt; palmer
# Processing Record 43 of Set 1 ---&gt; chuy
# Processing Record 44 of Set 1 ---&gt; rikitea
# Processing Record 45 of Set 1 ---&gt; geraldton
# calobre not found. Proceeding to the next city...
# Processing Record 46 of Set 1 ---&gt; mlyniv
# Processing Record 47 of Set 1 ---&gt; whitecourt
# marcona not found. Proceeding to the next city...
# Processing Record 48 of Set 1 ---&gt; lompoc
# Processing Record 49 of Set 1 ---&gt; langenburg
# Processing Record 50 of Set 1 ---&gt; tabou
# Processing Record 1 of Set 2 ---&gt; nikolskoye
# Processing Record 2 of Set 2 ---&gt; clyde river
# Processing Record 3 of Set 2 ---&gt; bambous virieux
# Processing Record 4 of Set 2 ---&gt; atuona
# Processing Record 5 of Set 2 ---&gt; licata
# Processing Record 6 of Set 2 ---&gt; port alfred
# attawapiskat not found. Proceeding to the next city...
# Processing Record 7 of Set 2 ---&gt; khatanga
# Processing Record 8 of Set 2 ---&gt; amuntai
# Processing Record 9 of Set 2 ---&gt; mutare
# Processing Record 10 of Set 2 ---&gt; oyama
# Processing Record 11 of Set 2 ---&gt; pochutla
# Processing Record 12 of Set 2 ---&gt; vestmannaeyjar
# Processing Record 13 of Set 2 ---&gt; tiksi
# los llanos de aridane not found. Proceeding to the next city...
# Processing Record 14 of Set 2 ---&gt; hualmay
# Processing Record 15 of Set 2 ---&gt; port hardy
# Processing Record 16 of Set 2 ---&gt; barrow
# belushya guba not found. Proceeding to the next city...
# Processing Record 17 of Set 2 ---&gt; agropoli
# Processing Record 18 of Set 2 ---&gt; busselton
# Processing Record 19 of Set 2 ---&gt; gabi
# Processing Record 20 of Set 2 ---&gt; lagoa
# Processing Record 21 of Set 2 ---&gt; kirensk
# Processing Record 22 of Set 2 ---&gt; muros
# Processing Record 23 of Set 2 ---&gt; hermanus
# Processing Record 24 of Set 2 ---&gt; coihaique
# Processing Record 25 of Set 2 ---&gt; georgetown
# Processing Record 26 of Set 2 ---&gt; lazaro cardenas
# Processing Record 27 of Set 2 ---&gt; kavieng
# Processing Record 28 of Set 2 ---&gt; phan thiet
# Processing Record 29 of Set 2 ---&gt; caravelas
# Processing Record 30 of Set 2 ---&gt; nyimba
# Processing Record 31 of Set 2 ---&gt; kuruman
# Processing Record 32 of Set 2 ---&gt; bredasdorp
# Processing Record 33 of Set 2 ---&gt; beyneu
# Processing Record 34 of Set 2 ---&gt; naryan-mar
# Processing Record 35 of Set 2 ---&gt; terenos
# Processing Record 36 of Set 2 ---&gt; hithadhoo
# Processing Record 37 of Set 2 ---&gt; arraial do cabo
# Processing Record 38 of Set 2 ---&gt; huangmei
# Processing Record 39 of Set 2 ---&gt; oranjemund
# Processing Record 40 of Set 2 ---&gt; banda aceh
# Processing Record 41 of Set 2 ---&gt; rantepao
# Processing Record 42 of Set 2 ---&gt; hay river
# Processing Record 43 of Set 2 ---&gt; duncan
# Processing Record 44 of Set 2 ---&gt; neyshabur
# Processing Record 45 of Set 2 ---&gt; klaksvik
# Processing Record 46 of Set 2 ---&gt; tete
# Processing Record 47 of Set 2 ---&gt; alofi
# Processing Record 48 of Set 2 ---&gt; anadyr
# Processing Record 49 of Set 2 ---&gt; sitka
# Processing Record 50 of Set 2 ---&gt; carnarvon
# Processing Record 1 of Set 3 ---&gt; avarua
# Processing Record 2 of Set 3 ---&gt; khorixas
# Processing Record 3 of Set 3 ---&gt; osorno
# Processing Record 4 of Set 3 ---&gt; morondava
# illoqqortoormiut not found. Proceeding to the next city...
# Processing Record 5 of Set 3 ---&gt; paamiut
# Processing Record 6 of Set 3 ---&gt; esperance
# Processing Record 7 of Set 3 ---&gt; saskylakh
# Processing Record 8 of Set 3 ---&gt; rio grande
# Processing Record 9 of Set 3 ---&gt; albany
# Processing Record 10 of Set 3 ---&gt; lanzhou
# Processing Record 11 of Set 3 ---&gt; hofn
# Processing Record 12 of Set 3 ---&gt; yogyakarta
# Processing Record 13 of Set 3 ---&gt; elat
# Processing Record 14 of Set 3 ---&gt; beringovskiy
# Processing Record 15 of Set 3 ---&gt; acapulco
# Processing Record 16 of Set 3 ---&gt; swellendam
# Processing Record 17 of Set 3 ---&gt; longyearbyen
# Processing Record 18 of Set 3 ---&gt; antofagasta
# Processing Record 19 of Set 3 ---&gt; kodiak
# Processing Record 20 of Set 3 ---&gt; guerrero negro
# Processing Record 21 of Set 3 ---&gt; vila velha
# Processing Record 22 of Set 3 ---&gt; puerto ayora
# Processing Record 23 of Set 3 ---&gt; tuktoyaktuk
# Processing Record 24 of Set 3 ---&gt; cookeville
# Processing Record 25 of Set 3 ---&gt; lavrentiya
# Processing Record 26 of Set 3 ---&gt; malinyi
# Processing Record 27 of Set 3 ---&gt; bingol
# Processing Record 28 of Set 3 ---&gt; osmena
# Processing Record 29 of Set 3 ---&gt; jumla
# tumannyy not found. Proceeding to the next city...
# Processing Record 30 of Set 3 ---&gt; victoria
# Processing Record 31 of Set 3 ---&gt; narasannapeta
# Processing Record 32 of Set 3 ---&gt; butaritari
# Processing Record 33 of Set 3 ---&gt; emerald
# Processing Record 34 of Set 3 ---&gt; takestan
# Processing Record 35 of Set 3 ---&gt; aberdeen
# Processing Record 36 of Set 3 ---&gt; mahebourg
# Processing Record 37 of Set 3 ---&gt; prieska
# Processing Record 38 of Set 3 ---&gt; belyy yar
# Processing Record 39 of Set 3 ---&gt; bluff
# Processing Record 40 of Set 3 ---&gt; sulangan
# Processing Record 41 of Set 3 ---&gt; tessalit
# Processing Record 42 of Set 3 ---&gt; penzance
# Processing Record 43 of Set 3 ---&gt; shimoda
# Processing Record 44 of Set 3 ---&gt; kuressaare
# Processing Record 45 of Set 3 ---&gt; lamesa
# Processing Record 46 of Set 3 ---&gt; sonoita
# Processing Record 47 of Set 3 ---&gt; korla
# Processing Record 48 of Set 3 ---&gt; mys shmidta
# Processing Record 49 of Set 3 ---&gt; najran
# umzimvubu not found. Proceeding to the next city...
# Processing Record 50 of Set 3 ---&gt; alipur chatha
# Processing Record 1 of Set 4 ---&gt; goderich
# Processing Record 2 of Set 4 ---&gt; cabo san lucas
# te anau not found. Proceeding to the next city...
# Processing Record 3 of Set 4 ---&gt; visnes
# Processing Record 4 of Set 4 ---&gt; sao joao da barra
# Processing Record 5 of Set 4 ---&gt; constitucion
# Processing Record 6 of Set 4 ---&gt; ukiah
# Processing Record 7 of Set 4 ---&gt; manokwari
# taolanaro not found. Proceeding to the next city...
# Processing Record 8 of Set 4 ---&gt; souillac
# Processing Record 9 of Set 4 ---&gt; bukachacha
# Processing Record 10 of Set 4 ---&gt; foundiougne
# Processing Record 11 of Set 4 ---&gt; cherskiy
# Processing Record 12 of Set 4 ---&gt; nanortalik
# Processing Record 13 of Set 4 ---&gt; hami
# Processing Record 14 of Set 4 ---&gt; padang
# Processing Record 15 of Set 4 ---&gt; lebu
# Processing Record 16 of Set 4 ---&gt; iqaluit
# Processing Record 17 of Set 4 ---&gt; fortuna
# Processing Record 18 of Set 4 ---&gt; saint-philippe
# Processing Record 19 of Set 4 ---&gt; marfino
# Processing Record 20 of Set 4 ---&gt; chaman
# Processing Record 21 of Set 4 ---&gt; eyl
# Processing Record 22 of Set 4 ---&gt; saint-pierre
# Processing Record 23 of Set 4 ---&gt; kutum
# Processing Record 24 of Set 4 ---&gt; apolda
# Processing Record 25 of Set 4 ---&gt; roald
# Processing Record 26 of Set 4 ---&gt; novyy urengoy
# Processing Record 27 of Set 4 ---&gt; faanui
# Processing Record 28 of Set 4 ---&gt; hilo
# Processing Record 29 of Set 4 ---&gt; plattsburgh
# Processing Record 30 of Set 4 ---&gt; wagar
# Processing Record 31 of Set 4 ---&gt; samana
# Processing Record 32 of Set 4 ---&gt; ulaangom
# Processing Record 33 of Set 4 ---&gt; naze
# Processing Record 34 of Set 4 ---&gt; kaitangata
# Processing Record 35 of Set 4 ---&gt; pisco
# Processing Record 36 of Set 4 ---&gt; ixtapa
# Processing Record 37 of Set 4 ---&gt; ous
# Processing Record 38 of Set 4 ---&gt; marawi
# Processing Record 39 of Set 4 ---&gt; vila
# Processing Record 40 of Set 4 ---&gt; bossangoa
# Processing Record 41 of Set 4 ---&gt; zhigansk
# Processing Record 42 of Set 4 ---&gt; san patricio
# Processing Record 43 of Set 4 ---&gt; novolabinskaya
# Processing Record 44 of Set 4 ---&gt; ayan
# Processing Record 45 of Set 4 ---&gt; tuatapere
# Processing Record 46 of Set 4 ---&gt; coquimbo
# Processing Record 47 of Set 4 ---&gt; bethel
# Processing Record 48 of Set 4 ---&gt; vao
# kazalinsk not found. Proceeding to the next city...
# Processing Record 49 of Set 4 ---&gt; tanabe
# Processing Record 50 of Set 4 ---&gt; hohhot
# Processing Record 1 of Set 5 ---&gt; narsaq
# Processing Record 2 of Set 5 ---&gt; tasiilaq
# saleaula not found. Proceeding to the next city...
# palabuhanratu not found. Proceeding to the next city...
# Processing Record 3 of Set 5 ---&gt; deputatskiy
# Processing Record 4 of Set 5 ---&gt; masvingo
# Processing Record 5 of Set 5 ---&gt; kolyvan
# Processing Record 6 of Set 5 ---&gt; victor harbor
# Processing Record 7 of Set 5 ---&gt; jamestown
# Processing Record 8 of Set 5 ---&gt; pitimbu
# Processing Record 9 of Set 5 ---&gt; lamu
# Processing Record 10 of Set 5 ---&gt; bengkulu
# Processing Record 11 of Set 5 ---&gt; nizwa
# rawannawi not found. Proceeding to the next city...
# Processing Record 12 of Set 5 ---&gt; saldanha
# barentsburg not found. Proceeding to the next city...
# Processing Record 13 of Set 5 ---&gt; dabakala
# Processing Record 14 of Set 5 ---&gt; nome
# Processing Record 15 of Set 5 ---&gt; east london
# Processing Record 16 of Set 5 ---&gt; payo
# Processing Record 17 of Set 5 ---&gt; yellowknife
# Processing Record 18 of Set 5 ---&gt; san jose
# Processing Record 19 of Set 5 ---&gt; bani walid
# Processing Record 20 of Set 5 ---&gt; ussel
# amderma not found. Proceeding to the next city...
# Processing Record 21 of Set 5 ---&gt; nara
# Processing Record 22 of Set 5 ---&gt; hobyo
# Processing Record 23 of Set 5 ---&gt; pacifica
# Processing Record 24 of Set 5 ---&gt; springbok
# Processing Record 25 of Set 5 ---&gt; embonas
# Processing Record 26 of Set 5 ---&gt; oistins
# Processing Record 27 of Set 5 ---&gt; nasaud
# Processing Record 28 of Set 5 ---&gt; voronovytsya
# Processing Record 29 of Set 5 ---&gt; kralendijk
# Processing Record 30 of Set 5 ---&gt; sao jose da coroa grande
# Processing Record 31 of Set 5 ---&gt; tateyama
# saint anthony not found. Proceeding to the next city...
# Processing Record 32 of Set 5 ---&gt; negresti-oas
# Processing Record 33 of Set 5 ---&gt; axim
# Processing Record 34 of Set 5 ---&gt; faya
# Processing Record 35 of Set 5 ---&gt; kalmunai
# Processing Record 36 of Set 5 ---&gt; mareeba
# Processing Record 37 of Set 5 ---&gt; ashqelon
# kamenskoye not found. Proceeding to the next city...
# Processing Record 38 of Set 5 ---&gt; tiznit
# Processing Record 39 of Set 5 ---&gt; luganville
# stantsiya gorchakovo not found. Proceeding to the next city...
# Processing Record 40 of Set 5 ---&gt; shache
# Processing Record 41 of Set 5 ---&gt; thenzawl
# Processing Record 42 of Set 5 ---&gt; maniitsoq
# Processing Record 43 of Set 5 ---&gt; port elizabeth
# Processing Record 44 of Set 5 ---&gt; port lincoln
# Processing Record 45 of Set 5 ---&gt; severo-kurilsk
# Processing Record 46 of Set 5 ---&gt; carutapera
# Processing Record 47 of Set 5 ---&gt; upernavik
# sfantu gheorghe not found. Proceeding to the next city...
# Processing Record 48 of Set 5 ---&gt; inhambane
# Processing Record 49 of Set 5 ---&gt; yumen
# Processing Record 50 of Set 5 ---&gt; baykit
# Processing Record 1 of Set 6 ---&gt; saint-louis
# Processing Record 2 of Set 6 ---&gt; vostok
# Processing Record 3 of Set 6 ---&gt; grindavik
# Processing Record 4 of Set 6 ---&gt; haines junction
# Processing Record 5 of Set 6 ---&gt; airai
# sanlucar de barrameda not found. Proceeding to the next city...
# Processing Record 6 of Set 6 ---&gt; pevek
# Processing Record 7 of Set 6 ---&gt; leningradskiy
# labutta not found. Proceeding to the next city...
# Processing Record 8 of Set 6 ---&gt; badou
# Processing Record 9 of Set 6 ---&gt; parrita
# Processing Record 10 of Set 6 ---&gt; christchurch
# Processing Record 11 of Set 6 ---&gt; bilma
# Processing Record 12 of Set 6 ---&gt; buin
# Processing Record 13 of Set 6 ---&gt; darnah
# Processing Record 14 of Set 6 ---&gt; aquiraz
# Processing Record 15 of Set 6 ---&gt; yerbogachen
# Processing Record 16 of Set 6 ---&gt; rincon
# Processing Record 17 of Set 6 ---&gt; chara
# alotau not found. Proceeding to the next city...
# Processing Record 18 of Set 6 ---&gt; nhulunbuy
# Processing Record 19 of Set 6 ---&gt; salihorsk
# barawe not found. Proceeding to the next city...
# Processing Record 20 of Set 6 ---&gt; beira
# Processing Record 21 of Set 6 ---&gt; west bay
# artyk not found. Proceeding to the next city...
# Processing Record 22 of Set 6 ---&gt; sola
# Processing Record 23 of Set 6 ---&gt; egvekinot
# Processing Record 24 of Set 6 ---&gt; hambantota
# wulanhaote not found. Proceeding to the next city...
# Processing Record 25 of Set 6 ---&gt; provideniya
# Processing Record 26 of Set 6 ---&gt; san rafael
# Processing Record 27 of Set 6 ---&gt; sept-iles
# Processing Record 28 of Set 6 ---&gt; severodvinsk
# Processing Record 29 of Set 6 ---&gt; yarega
# Processing Record 30 of Set 6 ---&gt; solnechnyy
# Processing Record 31 of Set 6 ---&gt; tura
# Processing Record 32 of Set 6 ---&gt; champerico
# Processing Record 33 of Set 6 ---&gt; forbes
# Processing Record 34 of Set 6 ---&gt; duldurga
# Processing Record 35 of Set 6 ---&gt; mereni
# Processing Record 36 of Set 6 ---&gt; brigham city
# Processing Record 37 of Set 6 ---&gt; ardakan
# Processing Record 38 of Set 6 ---&gt; pacific grove
# Processing Record 39 of Set 6 ---&gt; harnosand
# Processing Record 40 of Set 6 ---&gt; vanimo
# Processing Record 41 of Set 6 ---&gt; mehriz
# Processing Record 42 of Set 6 ---&gt; almaznyy
# Processing Record 43 of Set 6 ---&gt; kihei
# Processing Record 44 of Set 6 ---&gt; ilulissat
# Processing Record 45 of Set 6 ---&gt; bathsheba
# nizhneyansk not found. Proceeding to the next city...
# Processing Record 46 of Set 6 ---&gt; kahului
# Processing Record 47 of Set 6 ---&gt; ribeirao branco
# Processing Record 48 of Set 6 ---&gt; corner brook
# Processing Record 49 of Set 6 ---&gt; gisborne
# Processing Record 50 of Set 6 ---&gt; zaozerne
# sentyabrskiy not found. Proceeding to the next city...
# Processing Record 1 of Set 7 ---&gt; meulaboh
# mancio lima not found. Proceeding to the next city...
# Processing Record 2 of Set 7 ---&gt; asau
# Processing Record 3 of Set 7 ---&gt; bulungu
# Processing Record 4 of Set 7 ---&gt; nouadhibou
# Processing Record 5 of Set 7 ---&gt; lively
# buqayq not found. Proceeding to the next city...
# Processing Record 6 of Set 7 ---&gt; adelaide
# Processing Record 7 of Set 7 ---&gt; torbay
# Processing Record 8 of Set 7 ---&gt; orange cove
# Processing Record 9 of Set 7 ---&gt; nemuro
# Processing Record 10 of Set 7 ---&gt; kushiro
# Processing Record 11 of Set 7 ---&gt; urengoy
# Processing Record 12 of Set 7 ---&gt; mwadui
# Processing Record 13 of Set 7 ---&gt; salym
# Processing Record 14 of Set 7 ---&gt; yaan
# Processing Record 15 of Set 7 ---&gt; blantyre
# Processing Record 16 of Set 7 ---&gt; alihe
# Processing Record 17 of Set 7 ---&gt; fort nelson
# Processing Record 18 of Set 7 ---&gt; villa carlos paz
# Processing Record 19 of Set 7 ---&gt; erenhot
# Processing Record 20 of Set 7 ---&gt; basco
# Processing Record 21 of Set 7 ---&gt; paita
# vaitupu not found. Proceeding to the next city...
# Processing Record 22 of Set 7 ---&gt; koumac
# Processing Record 23 of Set 7 ---&gt; bilibino
# Processing Record 24 of Set 7 ---&gt; dallas
# hvammstangi not found. Proceeding to the next city...
# Processing Record 25 of Set 7 ---&gt; nanma
# Processing Record 26 of Set 7 ---&gt; roma
# Processing Record 27 of Set 7 ---&gt; sampit
# Processing Record 28 of Set 7 ---&gt; mayumba
# Processing Record 29 of Set 7 ---&gt; lahaina
# wichian buri not found. Proceeding to the next city...
# Processing Record 30 of Set 7 ---&gt; geilo
# Processing Record 31 of Set 7 ---&gt; codrington
# Processing Record 32 of Set 7 ---&gt; igarka
# Processing Record 33 of Set 7 ---&gt; dongsheng
# Processing Record 34 of Set 7 ---&gt; lata
# Processing Record 35 of Set 7 ---&gt; katangli
# Processing Record 36 of Set 7 ---&gt; college
# Processing Record 37 of Set 7 ---&gt; grimshaw
# Processing Record 38 of Set 7 ---&gt; puerto del rosario
# Processing Record 39 of Set 7 ---&gt; flinders
# Processing Record 40 of Set 7 ---&gt; bondo
# Processing Record 41 of Set 7 ---&gt; talaya
# Processing Record 42 of Set 7 ---&gt; zunyi
# Processing Record 43 of Set 7 ---&gt; erdenet
# tasbuget not found. Proceeding to the next city...
# denau not found. Proceeding to the next city...
# Processing Record 44 of Set 7 ---&gt; ancud
# Processing Record 45 of Set 7 ---&gt; rensvik
# Processing Record 46 of Set 7 ---&gt; melilla
# Processing Record 47 of Set 7 ---&gt; claudio
# Processing Record 48 of Set 7 ---&gt; alyangula
# Processing Record 49 of Set 7 ---&gt; taos
# Processing Record 50 of Set 7 ---&gt; kununurra
# Processing Record 1 of Set 8 ---&gt; touros
# Processing Record 2 of Set 8 ---&gt; abu samrah
# Processing Record 3 of Set 8 ---&gt; mount gambier
# Processing Record 4 of Set 8 ---&gt; vredendal
# Processing Record 5 of Set 8 ---&gt; kiama
# Processing Record 6 of Set 8 ---&gt; kieta
# Processing Record 7 of Set 8 ---&gt; xuddur
# Processing Record 8 of Set 8 ---&gt; husavik
# Processing Record 9 of Set 8 ---&gt; saint-joseph
# Processing Record 10 of Set 8 ---&gt; kruisfontein
# Processing Record 11 of Set 8 ---&gt; port blair
# Processing Record 12 of Set 8 ---&gt; jinka
# ngukurr not found. Proceeding to the next city...
# Processing Record 13 of Set 8 ---&gt; makakilo city
# Processing Record 14 of Set 8 ---&gt; ponta do sol
# rungata not found. Proceeding to the next city...
# Processing Record 15 of Set 8 ---&gt; byron bay
# Processing Record 16 of Set 8 ---&gt; rio gallegos
# Processing Record 17 of Set 8 ---&gt; ambilobe
# Processing Record 18 of Set 8 ---&gt; shashi
# Processing Record 19 of Set 8 ---&gt; pontes e lacerda
# Processing Record 20 of Set 8 ---&gt; sur
# Processing Record 21 of Set 8 ---&gt; pyapon
# Processing Record 22 of Set 8 ---&gt; cockburn town
# Processing Record 23 of Set 8 ---&gt; arrifes
# Processing Record 24 of Set 8 ---&gt; berlevag
# Processing Record 25 of Set 8 ---&gt; sabang
# Processing Record 26 of Set 8 ---&gt; marion
# Processing Record 27 of Set 8 ---&gt; qinggang
# Processing Record 28 of Set 8 ---&gt; avera
# Processing Record 29 of Set 8 ---&gt; bridlington
# Processing Record 30 of Set 8 ---&gt; zlobin
# Processing Record 31 of Set 8 ---&gt; batagay
# Processing Record 32 of Set 8 ---&gt; nueva concepcion
# Processing Record 33 of Set 8 ---&gt; kaa-khem
# Processing Record 34 of Set 8 ---&gt; praia da vitoria
# Processing Record 35 of Set 8 ---&gt; tilichiki
# burkhala not found. Proceeding to the next city...
# Processing Record 36 of Set 8 ---&gt; raymond
# Processing Record 37 of Set 8 ---&gt; ashland
# Processing Record 38 of Set 8 ---&gt; dryden
# Processing Record 39 of Set 8 ---&gt; zhongxing
# Processing Record 40 of Set 8 ---&gt; madras
# Processing Record 41 of Set 8 ---&gt; havre-saint-pierre
# Processing Record 42 of Set 8 ---&gt; corrales
# Processing Record 43 of Set 8 ---&gt; lubbock
# Processing Record 44 of Set 8 ---&gt; conde
# Processing Record 45 of Set 8 ---&gt; bowen
# Processing Record 46 of Set 8 ---&gt; eureka
# Processing Record 47 of Set 8 ---&gt; dudinka
# Processing Record 48 of Set 8 ---&gt; porto velho
# Processing Record 49 of Set 8 ---&gt; prince rupert
# Processing Record 50 of Set 8 ---&gt; belaya gora
# Processing Record 1 of Set 9 ---&gt; aktash
# Processing Record 2 of Set 9 ---&gt; ayagoz
# Processing Record 3 of Set 9 ---&gt; san quintin
# Processing Record 4 of Set 9 ---&gt; itarema
# Processing Record 5 of Set 9 ---&gt; tobol
# Processing Record 6 of Set 9 ---&gt; warman
# Processing Record 7 of Set 9 ---&gt; mnogovershinnyy
# Processing Record 8 of Set 9 ---&gt; gemena
# Processing Record 9 of Set 9 ---&gt; oussouye
# Processing Record 10 of Set 9 ---&gt; tocopilla
# Processing Record 11 of Set 9 ---&gt; visby
# Processing Record 12 of Set 9 ---&gt; karpogory
# Processing Record 13 of Set 9 ---&gt; chumikan
# Processing Record 14 of Set 9 ---&gt; birao
# Processing Record 15 of Set 9 ---&gt; leopold
# Processing Record 16 of Set 9 ---&gt; kabalo
# Processing Record 17 of Set 9 ---&gt; tabligbo
# Processing Record 18 of Set 9 ---&gt; sinop
# Processing Record 19 of Set 9 ---&gt; piraju
# Processing Record 20 of Set 9 ---&gt; afua
# Processing Record 21 of Set 9 ---&gt; pio ix
# Processing Record 22 of Set 9 ---&gt; sorland
# Processing Record 23 of Set 9 ---&gt; aden
# Processing Record 24 of Set 9 ---&gt; san pedro de macoris
# Processing Record 25 of Set 9 ---&gt; halifax
# Processing Record 26 of Set 9 ---&gt; sao filipe
# Processing Record 27 of Set 9 ---&gt; peleduy
# Processing Record 28 of Set 9 ---&gt; krumovgrad
# sinkat not found. Proceeding to the next city...
# tsihombe not found. Proceeding to the next city...
# Processing Record 29 of Set 9 ---&gt; talnakh
# Processing Record 30 of Set 9 ---&gt; ponorogo
# Processing Record 31 of Set 9 ---&gt; amot
# Processing Record 32 of Set 9 ---&gt; talcahuano
# Processing Record 33 of Set 9 ---&gt; kulim
# umm lajj not found. Proceeding to the next city...
# Processing Record 34 of Set 9 ---&gt; grand river south east
# Processing Record 35 of Set 9 ---&gt; ahipara
# Processing Record 36 of Set 9 ---&gt; wajir
# Processing Record 37 of Set 9 ---&gt; barcelona
# saryshagan not found. Proceeding to the next city...
# Processing Record 38 of Set 9 ---&gt; manavalakurichi
# Processing Record 39 of Set 9 ---&gt; cagayan de tawi-tawi
# Processing Record 40 of Set 9 ---&gt; rawson
# lolua not found. Proceeding to the next city...
# Processing Record 41 of Set 9 ---&gt; khor
# Processing Record 42 of Set 9 ---&gt; vicuna
# Processing Record 43 of Set 9 ---&gt; sumbe
# Processing Record 44 of Set 9 ---&gt; coihueco
# Processing Record 45 of Set 9 ---&gt; ventspils
# Processing Record 46 of Set 9 ---&gt; kashan
# Processing Record 47 of Set 9 ---&gt; takaka
# Processing Record 48 of Set 9 ---&gt; moron
# Processing Record 49 of Set 9 ---&gt; navlya
# Processing Record 50 of Set 9 ---&gt; vila franca do campo
# Processing Record 1 of Set 10 ---&gt; xining
# Processing Record 2 of Set 10 ---&gt; lusambo
# Processing Record 3 of Set 10 ---&gt; pingliang
# nguiu not found. Proceeding to the next city...
# Processing Record 4 of Set 10 ---&gt; kandrian
# Processing Record 5 of Set 10 ---&gt; barranco de loba
# Processing Record 6 of Set 10 ---&gt; salalah
# Processing Record 7 of Set 10 ---&gt; nsanje
# Processing Record 8 of Set 10 ---&gt; cockburn harbour
# Processing Record 9 of Set 10 ---&gt; katsuura
# Processing Record 10 of Set 10 ---&gt; dunedin
# Processing Record 11 of Set 10 ---&gt; mahajanga
# Processing Record 12 of Set 10 ---&gt; emba
# Processing Record 13 of Set 10 ---&gt; goure
# Processing Record 14 of Set 10 ---&gt; charleston
# Processing Record 15 of Set 10 ---&gt; sonqor
# Processing Record 16 of Set 10 ---&gt; yei
# Processing Record 17 of Set 10 ---&gt; isangel
# Processing Record 18 of Set 10 ---&gt; jalingo
# Processing Record 19 of Set 10 ---&gt; mount isa
# Processing Record 20 of Set 10 ---&gt; lorengau
# moiyabana not found. Proceeding to the next city...
# Processing Record 21 of Set 10 ---&gt; manta
# Processing Record 22 of Set 10 ---&gt; repnoye
# Processing Record 23 of Set 10 ---&gt; trelew
# Processing Record 24 of Set 10 ---&gt; myitkyina
# Processing Record 25 of Set 10 ---&gt; mechanicsville
# Processing Record 26 of Set 10 ---&gt; novobelokatay
# la ronge not found. Proceeding to the next city...
# Processing Record 27 of Set 10 ---&gt; pangnirtung
# Processing Record 28 of Set 10 ---&gt; ziro
# Processing Record 29 of Set 10 ---&gt; bandarbeyla
# Processing Record 30 of Set 10 ---&gt; menongue
# Processing Record 31 of Set 10 ---&gt; siderno
# Processing Record 32 of Set 10 ---&gt; bubaque
# tabiauea not found. Proceeding to the next city...
# Processing Record 33 of Set 10 ---&gt; comodoro rivadavia
# Processing Record 34 of Set 10 ---&gt; tabuk
# Processing Record 35 of Set 10 ---&gt; atherton
# Processing Record 36 of Set 10 ---&gt; imbituba
# Processing Record 37 of Set 10 ---&gt; niort
# Processing Record 38 of Set 10 ---&gt; fukue
# Processing Record 39 of Set 10 ---&gt; sayyan
# Processing Record 40 of Set 10 ---&gt; matagami
# Processing Record 41 of Set 10 ---&gt; carahue
# Processing Record 42 of Set 10 ---&gt; ketchikan
# Processing Record 43 of Set 10 ---&gt; teya
# Processing Record 44 of Set 10 ---&gt; kapit
# Processing Record 45 of Set 10 ---&gt; hasaki
# Processing Record 46 of Set 10 ---&gt; guane
# Processing Record 47 of Set 10 ---&gt; nahrin
# Processing Record 48 of Set 10 ---&gt; carballo
# Processing Record 49 of Set 10 ---&gt; ambovombe
# Processing Record 50 of Set 10 ---&gt; abyek
# Processing Record 1 of Set 11 ---&gt; namibe
# Processing Record 2 of Set 11 ---&gt; agadez
# Processing Record 3 of Set 11 ---&gt; marienburg
# Processing Record 4 of Set 11 ---&gt; promyshlennyy
# Processing Record 5 of Set 11 ---&gt; terrace bay
# Processing Record 6 of Set 11 ---&gt; darhan
# Processing Record 7 of Set 11 ---&gt; altus
# great yarmouth not found. Proceeding to the next city...
# dok kham tai not found. Proceeding to the next city...
# Processing Record 8 of Set 11 ---&gt; komsomolskiy
# Processing Record 9 of Set 11 ---&gt; chichli
# kuhestan not found. Proceeding to the next city...
# louisbourg not found. Proceeding to the next city...
# Processing Record 10 of Set 11 ---&gt; ihosy
# Processing Record 11 of Set 11 ---&gt; jieshi
# Processing Record 12 of Set 11 ---&gt; bontang
# Processing Record 13 of Set 11 ---&gt; viedma
# Processing Record 14 of Set 11 ---&gt; komsomolets
# Processing Record 15 of Set 11 ---&gt; pangody
# Processing Record 16 of Set 11 ---&gt; fenoarivo atsinanana
# Processing Record 17 of Set 11 ---&gt; mayo
# Processing Record 18 of Set 11 ---&gt; lira
# Processing Record 19 of Set 11 ---&gt; tshikapa
# Processing Record 20 of Set 11 ---&gt; aanekoski
# viligili not found. Proceeding to the next city...
# Processing Record 21 of Set 11 ---&gt; aksu
# Processing Record 22 of Set 11 ---&gt; shenjiamen
# Processing Record 23 of Set 11 ---&gt; beisfjord
# Processing Record 24 of Set 11 ---&gt; karratha
# Processing Record 25 of Set 11 ---&gt; puerto escondido
# la palma not found. Proceeding to the next city...
# Processing Record 26 of Set 11 ---&gt; raduzhnyy
# Processing Record 27 of Set 11 ---&gt; soe
# Processing Record 28 of Set 11 ---&gt; petropavlovsk-kamchatskiy
# great sankey not found. Proceeding to the next city...
# Processing Record 29 of Set 11 ---&gt; kewanee
# Processing Record 30 of Set 11 ---&gt; boende
# Processing Record 31 of Set 11 ---&gt; ninotsminda
# Processing Record 32 of Set 11 ---&gt; vengerovo
# Processing Record 33 of Set 11 ---&gt; gorin
# malwan not found. Proceeding to the next city...
# Processing Record 34 of Set 11 ---&gt; keffi
# Processing Record 35 of Set 11 ---&gt; willmar
# Processing Record 36 of Set 11 ---&gt; lodja
# Processing Record 37 of Set 11 ---&gt; davila
# mutsamudu not found. Proceeding to the next city...
# Processing Record 38 of Set 11 ---&gt; castanos
# Processing Record 39 of Set 11 ---&gt; bumba
# Processing Record 40 of Set 11 ---&gt; urucara
# Processing Record 41 of Set 11 ---&gt; shakawe
# Processing Record 42 of Set 11 ---&gt; matay
# Processing Record 43 of Set 11 ---&gt; tsiroanomandidy
# Processing Record 44 of Set 11 ---&gt; cangzhou
# *******************************
# Data Retrieval Complete
# *******************************

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# The data generated from the API calls will be compiled into a new Data Fram
weather_data_frame = pd.DataFrame({
    'City':updated_city_list,
    'Lattitude':lattitude,
    'Longitude': longitude,
    'Max Temp': max_temp,
    'Humidity': humidity,
    'Cloudiness': cloudinesses,
    'Wind Speed': wind,
    'Country': country_list,
    'Date':dates
})

## Exporting the new DataFrame into a csv file
weather_data_frame.to_csv('..\Output_Data\Weather_Data_Collection.csv')

## Displaying the DataFrame
print(f'{weather_data_frame.shape[0]} cities, along with their weather information, have been collated\n')
weather_data_frame.head()
# Out:
# 544 cities, along with their weather information, have been collated
#         City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0   portland      45.52    -122.68     20.00        84           0
# 1     hobart     -42.88     147.33     15.00        38          75
# 2    chapais      49.78     -74.85      7.00       100          90
# 3  kavarskas      55.43      24.92      9.16        74         100
# 4  fairbanks      64.84    -147.72     13.00        43           1
#
#    Wind Speed Country        Date
# 0        1.18      US  1601529367
# 1        4.60      AU  1601529298
# 2        2.10      CA  1601529581
# 3        4.92      LT  1601529581
# 4        3.10      US  1601529313

# %%
## Summary Statistics 
weather_data_frame.describe()
# Out:
#         Lattitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  544.000000  544.000000  544.000000  544.000000  544.000000  544.000000
# mean    21.918419   23.223860   17.480754   71.457721   50.908088    3.449651
# std     32.463103   86.878658    9.124651   20.230305   37.762449    2.342981
# min    -54.800000 -179.170000  -11.670000    9.000000    0.000000    0.120000
# 25%     -3.587500  -48.847500   11.000000   61.000000   14.750000    1.707500
# 50%     28.845000   25.710000   18.000000   75.000000   50.500000    3.030000
# 75%     48.880000   95.792500   25.000000   87.000000   90.000000    4.600000
# max     78.220000  179.320000   37.670000  100.000000  100.000000   15.530000
#
#                Date
# count  5.440000e+02
# mean   1.601530e+09
# std    1.170411e+02
# min    1.601529e+09
# 25%    1.601530e+09
# 50%    1.601530e+09
# 75%    1.601530e+09
# max    1.601530e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking to see if there are cities with humidities over 100
weather_data_frame[weather_data_frame['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lattitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames_Over100 = weather_data_frame[weather_data_frame['Humidity']>100].index

# %%
if (len(indexNames_Over100)) > 0:
    print(f'There are cities with humidity over 100')
else:
    print(f'There are no cities with humidity over 100')
# Out:
# There are no cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data_frame.drop(indexNames_Over100, inplace=False)

# %%
print(f'There are {clean_city_data.shape[0]} cities to be assessed\n')
clean_city_data.head()
# Out:
# There are 544 cities to be assessed
#         City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0   portland      45.52    -122.68     20.00        84           0
# 1     hobart     -42.88     147.33     15.00        38          75
# 2    chapais      49.78     -74.85      7.00       100          90
# 3  kavarskas      55.43      24.92      9.16        74         100
# 4  fairbanks      64.84    -147.72     13.00        43           1
#
#    Wind Speed Country        Date
# 0        1.18      US  1601529367
# 1        4.60      AU  1601529298
# 2        2.10      CA  1601529581
# 3        4.92      LT  1601529581
# 4        3.10      US  1601529313

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# A scatter plot will be used in order to determine the relationship between temperature and lattitudes
x_lattitude = clean_city_data['Lattitude']
y_temperature = clean_city_data['Max Temp']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Temperature',fontsize=15)
ax1.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_temperature, edgecolors='black', c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Temperature.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# We will use the previous x_label and create a new Y label pertaining to humidity
y_humidity = clean_city_data['Humidity']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Humidity',fontsize=15)
ax1.set_ylabel('Humidity', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_humidity, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Humidity.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# We will set a new y_ variable pertaining to Cloudiness
y_cloudiness = clean_city_data['Cloudiness']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Cloudiness',fontsize=15)
ax1.set_ylabel('Cloudiness(%)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_cloudiness, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Cloudiness.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# We wil set a new y_ variable pertaining to Wind Speed
y_windspeed = clean_city_data['Wind Speed']
fig1, ax1 = plt.subplots()
ax1.set_title('City Latitude vs Wind Speed',fontsize=15)
ax1.set_ylabel('Wind Speed (mph)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_windspeed, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_WindSpeed.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Northern Hemisphere Latitudes vs Max Temperature

# %%
# All cities within the Northern Hemisphere will be in the lattitude range of 0(equator) to 90. 
# We will need to filter the dataframe to contain cities within the northern hemisphere (nh)

northern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']>=0]

x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_max_temp = northern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_max_temp)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Max_Temp.png')
print(f'The r-squaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-squaured value is 0.757334935305191
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# All cities within the Southern Hemisphere will be in the lattitude range of 0(equator) to -90. 
# We will need to filter the dataframe to contain cities within the southern hemisphere (sh)

southern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']<=0]

x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_max_temp = southern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_max_temp)

# Linear Regression Label
line_eq_sh = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit_sh = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Max Temp vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit_sh,'black')
ax2.scatter(x_sh_latitude,y_sh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.49739158549806917
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_humidity = northern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.028638059773086408
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_humidity = southern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Humidity vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.012381222366731526
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_cloudiness = northern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.02396627468637211
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_cloudiness = southern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Cloudiness vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.0029940035672979637
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_windspeed = northern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('NH Windspeed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Windspeed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.010557154467094855
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_windspeed = southern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title('SH Wind Speed vs. Latitude Linear Regression',fontsize=15)
ax2.set_ylabel('Wind Speed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.027898756894729704
# &lt;Figure size 432x288 with 1 Axes&gt;

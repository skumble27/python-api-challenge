# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing the relevant modules for weather analyses
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import scipy.stats as st
import matplotlib
from datetime import datetime

# Importing the API Key
from api_keys import weather_api_key

# Setting Unit of Measurement for Temperature
celsius ='metric'

# Setting up the query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={celsius}&q="

# Creating a timestamp to plot in the graphs
current_time = datetime.now()

# %% [markdown]
# ## Generate Cities List

# %%
# Preparing lists to store random lattitude and longitude coordinates
random_lat_long = []
city_names = []

# Creting Random Lattitudes
ran_lattitude = np.random.uniform(low=-90.000, high=90.000, size=1500)
ran_longitude = np.random.uniform(low=-180.000, high=180.000, size=1500)
random_lat_long = zip(ran_lattitude,ran_longitude)

# Assigning the nearest city to the coordinates
for lat_long in random_lat_long:
    city = citipy.nearest_city(lat_long[0],lat_long[1]).city_name

    # Ensuring only unique city names are added
    if city in city_names:
        next
    else:
        city_names.append(city)
print(f'The number of cities added are {len(city_names)}')
# Out:
# The number of cities added are 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
updated_city_list = []
cloudinesses = []
dates = []
humidity = []
lattitude = []
longitude = []
max_temp = []
wind = []
country_list = []

# set initial count quantities for organization
record_number = 0
record_sets = 1

# loops for creating dataframe columns
print(f'Data Retreival commencing\n---------------------\n')
for city in city_names:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lattitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        if record_number > 49:
            record_number = 1
            record_sets += 1
            updated_city_list.append(city)
        else:
            record_number += 1
            updated_city_list.append(city)
        print(f"Processing Record {record_number} of Set {record_sets} ---> {city}")
    except Exception:
        print(f"{city} not found. Proceeding to the next city...")
print("*******************************")
print("Data Retrieval Complete\n*******************************")
# Out:
# Data Retreival commencing
# ---------------------
#
# Processing Record 1 of Set 1 ---&gt; bredasdorp
# Processing Record 2 of Set 1 ---&gt; ostrovnoy
# Processing Record 3 of Set 1 ---&gt; khandbari
# Processing Record 4 of Set 1 ---&gt; atar
# Processing Record 5 of Set 1 ---&gt; severo-kurilsk
# Processing Record 6 of Set 1 ---&gt; hervey bay
# Processing Record 7 of Set 1 ---&gt; new norfolk
# Processing Record 8 of Set 1 ---&gt; dalvik
# Processing Record 9 of Set 1 ---&gt; hithadhoo
# Processing Record 10 of Set 1 ---&gt; cape town
# Processing Record 11 of Set 1 ---&gt; ancud
# Processing Record 12 of Set 1 ---&gt; albany
# Processing Record 13 of Set 1 ---&gt; dikson
# Processing Record 14 of Set 1 ---&gt; ribeira grande
# Processing Record 15 of Set 1 ---&gt; victoria
# Processing Record 16 of Set 1 ---&gt; davidson
# Processing Record 17 of Set 1 ---&gt; castro
# Processing Record 18 of Set 1 ---&gt; hermanus
# Processing Record 19 of Set 1 ---&gt; forestville
# Processing Record 20 of Set 1 ---&gt; flin flon
# Processing Record 21 of Set 1 ---&gt; bluff
# Processing Record 22 of Set 1 ---&gt; mataura
# Processing Record 23 of Set 1 ---&gt; ushuaia
# Processing Record 24 of Set 1 ---&gt; barrow
# Processing Record 25 of Set 1 ---&gt; egvekinot
# Processing Record 26 of Set 1 ---&gt; akureyri
# Processing Record 27 of Set 1 ---&gt; fortuna
# Processing Record 28 of Set 1 ---&gt; broome
# Processing Record 29 of Set 1 ---&gt; pacific grove
# Processing Record 30 of Set 1 ---&gt; yumen
# Processing Record 31 of Set 1 ---&gt; qaanaaq
# Processing Record 32 of Set 1 ---&gt; ponta do sol
# Processing Record 33 of Set 1 ---&gt; leh
# Processing Record 34 of Set 1 ---&gt; nikolskoye
# Processing Record 35 of Set 1 ---&gt; san cristobal
# Processing Record 36 of Set 1 ---&gt; ziguinchor
# Processing Record 37 of Set 1 ---&gt; skjervoy
# Processing Record 38 of Set 1 ---&gt; sao pedro do sul
# Processing Record 39 of Set 1 ---&gt; kumluca
# Processing Record 40 of Set 1 ---&gt; parkes
# Processing Record 41 of Set 1 ---&gt; rikitea
# Processing Record 42 of Set 1 ---&gt; hobart
# Processing Record 43 of Set 1 ---&gt; mys shmidta
# Processing Record 44 of Set 1 ---&gt; hasaki
# Processing Record 45 of Set 1 ---&gt; lisakovsk
# Processing Record 46 of Set 1 ---&gt; vila franca do campo
# Processing Record 47 of Set 1 ---&gt; kapaa
# Processing Record 48 of Set 1 ---&gt; kieta
# Processing Record 49 of Set 1 ---&gt; hammerfest
# Processing Record 50 of Set 1 ---&gt; mount gambier
# Processing Record 1 of Set 2 ---&gt; adrar
# Processing Record 2 of Set 2 ---&gt; atuona
# Processing Record 3 of Set 2 ---&gt; batamshinskiy
# Processing Record 4 of Set 2 ---&gt; valdemarpils
# Processing Record 5 of Set 2 ---&gt; havelock
# Processing Record 6 of Set 2 ---&gt; kuala terengganu
# Processing Record 7 of Set 2 ---&gt; butaritari
# Processing Record 8 of Set 2 ---&gt; katsuura
# Processing Record 9 of Set 2 ---&gt; bykovo
# Processing Record 10 of Set 2 ---&gt; van
# Processing Record 11 of Set 2 ---&gt; shimoda
# amderma not found. Proceeding to the next city...
# Processing Record 12 of Set 2 ---&gt; kodiak
# hihifo not found. Proceeding to the next city...
# Processing Record 13 of Set 2 ---&gt; longyearbyen
# Processing Record 14 of Set 2 ---&gt; kinablangan
# Processing Record 15 of Set 2 ---&gt; iracoubo
# Processing Record 16 of Set 2 ---&gt; cape canaveral
# marcona not found. Proceeding to the next city...
# Processing Record 17 of Set 2 ---&gt; hamilton
# Processing Record 18 of Set 2 ---&gt; akyab
# Processing Record 19 of Set 2 ---&gt; lebu
# Processing Record 20 of Set 2 ---&gt; taihe
# Processing Record 21 of Set 2 ---&gt; jardim do serido
# Processing Record 22 of Set 2 ---&gt; punta arenas
# Processing Record 23 of Set 2 ---&gt; vanavara
# Processing Record 24 of Set 2 ---&gt; mehamn
# Processing Record 25 of Set 2 ---&gt; vaini
# ambodifototra not found. Proceeding to the next city...
# Processing Record 26 of Set 2 ---&gt; eravur
# Processing Record 27 of Set 2 ---&gt; laguna
# Processing Record 28 of Set 2 ---&gt; hilo
# Processing Record 29 of Set 2 ---&gt; jamestown
# Processing Record 30 of Set 2 ---&gt; grand river south east
# Processing Record 31 of Set 2 ---&gt; puerto ayora
# Processing Record 32 of Set 2 ---&gt; tuktoyaktuk
# Processing Record 33 of Set 2 ---&gt; marathon
# Processing Record 34 of Set 2 ---&gt; tasiilaq
# Processing Record 35 of Set 2 ---&gt; nome
# Processing Record 36 of Set 2 ---&gt; khatanga
# Processing Record 37 of Set 2 ---&gt; wattegama
# Processing Record 38 of Set 2 ---&gt; yellowknife
# Processing Record 39 of Set 2 ---&gt; chuy
# Processing Record 40 of Set 2 ---&gt; nabire
# Processing Record 41 of Set 2 ---&gt; talcahuano
# Processing Record 42 of Set 2 ---&gt; itarema
# Processing Record 43 of Set 2 ---&gt; chokurdakh
# Processing Record 44 of Set 2 ---&gt; coihaique
# Processing Record 45 of Set 2 ---&gt; phan thiet
# Processing Record 46 of Set 2 ---&gt; upernavik
# Processing Record 47 of Set 2 ---&gt; busselton
# Processing Record 48 of Set 2 ---&gt; flinders
# Processing Record 49 of Set 2 ---&gt; mar del plata
# Processing Record 50 of Set 2 ---&gt; doka
# Processing Record 1 of Set 3 ---&gt; biloela
# Processing Record 2 of Set 3 ---&gt; vostok
# chupei not found. Proceeding to the next city...
# Processing Record 3 of Set 3 ---&gt; lagoa
# Processing Record 4 of Set 3 ---&gt; garavuti
# Processing Record 5 of Set 3 ---&gt; bonavista
# Processing Record 6 of Set 3 ---&gt; avarua
# Processing Record 7 of Set 3 ---&gt; east london
# Processing Record 8 of Set 3 ---&gt; port alfred
# Processing Record 9 of Set 3 ---&gt; petropavlovsk-kamchatskiy
# Processing Record 10 of Set 3 ---&gt; ligayan
# Processing Record 11 of Set 3 ---&gt; esperance
# Processing Record 12 of Set 3 ---&gt; salalah
# Processing Record 13 of Set 3 ---&gt; bow island
# belushya guba not found. Proceeding to the next city...
# Processing Record 14 of Set 3 ---&gt; nuuk
# Processing Record 15 of Set 3 ---&gt; gladstone
# Processing Record 16 of Set 3 ---&gt; faanui
# wanderlandia not found. Proceeding to the next city...
# Processing Record 17 of Set 3 ---&gt; safaga
# illoqqortoormiut not found. Proceeding to the next city...
# Processing Record 18 of Set 3 ---&gt; bud
# Processing Record 19 of Set 3 ---&gt; thompson
# samalaeulu not found. Proceeding to the next city...
# Processing Record 20 of Set 3 ---&gt; nanortalik
# Processing Record 21 of Set 3 ---&gt; mitu
# Processing Record 22 of Set 3 ---&gt; bubaque
# Processing Record 23 of Set 3 ---&gt; libreville
# Processing Record 24 of Set 3 ---&gt; dingle
# Processing Record 25 of Set 3 ---&gt; talnakh
# Processing Record 26 of Set 3 ---&gt; lucapa
# Processing Record 27 of Set 3 ---&gt; saint-philippe
# Processing Record 28 of Set 3 ---&gt; jackson
# Processing Record 29 of Set 3 ---&gt; yulara
# Processing Record 30 of Set 3 ---&gt; zelenoborskiy
# Processing Record 31 of Set 3 ---&gt; conde
# Processing Record 32 of Set 3 ---&gt; bethel
# Processing Record 33 of Set 3 ---&gt; srednekolymsk
# Processing Record 34 of Set 3 ---&gt; rassvet
# Processing Record 35 of Set 3 ---&gt; dudinka
# Processing Record 36 of Set 3 ---&gt; andros town
# Processing Record 37 of Set 3 ---&gt; benguela
# Processing Record 38 of Set 3 ---&gt; pokhara
# Processing Record 39 of Set 3 ---&gt; bonfim
# Processing Record 40 of Set 3 ---&gt; cabra
# Processing Record 41 of Set 3 ---&gt; luderitz
# la ronge not found. Proceeding to the next city...
# Processing Record 42 of Set 3 ---&gt; pisco
# Processing Record 43 of Set 3 ---&gt; arapiraca
# Processing Record 44 of Set 3 ---&gt; port-cartier
# Processing Record 45 of Set 3 ---&gt; constantine
# chengmai not found. Proceeding to the next city...
# attawapiskat not found. Proceeding to the next city...
# Processing Record 46 of Set 3 ---&gt; gondanglegi
# Processing Record 47 of Set 3 ---&gt; marsabit
# Processing Record 48 of Set 3 ---&gt; miri
# Processing Record 49 of Set 3 ---&gt; tuatapere
# Processing Record 50 of Set 3 ---&gt; coquimbo
# samusu not found. Proceeding to the next city...
# Processing Record 1 of Set 4 ---&gt; port blair
# Processing Record 2 of Set 4 ---&gt; cabo san lucas
# Processing Record 3 of Set 4 ---&gt; tual
# Processing Record 4 of Set 4 ---&gt; ust-tsilma
# Processing Record 5 of Set 4 ---&gt; bollnas
# Processing Record 6 of Set 4 ---&gt; kahului
# Processing Record 7 of Set 4 ---&gt; whitehorse
# Processing Record 8 of Set 4 ---&gt; palembang
# Processing Record 9 of Set 4 ---&gt; bathsheba
# duz not found. Proceeding to the next city...
# Processing Record 10 of Set 4 ---&gt; kidal
# Processing Record 11 of Set 4 ---&gt; beidao
# taolanaro not found. Proceeding to the next city...
# Processing Record 12 of Set 4 ---&gt; orebro
# te anau not found. Proceeding to the next city...
# Processing Record 13 of Set 4 ---&gt; cabedelo
# Processing Record 14 of Set 4 ---&gt; svetlaya
# Processing Record 15 of Set 4 ---&gt; mahebourg
# Processing Record 16 of Set 4 ---&gt; kaitangata
# presidencia roque saenz pena not found. Proceeding to the next city...
# sentyabrskiy not found. Proceeding to the next city...
# Processing Record 17 of Set 4 ---&gt; pitimbu
# Processing Record 18 of Set 4 ---&gt; caravelas
# Processing Record 19 of Set 4 ---&gt; gazanjyk
# Processing Record 20 of Set 4 ---&gt; airai
# Processing Record 21 of Set 4 ---&gt; lashio
# Processing Record 22 of Set 4 ---&gt; naco
# Processing Record 23 of Set 4 ---&gt; urumqi
# Processing Record 24 of Set 4 ---&gt; inhambane
# Processing Record 25 of Set 4 ---&gt; kangaatsiaq
# Processing Record 26 of Set 4 ---&gt; borgo san dalmazzo
# mullaitivu not found. Proceeding to the next city...
# dzhusaly not found. Proceeding to the next city...
# Processing Record 27 of Set 4 ---&gt; berlevag
# Processing Record 28 of Set 4 ---&gt; tiksi
# Processing Record 29 of Set 4 ---&gt; lerwick
# Processing Record 30 of Set 4 ---&gt; itoman
# Processing Record 31 of Set 4 ---&gt; saint-augustin
# Processing Record 32 of Set 4 ---&gt; saskylakh
# Processing Record 33 of Set 4 ---&gt; maryborough
# saint george not found. Proceeding to the next city...
# la rioja not found. Proceeding to the next city...
# Processing Record 34 of Set 4 ---&gt; oranjestad
# Processing Record 35 of Set 4 ---&gt; isangel
# chagda not found. Proceeding to the next city...
# Processing Record 36 of Set 4 ---&gt; paulo afonso
# palabuhanratu not found. Proceeding to the next city...
# Processing Record 37 of Set 4 ---&gt; rocha
# Processing Record 38 of Set 4 ---&gt; fairbanks
# Processing Record 39 of Set 4 ---&gt; arcachon
# the valley not found. Proceeding to the next city...
# Processing Record 40 of Set 4 ---&gt; lahat
# Processing Record 41 of Set 4 ---&gt; namatanai
# Processing Record 42 of Set 4 ---&gt; chumikan
# Processing Record 43 of Set 4 ---&gt; tiznit
# Processing Record 44 of Set 4 ---&gt; torbay
# Processing Record 45 of Set 4 ---&gt; hofn
# Processing Record 46 of Set 4 ---&gt; comodoro rivadavia
# Processing Record 47 of Set 4 ---&gt; kenai
# Processing Record 48 of Set 4 ---&gt; georgetown
# Processing Record 49 of Set 4 ---&gt; vila velha
# Processing Record 50 of Set 4 ---&gt; penzance
# tumannyy not found. Proceeding to the next city...
# Processing Record 1 of Set 5 ---&gt; ola
# Processing Record 2 of Set 5 ---&gt; casper
# Processing Record 3 of Set 5 ---&gt; vieste
# Processing Record 4 of Set 5 ---&gt; payson
# tsihombe not found. Proceeding to the next city...
# Processing Record 5 of Set 5 ---&gt; hami
# Processing Record 6 of Set 5 ---&gt; nemuro
# Processing Record 7 of Set 5 ---&gt; lima
# Processing Record 8 of Set 5 ---&gt; lorengau
# Processing Record 9 of Set 5 ---&gt; bur gabo
# Processing Record 10 of Set 5 ---&gt; honiara
# la crosse not found. Proceeding to the next city...
# Processing Record 11 of Set 5 ---&gt; port-gentil
# Processing Record 12 of Set 5 ---&gt; sistranda
# Processing Record 13 of Set 5 ---&gt; springbok
# Processing Record 14 of Set 5 ---&gt; carmen
# Processing Record 15 of Set 5 ---&gt; cayenne
# Processing Record 16 of Set 5 ---&gt; padang
# Processing Record 17 of Set 5 ---&gt; cidreira
# Processing Record 18 of Set 5 ---&gt; isla vista
# Processing Record 19 of Set 5 ---&gt; vallenar
# Processing Record 20 of Set 5 ---&gt; amalfi
# Processing Record 21 of Set 5 ---&gt; port elizabeth
# Processing Record 22 of Set 5 ---&gt; san rafael
# Processing Record 23 of Set 5 ---&gt; norman wells
# toliary not found. Proceeding to the next city...
# Processing Record 24 of Set 5 ---&gt; necochea
# Processing Record 25 of Set 5 ---&gt; syava
# Processing Record 26 of Set 5 ---&gt; carballo
# Processing Record 27 of Set 5 ---&gt; chute-aux-outardes
# Processing Record 28 of Set 5 ---&gt; juegang
# Processing Record 29 of Set 5 ---&gt; bambanglipuro
# Processing Record 30 of Set 5 ---&gt; kapit
# Processing Record 31 of Set 5 ---&gt; kudahuvadhoo
# Processing Record 32 of Set 5 ---&gt; ust-maya
# Processing Record 33 of Set 5 ---&gt; constitucion
# Processing Record 34 of Set 5 ---&gt; tortoli
# Processing Record 35 of Set 5 ---&gt; shu
# Processing Record 36 of Set 5 ---&gt; pokoynoye
# Processing Record 37 of Set 5 ---&gt; port hardy
# pak phanang not found. Proceeding to the next city...
# Processing Record 38 of Set 5 ---&gt; fort nelson
# Processing Record 39 of Set 5 ---&gt; atambua
# Processing Record 40 of Set 5 ---&gt; andenes
# Processing Record 41 of Set 5 ---&gt; arraial do cabo
# Processing Record 42 of Set 5 ---&gt; ferme-neuve
# Processing Record 43 of Set 5 ---&gt; guerrero negro
# Processing Record 44 of Set 5 ---&gt; sirur
# Processing Record 45 of Set 5 ---&gt; tommot
# Processing Record 46 of Set 5 ---&gt; sirjan
# Processing Record 47 of Set 5 ---&gt; carnarvon
# Processing Record 48 of Set 5 ---&gt; chicama
# Processing Record 49 of Set 5 ---&gt; nikolayevsk-na-amure
# Processing Record 50 of Set 5 ---&gt; lompoc
# Processing Record 1 of Set 6 ---&gt; wad madani
# barentsburg not found. Proceeding to the next city...
# Processing Record 2 of Set 6 ---&gt; tabas
# Processing Record 3 of Set 6 ---&gt; krosno
# Processing Record 4 of Set 6 ---&gt; imeni poliny osipenko
# Processing Record 5 of Set 6 ---&gt; komsomolskiy
# Processing Record 6 of Set 6 ---&gt; raton
# huetamo not found. Proceeding to the next city...
# la plata not found. Proceeding to the next city...
# Processing Record 7 of Set 6 ---&gt; nyurba
# Processing Record 8 of Set 6 ---&gt; port hedland
# Processing Record 9 of Set 6 ---&gt; tocopilla
# Processing Record 10 of Set 6 ---&gt; geraldton
# Processing Record 11 of Set 6 ---&gt; vanimo
# Processing Record 12 of Set 6 ---&gt; bakchar
# Processing Record 13 of Set 6 ---&gt; magnor
# Processing Record 14 of Set 6 ---&gt; jablah
# Processing Record 15 of Set 6 ---&gt; mayo
# Processing Record 16 of Set 6 ---&gt; salinopolis
# Processing Record 17 of Set 6 ---&gt; kurchum
# Processing Record 18 of Set 6 ---&gt; ilulissat
# Processing Record 19 of Set 6 ---&gt; panjakent
# Processing Record 20 of Set 6 ---&gt; saint-joseph
# Processing Record 21 of Set 6 ---&gt; yuancheng
# Processing Record 22 of Set 6 ---&gt; alihe
# umm kaddadah not found. Proceeding to the next city...
# Processing Record 23 of Set 6 ---&gt; katete
# Processing Record 24 of Set 6 ---&gt; auki
# Processing Record 25 of Set 6 ---&gt; sorong
# Processing Record 26 of Set 6 ---&gt; souillac
# Processing Record 27 of Set 6 ---&gt; mackenzie
# Processing Record 28 of Set 6 ---&gt; coahuayana
# tolaga bay not found. Proceeding to the next city...
# Processing Record 29 of Set 6 ---&gt; zyryanka
# Processing Record 30 of Set 6 ---&gt; benjamin aceval
# los llanos de aridane not found. Proceeding to the next city...
# Processing Record 31 of Set 6 ---&gt; kungurtug
# Processing Record 32 of Set 6 ---&gt; homer
# Processing Record 33 of Set 6 ---&gt; eshowe
# Processing Record 34 of Set 6 ---&gt; zhuhai
# Processing Record 35 of Set 6 ---&gt; pevek
# Processing Record 36 of Set 6 ---&gt; shelburne
# Processing Record 37 of Set 6 ---&gt; gat
# Processing Record 38 of Set 6 ---&gt; qandala
# Processing Record 39 of Set 6 ---&gt; alofi
# Processing Record 40 of Set 6 ---&gt; mattru
# Processing Record 41 of Set 6 ---&gt; puerto penasco
# Processing Record 42 of Set 6 ---&gt; san angelo
# Processing Record 43 of Set 6 ---&gt; pochutla
# Processing Record 44 of Set 6 ---&gt; kushva
# umzimvubu not found. Proceeding to the next city...
# falealupo not found. Proceeding to the next city...
# Processing Record 45 of Set 6 ---&gt; san patricio
# luceville not found. Proceeding to the next city...
# Processing Record 46 of Set 6 ---&gt; ankazoabo
# burica not found. Proceeding to the next city...
# Processing Record 47 of Set 6 ---&gt; inuvik
# Processing Record 48 of Set 6 ---&gt; bengkulu
# Processing Record 49 of Set 6 ---&gt; sabha
# Processing Record 50 of Set 6 ---&gt; lazaro cardenas
# Processing Record 1 of Set 7 ---&gt; mount isa
# Processing Record 2 of Set 7 ---&gt; toora-khem
# Processing Record 3 of Set 7 ---&gt; yuzhnyy
# Processing Record 4 of Set 7 ---&gt; nouadhibou
# Processing Record 5 of Set 7 ---&gt; kruisfontein
# Processing Record 6 of Set 7 ---&gt; johannesburg
# Processing Record 7 of Set 7 ---&gt; arona
# Processing Record 8 of Set 7 ---&gt; kelvington
# Processing Record 9 of Set 7 ---&gt; kurilsk
# Processing Record 10 of Set 7 ---&gt; fare
# Processing Record 11 of Set 7 ---&gt; tazovskiy
# Processing Record 12 of Set 7 ---&gt; anadyr
# Processing Record 13 of Set 7 ---&gt; nouakchott
# Processing Record 14 of Set 7 ---&gt; port lincoln
# Processing Record 15 of Set 7 ---&gt; nicolas bravo
# Processing Record 16 of Set 7 ---&gt; college
# Processing Record 17 of Set 7 ---&gt; bambous virieux
# Processing Record 18 of Set 7 ---&gt; kasama
# wulanhaote not found. Proceeding to the next city...
# vaitupu not found. Proceeding to the next city...
# nizhneyansk not found. Proceeding to the next city...
# Processing Record 19 of Set 7 ---&gt; tadine
# Processing Record 20 of Set 7 ---&gt; nhulunbuy
# Processing Record 21 of Set 7 ---&gt; vysokogornyy
# Processing Record 22 of Set 7 ---&gt; xining
# Processing Record 23 of Set 7 ---&gt; mustang
# cheuskiny not found. Proceeding to the next city...
# Processing Record 24 of Set 7 ---&gt; abu kamal
# Processing Record 25 of Set 7 ---&gt; mae hong son
# Processing Record 26 of Set 7 ---&gt; faya
# Processing Record 27 of Set 7 ---&gt; marzuq
# Processing Record 28 of Set 7 ---&gt; chengde
# sedelnikovo not found. Proceeding to the next city...
# Processing Record 29 of Set 7 ---&gt; chino valley
# Processing Record 30 of Set 7 ---&gt; beysehir
# Processing Record 31 of Set 7 ---&gt; mitsamiouli
# Processing Record 32 of Set 7 ---&gt; mwinilunga
# Processing Record 33 of Set 7 ---&gt; lavrentiya
# Processing Record 34 of Set 7 ---&gt; helena
# Processing Record 35 of Set 7 ---&gt; ulladulla
# Processing Record 36 of Set 7 ---&gt; salta
# Processing Record 37 of Set 7 ---&gt; mutoko
# azimur not found. Proceeding to the next city...
# Processing Record 38 of Set 7 ---&gt; vestmannaeyjar
# Processing Record 39 of Set 7 ---&gt; kavieng
# Processing Record 40 of Set 7 ---&gt; xai-xai
# Processing Record 41 of Set 7 ---&gt; saldanha
# Processing Record 42 of Set 7 ---&gt; ekhabi
# Processing Record 43 of Set 7 ---&gt; muravlenko
# Processing Record 44 of Set 7 ---&gt; aksu
# Processing Record 45 of Set 7 ---&gt; codrington
# Processing Record 46 of Set 7 ---&gt; ladozhskaya
# Processing Record 47 of Set 7 ---&gt; carndonagh
# Processing Record 48 of Set 7 ---&gt; birjand
# Processing Record 49 of Set 7 ---&gt; igarape
# Processing Record 50 of Set 7 ---&gt; frankfort
# Processing Record 1 of Set 8 ---&gt; poum
# Processing Record 2 of Set 8 ---&gt; sal rei
# Processing Record 3 of Set 8 ---&gt; shingu
# Processing Record 4 of Set 8 ---&gt; samarai
# Processing Record 5 of Set 8 ---&gt; olafsvik
# Processing Record 6 of Set 8 ---&gt; belaya gora
# Processing Record 7 of Set 8 ---&gt; banda aceh
# Processing Record 8 of Set 8 ---&gt; camana
# Processing Record 9 of Set 8 ---&gt; litovko
# Processing Record 10 of Set 8 ---&gt; vardo
# Processing Record 11 of Set 8 ---&gt; axim
# Processing Record 12 of Set 8 ---&gt; dulovo
# Processing Record 13 of Set 8 ---&gt; portland
# Processing Record 14 of Set 8 ---&gt; santa maria
# Processing Record 15 of Set 8 ---&gt; armacao dos buzios
# Processing Record 16 of Set 8 ---&gt; ugoofaaru
# Processing Record 17 of Set 8 ---&gt; sovetskaya
# Processing Record 18 of Set 8 ---&gt; lahaina
# Processing Record 19 of Set 8 ---&gt; baindur
# Processing Record 20 of Set 8 ---&gt; ikalamavony
# Processing Record 21 of Set 8 ---&gt; olmos
# Processing Record 22 of Set 8 ---&gt; zwijndrecht
# Processing Record 23 of Set 8 ---&gt; abha
# Processing Record 24 of Set 8 ---&gt; ornskoldsvik
# Processing Record 25 of Set 8 ---&gt; tilichiki
# Processing Record 26 of Set 8 ---&gt; abapo
# Processing Record 27 of Set 8 ---&gt; hope
# Processing Record 28 of Set 8 ---&gt; pemba
# Processing Record 29 of Set 8 ---&gt; rundu
# Processing Record 30 of Set 8 ---&gt; sao joao da barra
# Processing Record 31 of Set 8 ---&gt; rosarito
# Processing Record 32 of Set 8 ---&gt; bayan
# Processing Record 33 of Set 8 ---&gt; sao filipe
# Processing Record 34 of Set 8 ---&gt; dunedin
# coolum beach not found. Proceeding to the next city...
# Processing Record 35 of Set 8 ---&gt; nanning
# Processing Record 36 of Set 8 ---&gt; svetlyy
# Processing Record 37 of Set 8 ---&gt; ankang
# Processing Record 38 of Set 8 ---&gt; grindavik
# Processing Record 39 of Set 8 ---&gt; novyy urengoy
# Processing Record 40 of Set 8 ---&gt; santa rosa
# Processing Record 41 of Set 8 ---&gt; jericho
# henties bay not found. Proceeding to the next city...
# Processing Record 42 of Set 8 ---&gt; tessalit
# Processing Record 43 of Set 8 ---&gt; pontarlier
# Processing Record 44 of Set 8 ---&gt; urucara
# Processing Record 45 of Set 8 ---&gt; riviere-au-renard
# Processing Record 46 of Set 8 ---&gt; ambikapur
# Processing Record 47 of Set 8 ---&gt; meulaboh
# Processing Record 48 of Set 8 ---&gt; miastko
# nguiu not found. Proceeding to the next city...
# Processing Record 49 of Set 8 ---&gt; kabanjahe
# Processing Record 50 of Set 8 ---&gt; haradok
# Processing Record 1 of Set 9 ---&gt; mao
# Processing Record 2 of Set 9 ---&gt; vao
# Processing Record 3 of Set 9 ---&gt; bilibino
# Processing Record 4 of Set 9 ---&gt; lasa
# Processing Record 5 of Set 9 ---&gt; sitarganj
# Processing Record 6 of Set 9 ---&gt; sakakah
# Processing Record 7 of Set 9 ---&gt; alwar
# Processing Record 8 of Set 9 ---&gt; frontera
# Processing Record 9 of Set 9 ---&gt; seoul
# Processing Record 10 of Set 9 ---&gt; tecpan
# Processing Record 11 of Set 9 ---&gt; derzhavinsk
# Processing Record 12 of Set 9 ---&gt; agadir
# Processing Record 13 of Set 9 ---&gt; cuamba
# Processing Record 14 of Set 9 ---&gt; lumeje
# Processing Record 15 of Set 9 ---&gt; taoudenni
# Processing Record 16 of Set 9 ---&gt; potam
# Processing Record 17 of Set 9 ---&gt; sarkand
# Processing Record 18 of Set 9 ---&gt; korla
# Processing Record 19 of Set 9 ---&gt; pauini
# bawisan not found. Proceeding to the next city...
# Processing Record 20 of Set 9 ---&gt; sept-iles
# Processing Record 21 of Set 9 ---&gt; natchez
# Processing Record 22 of Set 9 ---&gt; winnemucca
# Processing Record 23 of Set 9 ---&gt; swift current
# Processing Record 24 of Set 9 ---&gt; tanout
# Processing Record 25 of Set 9 ---&gt; iralaya
# utiroa not found. Proceeding to the next city...
# Processing Record 26 of Set 9 ---&gt; evensk
# Processing Record 27 of Set 9 ---&gt; oistins
# Processing Record 28 of Set 9 ---&gt; nanzhou
# Processing Record 29 of Set 9 ---&gt; popondetta
# Processing Record 30 of Set 9 ---&gt; saint-pierre
# Processing Record 31 of Set 9 ---&gt; kailua
# Processing Record 32 of Set 9 ---&gt; ust-kuyga
# Processing Record 33 of Set 9 ---&gt; blovstrod
# Processing Record 34 of Set 9 ---&gt; jalu
# Processing Record 35 of Set 9 ---&gt; touros
# Processing Record 36 of Set 9 ---&gt; klaksvik
# Processing Record 37 of Set 9 ---&gt; george town
# Processing Record 38 of Set 9 ---&gt; izumo
# Processing Record 39 of Set 9 ---&gt; bestobe
# Processing Record 40 of Set 9 ---&gt; barwadih
# Processing Record 41 of Set 9 ---&gt; mossendjo
# Processing Record 42 of Set 9 ---&gt; ilhabela
# Processing Record 43 of Set 9 ---&gt; taltal
# Processing Record 44 of Set 9 ---&gt; paramonga
# Processing Record 45 of Set 9 ---&gt; gelemso
# Processing Record 46 of Set 9 ---&gt; greenwood
# Processing Record 47 of Set 9 ---&gt; kyra
# warqla not found. Proceeding to the next city...
# Processing Record 48 of Set 9 ---&gt; salvacion
# Processing Record 49 of Set 9 ---&gt; voh
# Processing Record 50 of Set 9 ---&gt; olden
# Processing Record 1 of Set 10 ---&gt; juneau
# Processing Record 2 of Set 10 ---&gt; narsaq
# Processing Record 3 of Set 10 ---&gt; pecos
# Processing Record 4 of Set 10 ---&gt; biak
# Processing Record 5 of Set 10 ---&gt; port macquarie
# Processing Record 6 of Set 10 ---&gt; luwuk
# Processing Record 7 of Set 10 ---&gt; solnechnyy
# Processing Record 8 of Set 10 ---&gt; altay
# Processing Record 9 of Set 10 ---&gt; juba
# Processing Record 10 of Set 10 ---&gt; suhbaatar
# Processing Record 11 of Set 10 ---&gt; kaniama
# Processing Record 12 of Set 10 ---&gt; algiers
# Processing Record 13 of Set 10 ---&gt; coari
# Processing Record 14 of Set 10 ---&gt; visnes
# sorvag not found. Proceeding to the next city...
# Processing Record 15 of Set 10 ---&gt; iqaluit
# Processing Record 16 of Set 10 ---&gt; simbahan
# todos santos not found. Proceeding to the next city...
# Processing Record 17 of Set 10 ---&gt; namibe
# Processing Record 18 of Set 10 ---&gt; pangai
# Processing Record 19 of Set 10 ---&gt; murgab
# Processing Record 20 of Set 10 ---&gt; buluang
# Processing Record 21 of Set 10 ---&gt; sitka
# Processing Record 22 of Set 10 ---&gt; naze
# Processing Record 23 of Set 10 ---&gt; bandarbeyla
# Processing Record 24 of Set 10 ---&gt; gidole
# Processing Record 25 of Set 10 ---&gt; riacho de santana
# Processing Record 26 of Set 10 ---&gt; labuhan
# Processing Record 27 of Set 10 ---&gt; loa janan
# Processing Record 28 of Set 10 ---&gt; sola
# Processing Record 29 of Set 10 ---&gt; srikakulam
# Processing Record 30 of Set 10 ---&gt; bonthe
# Processing Record 31 of Set 10 ---&gt; paita
# Processing Record 32 of Set 10 ---&gt; inta
# Processing Record 33 of Set 10 ---&gt; dimapur
# Processing Record 34 of Set 10 ---&gt; mbalmayo
# Processing Record 35 of Set 10 ---&gt; edson
# Processing Record 36 of Set 10 ---&gt; saint-felicien
# Processing Record 37 of Set 10 ---&gt; ximei
# Processing Record 38 of Set 10 ---&gt; kashmor
# Processing Record 39 of Set 10 ---&gt; polunochnoye
# saint anthony not found. Proceeding to the next city...
# Processing Record 40 of Set 10 ---&gt; catia la mar
# Processing Record 41 of Set 10 ---&gt; mbandaka
# taburi not found. Proceeding to the next city...
# Processing Record 42 of Set 10 ---&gt; uddevalla
# tarudant not found. Proceeding to the next city...
# Processing Record 43 of Set 10 ---&gt; zeya
# Processing Record 44 of Set 10 ---&gt; najran
# Processing Record 45 of Set 10 ---&gt; chiredzi
# nerchinskiy zavod not found. Proceeding to the next city...
# Processing Record 46 of Set 10 ---&gt; wenling
# Processing Record 47 of Set 10 ---&gt; fiki
# Processing Record 48 of Set 10 ---&gt; tomakomai
# Processing Record 49 of Set 10 ---&gt; wadi maliz
# general pico not found. Proceeding to the next city...
# Processing Record 50 of Set 10 ---&gt; dawlatabad
# Processing Record 1 of Set 11 ---&gt; darhan
# Processing Record 2 of Set 11 ---&gt; prijepolje
# Processing Record 3 of Set 11 ---&gt; almeirim
# Processing Record 4 of Set 11 ---&gt; moussoro
# Processing Record 5 of Set 11 ---&gt; manali
# Processing Record 6 of Set 11 ---&gt; illela
# Processing Record 7 of Set 11 ---&gt; cockburn town
# port-de-paix not found. Proceeding to the next city...
# Processing Record 8 of Set 11 ---&gt; malpe
# Processing Record 9 of Set 11 ---&gt; katangli
# Processing Record 10 of Set 11 ---&gt; atasu
# ciudad bolivar not found. Proceeding to the next city...
# Processing Record 11 of Set 11 ---&gt; kavaratti
# Processing Record 12 of Set 11 ---&gt; celestun
# Processing Record 13 of Set 11 ---&gt; boulder
# Processing Record 14 of Set 11 ---&gt; azul
# Processing Record 15 of Set 11 ---&gt; akom
# Processing Record 16 of Set 11 ---&gt; ivolginsk
# Processing Record 17 of Set 11 ---&gt; barra patuca
# Processing Record 18 of Set 11 ---&gt; kirakira
# karamea not found. Proceeding to the next city...
# Processing Record 19 of Set 11 ---&gt; pryazha
# Processing Record 20 of Set 11 ---&gt; makakilo city
# Processing Record 21 of Set 11 ---&gt; koslan
# Processing Record 22 of Set 11 ---&gt; champerico
# Processing Record 23 of Set 11 ---&gt; leeton
# Processing Record 24 of Set 11 ---&gt; oranjemund
# Processing Record 25 of Set 11 ---&gt; joshimath
# Processing Record 26 of Set 11 ---&gt; ericeira
# Processing Record 27 of Set 11 ---&gt; kuching
# Processing Record 28 of Set 11 ---&gt; mahajanga
# Processing Record 29 of Set 11 ---&gt; suleya
# Processing Record 30 of Set 11 ---&gt; alta floresta
# Processing Record 31 of Set 11 ---&gt; doha
# Processing Record 32 of Set 11 ---&gt; teya
# Processing Record 33 of Set 11 ---&gt; khonsa
# mundo nuevo not found. Proceeding to the next city...
# Processing Record 34 of Set 11 ---&gt; lodja
# Processing Record 35 of Set 11 ---&gt; redmond
# wiang sa not found. Proceeding to the next city...
# Processing Record 36 of Set 11 ---&gt; sicuani
# Processing Record 37 of Set 11 ---&gt; illapel
# Processing Record 38 of Set 11 ---&gt; koumac
# Processing Record 39 of Set 11 ---&gt; herat
# Processing Record 40 of Set 11 ---&gt; lakes entrance
# Processing Record 41 of Set 11 ---&gt; biu
# Processing Record 42 of Set 11 ---&gt; asau
# *******************************
# Data Retrieval Complete
# *******************************

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# The data generated from the API calls will be compiled into a new Data Fram
weather_data_frame = pd.DataFrame({
    'City':updated_city_list,
    'Lattitude':lattitude,
    'Longitude': longitude,
    'Max Temp': max_temp,
    'Humidity': humidity,
    'Cloudiness': cloudinesses,
    'Wind Speed': wind,
    'Country': country_list,
    'Date':dates
})

## Exporting the new DataFrame into a csv file
weather_data_frame.to_csv('..\Output_Data\Weather_Data_Collection.csv')

## Displaying the DataFrame
print(f'{weather_data_frame.shape[0]} cities, along with their weather information, have been collated\n')
weather_data_frame.head()
# Out:
# 542 cities, along with their weather information, have been collated
#              City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0      bredasdorp     -34.53      20.04     14.00        67          93
# 1       ostrovnoy      68.05      39.51      7.52        85         100
# 2       khandbari      27.37      87.20     29.20        51           1
# 3            atar      20.52     -13.05     29.36        25           0
# 4  severo-kurilsk      50.68     156.12      9.45        82          99
#
#    Wind Speed Country        Date
# 0        8.20      ZA  1601618790
# 1        7.34      RU  1601618790
# 2        1.99      NP  1601618791
# 3        4.75      MR  1601618791
# 4        4.78      RU  1601618791

# %%
## Summary Statistics 
weather_data_frame.describe()
# Out:
#         Lattitude   Longitude   Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  542.000000  542.000000  542.00000  542.000000  542.000000  542.000000
# mean    22.143579   20.946697   17.96690   70.097786   49.758303    3.420498
# std     31.790999   88.523360    9.15488   21.095672   38.871734    2.395393
# min    -54.800000 -179.170000   -8.23000    9.000000    0.000000    0.030000
# 25%     -4.010000  -53.395000   11.00000   59.250000    5.250000    1.505000
# 50%     27.205000   26.085000   18.89000   74.000000   44.500000    2.760000
# 75%     48.630000   95.110000   25.98750   87.000000   90.000000    4.697500
# max     78.220000  177.480000   37.22000  100.000000  100.000000   14.400000
#
#                Date
# count  5.420000e+02
# mean   1.601619e+09
# std    8.096807e+01
# min    1.601618e+09
# 25%    1.601619e+09
# 50%    1.601619e+09
# 75%    1.601619e+09
# max    1.601619e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking to see if there are cities with humidities over 100
weather_data_frame[weather_data_frame['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lattitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames_Over100 = weather_data_frame[weather_data_frame['Humidity']>100].index

# %%
if (len(indexNames_Over100)) > 0:
    print(f'There are cities with humidity over 100')
else:
    print(f'There are no cities with humidity over 100')
# Out:
# There are no cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data_frame.drop(indexNames_Over100, inplace=False)

# %%
print(f'There are {clean_city_data.shape[0]} cities to be assessed\n')
clean_city_data.head()
# Out:
# There are 542 cities to be assessed
#              City  Lattitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0      bredasdorp     -34.53      20.04     14.00        67          93
# 1       ostrovnoy      68.05      39.51      7.52        85         100
# 2       khandbari      27.37      87.20     29.20        51           1
# 3            atar      20.52     -13.05     29.36        25           0
# 4  severo-kurilsk      50.68     156.12      9.45        82          99
#
#    Wind Speed Country        Date
# 0        8.20      ZA  1601618790
# 1        7.34      RU  1601618790
# 2        1.99      NP  1601618791
# 3        4.75      MR  1601618791
# 4        4.78      RU  1601618791

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# A scatter plot will be used in order to determine the relationship between temperature and lattitudes


x_lattitude = clean_city_data['Lattitude']
y_temperature = clean_city_data['Max Temp']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Temperature\n Analysed on {current_time}',fontsize=15)
ax1.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_temperature, edgecolors='black', c='#eb63c6')
ax1.grid(True)

fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Temperature.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# We will use the previous x_label and create a new Y label pertaining to humidity
y_humidity = clean_city_data['Humidity']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Humidity\n Analysed on {current_time}',fontsize=15)
ax1.set_ylabel('Humidity', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_humidity, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Humidity.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# We will set a new y_ variable pertaining to Cloudiness
y_cloudiness = clean_city_data['Cloudiness']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Cloudiness\nAnalysed on {current_time}',fontsize=15)
ax1.set_ylabel('Cloudiness(%)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_cloudiness, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_Cloudiness.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# We wil set a new y_ variable pertaining to Wind Speed
y_windspeed = clean_city_data['Wind Speed']
fig1, ax1 = plt.subplots()
ax1.set_title(f'City Latitude vs Wind Speed\nAnalysed on {current_time}',fontsize=15)
ax1.set_ylabel('Wind Speed (mph)', fontsize=15)
ax1.set_xlabel('Latitude',fontsize=15)
ax1.scatter(x_lattitude,y_windspeed, edgecolors='black',c='#eb63c6')
ax1.grid(True)
fig1.tight_layout()
plt.savefig('../Images/Latitude_vs_WindSpeed.png')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Northern Hemisphere Latitudes vs Max Temperature

# %%
# All cities within the Northern Hemisphere will be in the lattitude range of 0(equator) to 90. 
# We will need to filter the dataframe to contain cities within the northern hemisphere (nh)

northern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']>=0]

x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_max_temp = northern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_max_temp)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Max Temp vs. Latitude Linear Regression\nAnalysed on {current_time}',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Max_Temp.png')
print(f'The r-squaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-squaured value is 0.7202954033071421
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# All cities within the Southern Hemisphere will be in the lattitude range of 0(equator) to -90. 
# We will need to filter the dataframe to contain cities within the southern hemisphere (sh)

southern_hemisphere_cities_df = clean_city_data[clean_city_data['Lattitude']<=0]

x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_max_temp = southern_hemisphere_cities_df['Max Temp']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_max_temp)

# Linear Regression Label
line_eq_sh = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit_sh = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Max Temp vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Maximum Temperature(˚C)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit_sh,'black')
ax2.scatter(x_sh_latitude,y_sh_max_temp, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Max_Temp.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.40912223576827705
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_humidity = northern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Humidity vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.032083138723007915
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_humidity = southern_hemisphere_cities_df['Humidity']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_humidity)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Humidity vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Humidity(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_humidity, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_Humidity.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.01743092049230884
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_cloudiness = northern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Cloudiness vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.0345854096429402
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_cloudiness = southern_hemisphere_cities_df['Cloudiness']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_cloudiness)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Cloudiness vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Cloudiness(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_cloudiness, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_cloudiness.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.01547347300654092
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_nh_latitude = northern_hemisphere_cities_df['Lattitude']
y_nh_windspeed = northern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latnh_slope, latnh_int, latnh_r,latnh_p,latnh_stderr = st.linregress(x_nh_latitude,y_nh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latnh_slope,2)) + "x + " + str(round(latnh_int,2))

line_of_best_fit = x_nh_latitude * latnh_slope + latnh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'NH Windspeed vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Windspeed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_nh_latitude,line_of_best_fit,'black')
ax2.scatter(x_nh_latitude,y_nh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/NH_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latnh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.05702360352180783
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Creating New y_axis data
x_sh_latitude = southern_hemisphere_cities_df['Lattitude']
y_sh_windspeed = southern_hemisphere_cities_df['Wind Speed']

# Setting the Linear Regression Equation
latsh_slope, latsh_int, latsh_r,latsh_p,latsh_stderr = st.linregress(x_sh_latitude,y_sh_windspeed)

# Linear Regression Label
line_eq = "y = " + str(round(latsh_slope,2)) + "x + " + str(round(latsh_int,2))

line_of_best_fit = x_sh_latitude * latsh_slope + latsh_int

# Plotting the scatter plots with the Linear Regression Equation
fig2, ax2 = plt.subplots()
ax2.set_title(f'SH Wind Speed vs. Latitude Linear Regression\nAnalysed on{current_time}',fontsize=15)
ax2.set_ylabel('Wind Speed(%)', fontsize=15)
ax2.set_xlabel('Latitude',fontsize=15)
ax2.plot(x_sh_latitude,line_of_best_fit,'black')
ax2.scatter(x_sh_latitude,y_sh_windspeed, edgecolors='black',c='#eb63c6')
ax2.grid(True)
ax2.legend([line_eq])
fig2.tight_layout()
plt.savefig('../Images/sh_Latitude_vs_windspeed.png')
print(f'The r-sqaured value is {latsh_r**2}')
plt.show()
# Out:
# The r-sqaured value is 0.05401488844209344
# &lt;Figure size 432x288 with 1 Axes&gt;
